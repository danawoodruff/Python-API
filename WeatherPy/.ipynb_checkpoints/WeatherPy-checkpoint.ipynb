# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 605

# %%
print(cities)
# Out:
# ['new norfolk', 'malwan', 'saqqez', 'teguldet', 'salalah', 'east london', 'iqaluit', 'los llanos de aridane', 'mys shmidta', 'rikitea', 'bada', 'kodiak', 'hermanus', 'provideniya', 'norman wells', 'port alfred', 'naze', 'clyde river', 'castro', 'illoqqortoormiut', 'pontianak', 'saint-joseph', 'ahipara', 'calvinia', 'bambous virieux', 'broome', 'ostrovnoy', 'ilulissat', 'esperance', 'jutai', 'pevek', 'souillac', 'mao', 'lompoc', 'camabatela', 'atuona', 'georgetown', 'jumla', 'nador', 'vaini', 'kapaa', 'taolanaro', 'punta arenas', 'baiyin', 'klyuchi', 'puerto ayora', 'hilo', 'constitucion', 'busselton', 'belushya guba', 'yining', 'ushuaia', 'kilrush', 'bredasdorp', 'novobirilyussy', 'yellowknife', 'arraial do cabo', 'bluff', 'albany', 'ancud', 'srednekolymsk', 'severo-kurilsk', 'walvis bay', 'chicama', 'port huron', 'reinosa', 'valparaiso', 'barrow', 'fukue', 'north myrtle beach', 'coahuayana', 'havre-saint-pierre', 'namibe', 'saint george', 'avdiyivka', 'satitoa', 'okhotsk', 'bonavista', 'alotau', 'grand gaube', 'kulhudhuffushi', 'longyearbyen', 'visby', 'amderma', 'shaunavon', 'aqtobe', 'mar del plata', 'butaritari', 'aripuana', 'cherskiy', 'la ronge', 'upernavik', 'alofi', 'yar-sale', 'tarudant', 'rio grande', 'pisco', 'jamestown', 'mataura', 'sakakah', 'avarua', 'sentyabrskiy', 'tasiilaq', 'fort nelson', 'shubarkuduk', 'nikolskoye', 'kruisfontein', 'rome', 'beringovskiy', 'hobart', 'qaanaaq', 'yumen', 'nome', 'katsuura', 'paamiut', 'roald', 'port elizabeth', 'ubajara', 'asfi', 'hithadhoo', 'himora', 'bara', 'sabaudia', 'tahta', 'riyadh', 'buin', 'tessalit', 'bengkulu', 'tuatapere', 'vila franca do campo', 'mokrous', 'gizo', 'rungata', 'ponta do sol', 'cabo san lucas', 'grand forks', 'klaksvik', 'saleaula', 'hambantota', 'terrace', 'champerico', 'chokurdakh', 'umarkhed', 'fare', 'westport', 'tiksi', 'bambanglipuro', 'muros', 'narsaq', 'vardo', 'herat', 'saint-philippe', 'gotsu', 'tiarei', 'slave lake', 'llangefni', 'thompson', 'portobelo', 'dmitriyev-lgovskiy', 'carnarvon', 'saran', 'bathsheba', 'pacific grove', 'poum', 'wad rawah', 'san jose', 'tsihombe', 'carutapera', 'tame', 'kefamenanu', 'yangjiang', 'cape town', 'marathon', 'ngunguru', 'port blair', 'faanui', 'gladstone', 'pangkalanbuun', 'russell', 'geraldton', 'inhambane', 'kaitangata', 'coffs harbour', 'mecca', 'angoche', 'manalurpet', 'lincoln', 'nizwa', 'spirit river', 'codrington', 'dukat', 'husavik', 'khandyga', 'litayen', 'tuktoyaktuk', 'laguna', 'takoradi', 'aitape', 'vimperk', 'knysna', 'yuksekova', 'bagdarin', 'bethel', 'nalobikha', 'mahaicony', 'nara', 'windsor', 'santa cruz', 'solbjerg', 'airai', 'barentsburg', 'selkirk', 'baykit', 'torbay', 'huarmey', 'college', 'beloha', 'simbahan', 'truckee', 'severodvinsk', 'marsh harbour', 'silivainiotika', 'calama', 'bilma', 'jinchang', 'japura', 'fethiye', 'ust-kuyga', 'sao filipe', 'emerald', 'skegness', 'aswan', 'fortuna', 'leningradskiy', 'tilichiki', 'sao miguel do araguaia', 'aleksandrovsk-sakhalinskiy', 'leshukonskoye', 'nizhneyansk', 'lewistown', 'luganville', 'loikaw', 'nyurba', 'mehran', 'chuy', 'odweyne', 'obama', 'victoria', 'saint-francois', 'omsukchan', 'gazanjyk', 'touros', 'lagoa', 'saldanha', 'padang', 'khatanga', 'saint-georges', 'cidreira', 'lavrentiya', 'nizhniy odes', 'ribeira grande', 'ulladulla', 'arlit', 'tolu', 'korla', 'grammatikon', 'flinders', 'sisimiut', 'liverpool', 'fairbanks', 'cacoal', 'rocha', 'svetlogorsk', 'lerwick', 'denton', 'maldonado', 'vangaindrano', 'puerto escondido', 'dikson', 'lowestoft', 'attawapiskat', 'mahebourg', 'palafrugell', 'vestmannaeyjar', 'rondonopolis', 'zelenoborsk', 'kenai', 'teguise', 'atambua', 'moerai', 'mnogovershinnyy', 'biak', 'namatanai', 'nishihara', 'grand-lahou', 'tome', 'bako', 'batsfjord', 'great yarmouth', 'ajaccio', 'batetskiy', 'drayton valley', 'rundu', 'newcastle', 'stettler', 'batticaloa', 'ambilobe', 'lisakovsk', 'opuwo', 'kushiro', 'birao', 'shubarshi', 'vaitupu', 'zhezkazgan', 'broken hill', 'mount gambier', 'whitehorse', 'asayita', 'lima', ...

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
import json
import requests

from api_keys import weather_api_key
from urllib.error import HTTPError

# Build query URL
query_url = f"http://api.openweathermap.org/data/2.5/weather?appid=a48e24767ec9494ca8be13ca3d87fa76&units=imperial&q="

# Lists for the dataframe
citylist = []
cloudiness = []
dates = []
humidity = []
lats = []
longs = []
max_temps = []
windspeeds = []
countries = []

# Initial counters
counter = 0

# Loop for calling data city by city
for city in cities:
    try:
        response = requests.get(query_url + city.replace(" ","&")).json()
        cloudiness.append(response['clouds']['all'])
        dates.append(response['dt'])
        humidity.append(response['main']['humidity'])
        lats.append(response['coord']['lat'])
        longs.append(response['coord']['lon'])
        max_temps.append(response['main']['temp_max'])
        windspeeds.append(response['wind']['speed'])
        countries.append(response['sys']['country'])
        citylist.append(city)
        counter = counter + 1   
        
        print(f"Processing Record {counter} | {city}")
    except Exception:
        print("City way too small for wx data. Skipping...")
# Out:
# Processing Record 1 | new norfolk
# City way too small for wx data. Skipping...
# Processing Record 2 | saqqez
# Processing Record 3 | teguldet
# Processing Record 4 | salalah
# Processing Record 5 | east london
# Processing Record 6 | iqaluit
# City way too small for wx data. Skipping...
# Processing Record 7 | mys shmidta
# Processing Record 8 | rikitea
# Processing Record 9 | bada
# Processing Record 10 | kodiak
# Processing Record 11 | hermanus
# Processing Record 12 | provideniya
# Processing Record 13 | norman wells
# Processing Record 14 | port alfred
# Processing Record 15 | naze
# Processing Record 16 | clyde river
# Processing Record 17 | castro
# City way too small for wx data. Skipping...
# Processing Record 18 | pontianak
# Processing Record 19 | saint-joseph
# Processing Record 20 | ahipara
# Processing Record 21 | calvinia
# Processing Record 22 | bambous virieux
# Processing Record 23 | broome
# Processing Record 24 | ostrovnoy
# Processing Record 25 | ilulissat
# Processing Record 26 | esperance
# Processing Record 27 | jutai
# Processing Record 28 | pevek
# Processing Record 29 | souillac
# Processing Record 30 | mao
# Processing Record 31 | lompoc
# Processing Record 32 | camabatela
# Processing Record 33 | atuona
# Processing Record 34 | georgetown
# Processing Record 35 | jumla
# Processing Record 36 | nador
# Processing Record 37 | vaini
# Processing Record 38 | kapaa
# City way too small for wx data. Skipping...
# Processing Record 39 | punta arenas
# Processing Record 40 | baiyin
# Processing Record 41 | klyuchi
# Processing Record 42 | puerto ayora
# Processing Record 43 | hilo
# Processing Record 44 | constitucion
# Processing Record 45 | busselton
# City way too small for wx data. Skipping...
# Processing Record 46 | yining
# Processing Record 47 | ushuaia
# Processing Record 48 | kilrush
# Processing Record 49 | bredasdorp
# Processing Record 50 | novobirilyussy
# Processing Record 51 | yellowknife
# Processing Record 52 | arraial do cabo
# Processing Record 53 | bluff
# Processing Record 54 | albany
# Processing Record 55 | ancud
# Processing Record 56 | srednekolymsk
# Processing Record 57 | severo-kurilsk
# City way too small for wx data. Skipping...
# Processing Record 58 | chicama
# Processing Record 59 | port huron
# Processing Record 60 | reinosa
# Processing Record 61 | valparaiso
# Processing Record 62 | barrow
# Processing Record 63 | fukue
# Processing Record 64 | north myrtle beach
# Processing Record 65 | coahuayana
# Processing Record 66 | havre-saint-pierre
# Processing Record 67 | namibe
# City way too small for wx data. Skipping...
# Processing Record 68 | avdiyivka
# City way too small for wx data. Skipping...
# Processing Record 69 | okhotsk
# Processing Record 70 | bonavista
# City way too small for wx data. Skipping...
# Processing Record 71 | grand gaube
# Processing Record 72 | kulhudhuffushi
# Processing Record 73 | longyearbyen
# Processing Record 74 | visby
# City way too small for wx data. Skipping...
# Processing Record 75 | shaunavon
# Processing Record 76 | aqtobe
# Processing Record 77 | mar del plata
# Processing Record 78 | butaritari
# Processing Record 79 | aripuana
# Processing Record 80 | cherskiy
# City way too small for wx data. Skipping...
# Processing Record 81 | upernavik
# Processing Record 82 | alofi
# Processing Record 83 | yar-sale
# City way too small for wx data. Skipping...
# Processing Record 84 | rio grande
# Processing Record 85 | pisco
# Processing Record 86 | jamestown
# Processing Record 87 | mataura
# Processing Record 88 | sakakah
# Processing Record 89 | avarua
# City way too small for wx data. Skipping...
# Processing Record 90 | tasiilaq
# Processing Record 91 | fort nelson
# Processing Record 92 | shubarkuduk
# Processing Record 93 | nikolskoye
# Processing Record 94 | kruisfontein
# Processing Record 95 | rome
# Processing Record 96 | beringovskiy
# Processing Record 97 | hobart
# Processing Record 98 | qaanaaq
# Processing Record 99 | yumen
# Processing Record 100 | nome
# Processing Record 101 | katsuura
# Processing Record 102 | paamiut
# Processing Record 103 | roald
# Processing Record 104 | port elizabeth
# Processing Record 105 | ubajara
# Processing Record 106 | asfi
# Processing Record 107 | hithadhoo
# City way too small for wx data. Skipping...
# Processing Record 108 | bara
# Processing Record 109 | sabaudia
# Processing Record 110 | tahta
# Processing Record 111 | riyadh
# Processing Record 112 | buin
# Processing Record 113 | tessalit
# Processing Record 114 | bengkulu
# Processing Record 115 | tuatapere
# Processing Record 116 | vila franca do campo
# Processing Record 117 | mokrous
# Processing Record 118 | gizo
# City way too small for wx data. Skipping...
# Processing Record 119 | ponta do sol
# Processing Record 120 | cabo san lucas
# Processing Record 121 | grand forks
# Processing Record 122 | klaksvik
# City way too small for wx data. Skipping...
# Processing Record 123 | hambantota
# Processing Record 124 | terrace
# Processing Record 125 | champerico
# Processing Record 126 | chokurdakh
# Processing Record 127 | umarkhed
# Processing Record 128 | fare
# Processing Record 129 | westport
# Processing Record 130 | tiksi
# Processing Record 131 | bambanglipuro
# Processing Record 132 | muros
# Processing Record 133 | narsaq
# Processing Record 134 | vardo
# Processing Record 135 | herat
# Processing Record 136 | saint-philippe
# Processing Record 137 | gotsu
# Processing Record 138 | tiarei
# City way too small for wx data. Skipping...
# Processing Record 139 | llangefni
# Processing Record 140 | thompson
# Processing Record 141 | portobelo
# City way too small for wx data. Skipping...
# Processing Record 142 | carnarvon
# Processing Record 143 | saran
# Processing Record 144 | bathsheba
# Processing Record 145 | pacific grove
# Processing Record 146 | poum
# Processing Record 147 | wad rawah
# Processing Record 148 | san jose
# City way too small for wx data. Skipping...
# Processing Record 149 | carutapera
# Processing Record 150 | tame
# Processing Record 151 | kefamenanu
# Processing Record 152 | yangjiang
# Processing Record 153 | cape town
# Processing Record 154 | marathon
# Processing Record 155 | ngunguru
# Processing Record 156 | port blair
# Processing Record 157 | faanui
# Processing Record 158 | gladstone
# Processing Record 159 | pangkalanbuun
# Processing Record 160 | russell
# Processing Record 161 | geraldton
# Processing Record 162 | inhambane
# Processing Record 163 | kaitangata
# City way too small for wx data. Skipping...
# Processing Record 164 | mecca
# Processing Record 165 | angoche
# City way too small for wx data. Skipping...
# Processing Record 166 | lincoln
# Processing Record 167 | nizwa
# Processing Record 168 | spirit river
# Processing Record 169 | codrington
# Processing Record 170 | dukat
# Processing Record 171 | husavik
# Processing Record 172 | khandyga
# City way too small for wx data. Skipping...
# Processing Record 173 | tuktoyaktuk
# Processing Record 174 | laguna
# Processing Record 175 | takoradi
# Processing Record 176 | aitape
# Processing Record 177 | vimperk
# Processing Record 178 | knysna
# Processing Record 179 | yuksekova
# Processing Record 180 | bagdarin
# Processing Record 181 | bethel
# Processing Record 182 | nalobikha
# City way too small for wx data. Skipping...
# Processing Record 183 | nara
# Processing Record 184 | windsor
# Processing Record 185 | santa cruz
# Processing Record 186 | solbjerg
# Processing Record 187 | airai
# City way too small for wx data. Skipping...
# Processing Record 188 | selkirk
# Processing Record 189 | baykit
# Processing Record 190 | torbay
# Processing Record 191 | huarmey
# Processing Record 192 | college
# Processing Record 193 | beloha
# Processing Record 194 | simbahan
# Processing Record 195 | truckee
# Processing Record 196 | severodvinsk
# Processing Record 197 | marsh harbour
# City way too small for wx data. Skipping...
# Processing Record 198 | calama
# Processing Record 199 | bilma
# Processing Record 200 | jinchang
# Processing Record 201 | japura
# Processing Record 202 | fethiye
# Processing Record 203 | ust-kuyga
# Processing Record 204 | sao filipe
# Processing Record 205 | emerald
# Processing Record 206 | skegness
# Processing Record 207 | aswan
# Processing Record 208 | fortuna
# Processing Record 209 | leningradskiy
# Processing Record 210 | tilichiki
# Processing Record 211 | sao miguel do araguaia
# Processing Record 212 | aleksandrovsk-sakhalinskiy
# Processing Record 213 | leshukonskoye
# City way too small for wx data. Skipping...
# Processing Record 214 | lewistown
# Processing Record 215 | luganville
# Processing Record 216 | loikaw
# Processing Record 217 | nyurba
# Processing Record 218 | mehran
# Processing Record 219 | chuy
# Processing Record 220 | odweyne
# Processing Record 221 | obama
# Processing Record 222 | victoria
# Processing Record 223 | saint-francois
# Processing Record 224 | omsukchan
# Processing Record 225 | gazanjyk
# Processing Record 226 | touros
# Processing Record 227 | lagoa
# Processing Record 228 | saldanha
# Processing Record 229 | padang
# Processing Record 230 | khatanga
# Processing Record 231 | saint-georges
# Processing Record 232 | cidreira
# Processing Record 233 | lavrentiya
# Processing Record 234 | nizhniy odes
# Processing Record 235 | ribeira grande
# Processing Record 236 | ulladulla
# Processing Record 237 | arlit
# Processing Record 238 | tolu
# Processing Record 239 | korla
# City way too small for wx data. Skipping...
# Processing Record 240 | flinders
# Processing Record 241 | sisimiut
# Processing Record 242 | liverpool
# Processing Record 243 | fairbanks
# Processing Record 244 | cacoal
# Processing Record 245 | rocha
# Processing Record 246 | svetlogorsk
# Processing Record 247 | lerwick
# Processing Record 248 | denton
# Processing Record 249 | maldonado
# Processing Record 250 | vangaindrano
# Processing Record 251 | puerto escondido
# Processing Record 252 | dikson
# Processing Record 253 | lowestoft
# City way too small for wx data. Skipping...
# Processing Record 254 | mahebourg
# Processing Record 255 | palafrugell
# Processing Record 256 | vestmannaeyjar
# Processing Record 257 | rondonopolis
# Processing Record 258 | zelenoborsk
# Processing Record 259 | kenai
# Processing Record 260 | teguise
# Processing Record 261 | atambua
# Processing Record 262 | moerai
# Processing Record 263 | mnogovershinnyy
# Processing Record 264 | biak
# Processing Record 265 | namatanai
# Processing Record 266 | nishihara
# Processing Record 267 | grand-lahou
# Processing Record 268 | tome
# Processing Record 269 | bako
# Processing Record 270 | batsfjord
# City way too small for wx data. Skipping...
# Processing Record 271 | ajaccio
# Processing Record 272 | batetskiy
# Processing Record 273 | drayton valley
# Processing Record 274 | rundu
# Processing Record 275 | newcastle
# Processing Record 276 | stettler
# Processing Record 277 | batticaloa
# Processing Record 278 | ambilobe
# Processing Record 279 | lisakovsk
# Processing Record 280 | opuwo
# Processing Record 281 | kushiro
# Processing Record 282 | birao
# Processing Record 283 | shubarshi
# City way too small for wx data. Skipping...
# Processing Record 284 | zhezkazgan
# City way too small for wx data. Skipping...
# Processing Record 285 | mount gambier
# Processing Record 286 | whitehorse
# City way too small for wx data. Skipping...
# Processing Record 287 | lima
# Processing Record 288 | juba
# Processing Record 289 | chara
# City way too small for wx data. Skipping...
# City way too small for wx data. Skipping...
# Processing Record 290 | cananeia
# Processing Record 291 | cairns
# Processing Record 292 | stornoway
# City way too small for wx data. Skipping...
# Processing Record 293 | okha
# City way too small for wx data. Skipping...
# Processing Record 294 | majene
# City way too small for wx data. Skipping...
# Processing Record 295 | yabrud
# Processing Record 296 | port lincoln
# Processing Record 297 | ukiah
# City way too small for wx data. Skipping...
# Processing Record 298 | yokadouma
# Processing Record 299 | edd
# Processing Record 300 | dakar
# Processing Record 301 | hamilton
# Processing Record 302 | half moon bay
# Processing Record 303 | nioro
# City way too small for wx data. Skipping...
# Processing Record 304 | abu zabad
# Processing Record 305 | roxana
# City way too small for wx data. Skipping...
# Processing Record 306 | yola
# Processing Record 307 | guerrero negro
# Processing Record 308 | morant bay
# Processing Record 309 | tyrma
# Processing Record 310 | dandong
# Processing Record 311 | rio gallegos
# Processing Record 312 | byron bay
# Processing Record 313 | lebu
# Processing Record 314 | azare
# Processing Record 315 | yeppoon
# Processing Record 316 | lauchhammer
# City way too small for wx data. Skipping...
# Processing Record 317 | karlstad
# City way too small for wx data. Skipping...
# Processing Record 318 | merauke
# Processing Record 319 | sitka
# Processing Record 320 | san andres
# Processing Record 321 | amahai
# Processing Record 322 | wakkanai
# Processing Record 323 | corner brook
# Processing Record 324 | tura
# Processing Record 325 | caceres
# Processing Record 326 | chokwe
# Processing Record 327 | novovarshavka
# City way too small for wx data. Skipping...
# Processing Record 328 | samarai
# Processing Record 329 | igrim
# Processing Record 330 | kavieng
# Processing Record 331 | new iberia
# Processing Record 332 | chupa
# Processing Record 333 | sinnamary
# Processing Record 334 | woodward
# Processing Record 335 | manhuacu
# Processing Record 336 | gravdal
# City way too small for wx data. Skipping...
# Processing Record 337 | kashi
# City way too small for wx data. Skipping...
# Processing Record 338 | puerto madryn
# Processing Record 339 | mayumba
# City way too small for wx data. Skipping...
# Processing Record 340 | tamworth
# Processing Record 341 | ucluelet
# City way too small for wx data. Skipping...
# Processing Record 342 | kuressaare
# Processing Record 343 | joshimath
# City way too small for wx data. Skipping...
# Processing Record 344 | gatesville
# Processing Record 345 | petropavlovsk-kamchatskiy
# City way too small for wx data. Skipping...
# Processing Record 346 | santo antonio do amparo
# City way too small for wx data. Skipping...
# Processing Record 347 | opportunity
# Processing Record 348 | providencia
# Processing Record 349 | san-pedro
# Processing Record 350 | sistranda
# Processing Record 351 | palm coast
# Processing Record 352 | khovu-aksy
# Processing Record 353 | gisors
# Processing Record 354 | kiruna
# Processing Record 355 | vanino
# Processing Record 356 | ballina
# Processing Record 357 | olafsvik
# Processing Record 358 | nouadhibou
# Processing Record 359 | sehore
# Processing Record 360 | vostok
# Processing Record 361 | san pedro
# Processing Record 362 | guadalupe victoria
# Processing Record 363 | saint-pierre
# Processing Record 364 | ossora
# Processing Record 365 | micheweni
# Processing Record 366 | atar
# Processing Record 367 | salcioara
# Processing Record 368 | xining
# Processing Record 369 | claremorris
# Processing Record 370 | hattiesburg
# Processing Record 371 | ganzhou
# Processing Record 372 | cameron park
# Processing Record 373 | ahuimanu
# Processing Record 374 | kahului
# Processing Record 375 | yatou
# Processing Record 376 | vargashi
# Processing Record 377 | kungurtug
# Processing Record 378 | moroto
# Processing Record 379 | santiago de cao
# Processing Record 380 | jawa
# Processing Record 381 | mason city
# Processing Record 382 | praya
# Processing Record 383 | middelburg
# Processing Record 384 | pafos
# Processing Record 385 | keti bandar
# Processing Record 386 | tarrafal
# Processing Record 387 | rancho grande
# Processing Record 388 | athabasca
# Processing Record 389 | saskylakh
# Processing Record 390 | maridi
# Processing Record 391 | marfino
# Processing Record 392 | coxim
# Processing Record 393 | armacao dos buzios
# Processing Record 394 | luderitz
# Processing Record 395 | gannan
# Processing Record 396 | warmbad
# Processing Record 397 | methoni
# Processing Record 398 | san angelo
# City way too small for wx data. Skipping...
# Processing Record 399 | ulaangom
# Processing Record 400 | rio cuarto
# Processing Record 401 | lamu
# Processing Record 402 | hofn
# Processing Record 403 | lorengau
# Processing Record 404 | axim
# Processing Record 405 | maragogi
# Processing Record 406 | bogashevo
# Processing Record 407 | marawi
# Processing Record 408 | visnes
# Processing Record 409 | novy bydzov
# Processing Record 410 | grindavik
# Processing Record 411 | san miguel
# Processing Record 412 | guarapari
# Processing Record 413 | madimba
# Processing Record 414 | akom
# Processing Record 415 | belyy gorodok
# Processing Record 416 | vila velha
# Processing Record 417 | cozumel
# Processing Record 418 | gamba
# Processing Record 419 | sur
# City way too small for wx data. Skipping...
# Processing Record 420 | stroitel
# Processing Record 421 | kirakira
# Processing Record 422 | preobrazheniye
# Processing Record 423 | san patricio
# Processing Record 424 | mangrol
# Processing Record 425 | cefalu
# Processing Record 426 | kamaishi
# Processing Record 427 | genhe
# Processing Record 428 | lake havasu city
# Processing Record 429 | harlingen
# Processing Record 430 | kathmandu
# Processing Record 431 | andros town
# City way too small for wx data. Skipping...
# City way too small for wx data. Skipping...
# Processing Record 432 | abu samrah
# Processing Record 433 | kafue
# Processing Record 434 | noumea
# Processing Record 435 | manjeri
# Processing Record 436 | kamuli
# Processing Record 437 | avera
# Processing Record 438 | vondrozo
# Processing Record 439 | anchorage
# Processing Record 440 | hofu
# Processing Record 441 | jacareacanga
# Processing Record 442 | mitsamiouli
# Processing Record 443 | beidao
# Processing Record 444 | rupert
# Processing Record 445 | queretaro
# Processing Record 446 | antibes
# Processing Record 447 | oda
# Processing Record 448 | cayenne
# Processing Record 449 | angul
# Processing Record 450 | salinopolis
# Processing Record 451 | quirinopolis
# Processing Record 452 | saint-augustin
# Processing Record 453 | guimbal
# Processing Record 454 | vozhega
# Processing Record 455 | chodavaram
# Processing Record 456 | ikalamavony
# Processing Record 457 | hasaki
# Processing Record 458 | makhachkala
# Processing Record 459 | manicore
# Processing Record 460 | kosh-agach
# Processing Record 461 | basco
# Processing Record 462 | tuy hoa
# Processing Record 463 | san nicolas
# Processing Record 464 | rampura
# Processing Record 465 | zlotoryja
# Processing Record 466 | gat
# City way too small for wx data. Skipping...
# Processing Record 467 | sabang
# Processing Record 468 | urumqi
# Processing Record 469 | popondetta
# Processing Record 470 | grand river south east
# Processing Record 471 | tazovskiy
# Processing Record 472 | mosquera
# Processing Record 473 | port hedland
# Processing Record 474 | matara
# Processing Record 475 | turayf
# City way too small for wx data. Skipping...
# Processing Record 476 | catuday
# City way too small for wx data. Skipping...
# Processing Record 477 | kidal
# Processing Record 478 | brae
# Processing Record 479 | araouane
# Processing Record 480 | dongsheng
# Processing Record 481 | santa maria
# Processing Record 482 | zig
# Processing Record 483 | marzuq
# Processing Record 484 | sheridan
# Processing Record 485 | royan
# Processing Record 486 | greytown
# Processing Record 487 | nijar
# Processing Record 488 | high rock
# Processing Record 489 | isangel
# Processing Record 490 | yulara
# Processing Record 491 | kelvington
# Processing Record 492 | adre
# Processing Record 493 | kichera
# Processing Record 494 | coyah
# Processing Record 495 | bandarbeyla
# Processing Record 496 | takab
# Processing Record 497 | kuching
# Processing Record 498 | prince george
# Processing Record 499 | port macquarie
# Processing Record 500 | urayasu
# Processing Record 501 | porto santo
# Processing Record 502 | groningen
# Processing Record 503 | hope
# Processing Record 504 | talnakh
# Processing Record 505 | belmonte
# Processing Record 506 | seymchan
# Processing Record 507 | maicao
# Processing Record 508 | acapulco
# Processing Record 509 | nanortalik
# Processing Record 510 | gimli
# Processing Record 511 | yaan
# Processing Record 512 | redding
# Processing Record 513 | sulangan
# Processing Record 514 | mehamn
# City way too small for wx data. Skipping...
# Processing Record 515 | haines junction
# Processing Record 516 | paris
# Processing Record 517 | vieste
# Processing Record 518 | christchurch
# Processing Record 519 | mogadishu
# Processing Record 520 | macapa
# Processing Record 521 | baracoa
# City way too small for wx data. Skipping...
# City way too small for wx data. Skipping...
# City way too small for wx data. Skipping...
# Processing Record 522 | buluang
# City way too small for wx data. Skipping...
# Processing Record 523 | sayyan
# Processing Record 524 | minab
# Processing Record 525 | hwange
# Processing Record 526 | viedma
# Processing Record 527 | praia
# Processing Record 528 | campestre
# Processing Record 529 | ritterhude
# Processing Record 530 | urdoma
# Processing Record 531 | riberalta
# Processing Record 532 | mandalgovi
# Processing Record 533 | niquelandia
# Processing Record 534 | yenagoa
# City way too small for wx data. Skipping...
# Processing Record 535 | bubaque
# Processing Record 536 | skibbereen
# Processing Record 537 | pitimbu
# Processing Record 538 | dingle
# Processing Record 539 | vershino-darasunskiy
# Processing Record 540 | alyangula
# Processing Record 541 | zhigansk
# Processing Record 542 | qaqortoq

# %%
# Data retrieval verification

print(f"The windspeed information received is: {windspeeds}")
# Out:
# The windspeed information received is: [6.93, 1.43, 4.63, 19.46, 12.75, 18.34, 5.35, 15.08, 7.58, 3.36, 4, 5.68, 4.7, 2.8, 14.99, 1.99, 6.22, 6.64, 21.92, 11.18, 22.46, 12.75, 9.17, 27.18, 5.82, 19.46, 1.74, 5.1, 12.75, 3.36, 11.41, 6.73, 21, 9.04, 3.91, 19.46, 10.29, 6.93, 6.44, 4.47, 3.47, 5.82, 6.93, 15.05, 1.99, 1.68, 14.99, 16.11, 14.99, 5.08, 5.82, 4.7, 10.65, 4.54, 6.93, 6.4, 24.36, 10.29, 2.8, 1.01, 4.7, 16.11, 8.37, 1.99, 9.17, 5.82, 9.17, 14.2, 10.96, 14.99, 3.36, 14.61, 13.87, 10.29, 2.24, 3.15, 6.93, 6.15, 5.3, 4.43, 8.48, 10.29, 17.81, 12.75, 6.93, 13.87, 1.59, 11.41, 6.93, 3.36, 3, 4.88, 8.95, 8.01, 4.36, 5.88, 12.75, 2.57, 11.5, 4.7, 10.29, 6.51, 6.93, 2.8, 9.08, 17.18, 6.4, 9.17, 1.99, 9.17, 2.24, 4.7, 7.67, 5.66, 3.42, 4, 7.99, 8.37, 14.99, 10.29, 3.36, 18.34, 4.7, 1.34, 6.4, 2.84, 5.39, 13.56, 9.17, 12.5, 13.24, 12.86, 11.41, 35.57, 3.36, 21.92, 5.41, 3.36, 20.8, 9.17, 12.59, 17.22, 6.93, 12.75, 8.93, 8.66, 5.17, 8.84, 11.61, 7.74, 4.14, 5.46, 9.17, 4.7, 11.01, 2.8, 12.5, 13.87, 2.82, 2.24, 12.75, 11.12, 1.99, 9.71, 13.11, 3.36, 3.51, 6.17, 12.06, 2.01, 4.7, 1.59, 10.29, 4.7, 10.02, 1.66, 1.99, 10.29, 4.7, 2.08, 7.07, 1.81, 2.24, 8.05, 4.81, 3, 1.66, 3.36, 1.81, 34.45, 8.86, 3.36, 22.1, 8.34, 3.76, 2.24, 4.7, 8.05, 7.61, 5.3, 1.57, 4.7, 8.23, 5.93, 12.75, 5.82, 11.03, 1.01, 7.96, 10.83, 5.93, 4.81, 5.99, 10.29, 5.95, 3.6, 3.91, 2.24, 4.74, 17.94, 5.99, 7, 3.36, 1.07, 11.32, 13.87, 23.31, 16.11, 3.69, 1.03, 11.41, 10.07, 8.75, 4.47, 3.36, 4.83, 5.57, 3.31, 3, 1.01, 10.11, 8.05, 2.82, 3.71, 3.91, 9.57, 23.04, 6.46, 8.05, 6.33, 5.82, 9.53, 9.62, 12.75, 5.46, 5.82, 6.4, 5.84, 6.93, 20.8, 1.61, 12.71, 3.09, 1.36, 2.55, 12.17, 8.03, 9.17, 1.54, 34.45, 12.75, 8.14, 12.75, 5.32, 8.05, 5.82, 11.23, 4.07, 5.93, 17.81, 4.5, 8.7, 4, 1.34, 4.68, 14.99, 8.05, 2.39, 0.76, 6.8, 5.82, 18.34, 7.47, 3.69, 11.41, 2.8, 2.3, 5.59, 9.22, 17.22, 10.29, 6.93, 7.81, 1.57, 13.87, 4.79, 1.45, 25.28, 1.88, 2.68, 12.75, 4.7, 16.8, 7.74, 10.29, 11.41, 6.93, 5.1, 6.93, 8.84, 3.13, 15.97, 3.91, 3.47, 3, 5.68, 5.3, 8.61, 6.87, 3.04, 6.93, 10.13, 7.47, 9.17, 3.15, 14.99, 4.47, 5.82, 10.33, 4.7, 1.99, 16.11, 2.1, 7.52, 11.18, 2.95, 4.7, 5.82, 8.97, 11.41, 2.24, 2.04, 3.36, 17.22, 6.2, 1.12, 21.07, 18.34, 2.24, 5.3, 8.84, 6.93, 21.92, 11.54, 9.44, 16.69, 14.99, 1.21, 10.71, 4.03, 2.42, 5.82, 10.29, 8.05, 4.99, 4.23, 1.59, 19.39, 4.7, 5.17, 6.93, 19.46, 9.19, 5.82, 1.5, 19.46, 1.61, 5.82, 8.63, 4.14, 6.71, 4.76, 13.87, 19.26, 5.14, 13.69, 12.75, 8.84, 2.84, 12.75, 10.29, 19.46, 4.36, 9.22, 13.27, 4.47, 3, 14.99, 1.01, 21.92, 8.84, 11.41, 13.87, 2.86, 9.33, 4, 14.99, 10.76, 11.79, 13.42, 3.24, 5.39, 8.84, 4.88, 10, 5.01, 2.28, 6.93, 4.97, 3.36, 11.01, 1.57, 6.93, 7.31, 1.81, 1.07, 6.93, 5.06, 5.82, 4.7, 5.82, 4.9, 1.63, 4.7, 4.7, 5.82, 5.46, 8.05, 3.38, 13.65, 0.07, 11.81, 6.82, 4.72, 2.24, 6.33, 8.05, 20.13, 1.86, 1.21, 19.77, 2.24, 8.84, 8.28, 7.94, 4.94, 12.66, 2.24, 2.57, 3.36, 11.25, 5.82, 2.8, 7.11, 10.29, 6.46, 6.69, 23.04, 10.65, 11.16, 4.81, 8.05, 8.3, 3.36, 2.24, 8.03, 10.29, 5.21, 10.87, 9.17, 5.82, 10.67, 7.09, 6.26, 23.55, 1.81, 4.7, 2.24, 2.8, 10.29, 8.05, 6.93, 4.7, 6.71, 20.8, 1.72, 13.56, 4.7, 4.5, 5.82, 1.95, 3.85, 2.26, 19.46, 5.82, 5.82, 1.12, 2.24, 17.22, 8.05, 10.96, 4.23, 5.73, 4.7, 1.83, 1.99, 19.46, 1.54, 4.7, 4.97, 13.87, 13.18, 1.01, 5.66, 11.32, 11.41, 4.7, 5.08, 5.5, 6.93, 5.79, 11.41]

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#Create a dataframe to store the data
wx = {"City":citylist,"Lat":lats,"Long":longs,"Cloudiness":cloudiness,"Humidity":humidity,"Max Temp":max_temps,"Wind Speed":windspeeds, "Date":dates,}

weather_df = pd.DataFrame(wx)

# %%
#Preview the dataframe
weather_df.head()
# Out:
#           City    Lat   Long  Cloudiness  Humidity  Max Temp  Wind Speed  \
# 0  new norfolk   6.65 -10.59          75        70     87.80        6.93
# 1       saqqez  36.25  46.27         100        94     31.46        1.43
# 2     teguldet  57.31  88.17         100        91     -5.31        4.63
# 3      salalah  17.02  54.09           0        17     82.40       19.46
# 4  east london  65.00 -15.00          90       100     24.80       12.75
#
#          Date
# 0  1607526407
# 1  1607526592
# 2  1607526592
# 3  1607526592
# 4  1607526593

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
weather_df.sort_values(by=['Humidity'], ascending=False)
# Out:
#             City    Lat    Long  Cloudiness  Humidity  Max Temp  Wind Speed  \
# 515        paris  48.85    2.35          90       100     41.00        5.82
# 142        saran  47.95    1.88          90       100     39.20        6.93
# 186        airai  -8.93  125.41          95       100     63.64        1.66
# 316     karlstad  59.38   13.50          75       100     37.40        6.93
# 4    east london  65.00  -15.00          90       100     24.80       12.75
# ..           ...    ...     ...         ...       ...       ...         ...
# 397   san angelo  13.30   -4.90           1        11     99.19        8.84
# 198        bilma  18.69   12.92          49        11     91.54        7.61
# 236        arlit  18.74    7.39           9        10     93.22        5.57
# 305         yola   9.20   12.48          55         9    101.89        4.79
# 368  claremorris  53.72   -9.00         100         3     46.00       10.71
#
#            Date
# 515  1607526504
# 142  1607526625
# 186  1607526634
# 316  1607526660
# 4    1607526593
# ..          ...
# 397  1607526678
# 198  1607526636
# 236  1607526574
# 305  1607526658
# 368  1607526673
#
# [542 rows x 8 columns]

# %%
#  Get the indices of cities that have humidity over 100%.
weather_df[weather_df['Humidity'] == 100]
# Out:
#              City    Lat    Long  Cloudiness  Humidity  Max Temp  Wind Speed  \
# 4     east london  65.00  -15.00          90       100     24.80       12.75
# 123       terrace  54.52 -128.60          90       100     35.60        1.34
# 142         saran  47.95    1.88          90       100     39.20        6.93
# 167  spirit river  45.45  -90.11           1       100     27.00        6.17
# 186         airai  -8.93  125.41          95       100     63.64        1.66
# 189        torbay  47.67  -52.73          90       100     37.00       34.45
# 265     nishihara  26.18  127.76          90       100     69.80       12.17
# 316      karlstad  59.38   13.50          75       100     37.40        6.93
# 350    palm coast  47.64   16.11         100       100     37.40        2.24
# 380    mason city  39.36  -84.31           1       100     41.00        6.93
# 437      vondrozo -22.82   47.28          94       100     63.14        5.06
# 515         paris  48.85    2.35          90       100     41.00        5.82
# 535    skibbereen  51.55   -9.27          90       100     48.20       11.41
#
#            Date
# 4    1607526593
# 123  1607526371
# 142  1607526625
# 167  1607526630
# 186  1607526634
# 189  1607526338
# 265  1607526649
# 316  1607526660
# 350  1607526669
# 380  1607526675
# 437  1607526686
# 515  1607526504
# 535  1607526705

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.

clean_weather_df = weather_df[weather_df['Humidity'] != 100]
clean_weather_df.sort_values(by=['Humidity'], ascending=False)
# Out:
#             City    Lat   Long  Cloudiness  Humidity  Max Temp  Wind Speed  \
# 140    portobelo   9.55 -79.65          98        99     82.99       12.59
# 176      vimperk  49.06  13.78         100        99     36.00        1.99
# 278    lisakovsk  52.54  62.49         100        98     20.57        5.93
# 80     upernavik  72.79 -56.15         100        97     23.25        8.48
# 384  keti bandar  40.87  43.84          90        97     32.00        1.50
# ..           ...    ...    ...         ...       ...       ...         ...
# 281        birao  10.28  22.79         100        11     94.21        8.70
# 313        azare  11.68  10.19          97        11     96.44        7.74
# 236        arlit  18.74   7.39           9        10     93.22        5.57
# 305         yola   9.20  12.48          55         9    101.89        4.79
# 368  claremorris  53.72  -9.00         100         3     46.00       10.71
#
#            Date
# 140  1607526624
# 176  1607526632
# 278  1607526651
# 80   1607526611
# 384  1607526676
# ..          ...
# 281  1607526652
# 313  1607526659
# 236  1607526574
# 305  1607526658
# 368  1607526673
#
# [529 rows x 8 columns]

# %%
clean_weather_df.sort_values(by=['Max Temp'], ascending=False)
# Out:
#              City    Lat    Long  Cloudiness  Humidity  Max Temp  Wind Speed  \
# 305          yola   9.20   12.48          55         9    101.89        4.79
# 422  san patricio  13.30   -4.90           1        11     99.19        8.84
# 360     san pedro  13.30   -4.90           1        11     99.19        8.84
# 397    san angelo  13.30   -4.90           1        11     99.19        8.84
# 147      san jose  13.30   -4.90           1        11     99.19        8.84
# ..            ...    ...     ...         ...       ...       ...         ...
# 125    chokurdakh  70.63  147.92           9        83    -29.31        2.84
# 171      khandyga  62.67  135.60           0        78    -29.52        1.59
# 229      khatanga  71.97  102.50          64        85    -31.18        1.03
# 216        nyurba  63.28  118.33         100        83    -34.91        3.91
# 540      zhigansk  66.77  123.37          25        82    -35.64        5.79
#
#            Date
# 305  1607526658
# 422  1607526661
# 360  1607526661
# 397  1607526678
# 147  1607526626
# ..          ...
# 125  1607526622
# 171  1607526631
# 229  1607526642
# 216  1607526640
# 540  1607526706
#
# [529 rows x 8 columns]

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# Plotting cities by Lat and Long and visualizing tempertaure by color gave a more useful plot 
#    than latitude and tempertaure alone.

# Extract the data we're interested in
Lat, Long = clean_weather_df['Lat'], clean_weather_df['Long']
temperature = clean_weather_df['Max Temp']

# Scatter the points, using temperature color
plt.scatter(Long, Lat, label=None,
            c=temperature, cmap='rainbow',
            linewidth=0, alpha=0.5)

# Title and Labels
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.colorbar(label='Temperature')
plt.clim(-40, 110)
 
plt.title(f'Latitude vs Temperature (F)  {time.strftime("%m/%d/%Y")}');

# Save the figure
plt.savefig('Latitude vs.Temperature v1.png')

# %%
#'Latitude vs Temperature (F)' utlizes color to show maximum temperature distribution 
#   by Latitude, and, to a lesser degree, by Longitude. As expected the bands are relatively 
#   uniform horizontally with the exception of some longitudes with particularly cooler temperatures.

# %%
# Build a boring, less useful scatter plot 'Latitude vs.Temperature (F)'

t= np.arange(529)  # color scale matched with number of data points
plt.scatter(clean_weather_df['Lat'], clean_weather_df['Max Temp'], s=5, c=t)

# Title and Labels
plt.xlabel('Latitude')
plt.ylabel('Temperature (F)')
plt.title(f'Latitude vs.Temperature (F) {time.strftime("%m/%d/%Y")}')

plt.grid(True)

plt.show()

# Save the figure
plt.savefig('Latitude vs.Temperature v2.png')

# %%
#'Latitude vs Temperature (F)' utlizes color to show maximum temperature distribution 
#   by Latitude. This is a less visually educational plot because all latitudes are 
#   grouped together but the colors do show temperature distribution.

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# Plotting cities by Lat and Long and visualizing humidity by color gave a more useful plot 
#    than latitude and tempertaure alone.
# Two dimensional scatterplot located in regression section.

# Extract the data we're interested in
Lat, Long = clean_weather_df['Lat'], clean_weather_df['Long']
hum = clean_weather_df['Humidity']

# Scatter the points, using Humidity
plt.scatter(Long, Lat, label=None,
            c=hum, cmap='rainbow',
            linewidth=0, alpha=0.5)

plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.colorbar(label='Humidity %')
plt.clim(0, 100)
 
plt.title(f'Latitude vs Humidity %  {time.strftime("%m/%d/%Y")}');

# Save the figure
plt.savefig('Latitude vs.Humidity.png')

# %%
#'Latitude vs Humidity %' utlizes color to show humidity % distribution 
#   by Latitude, and, to a lesser degree, by Longitude. The plot visually
#   confers that humidity is not determined by latitude alone...longitude
#   plays an important role in the humidity a city will experience.

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# Plotting cities by Lat and Long and visualizing cloudiness by color gave a more useful plot 
#    than latitude and tempertaure alone.
# Two dimensional scatterplot located in regression section.

# Extract the data we're interested in
Lat, Long = clean_weather_df['Lat'], clean_weather_df['Long']
cloud = clean_weather_df['Cloudiness']

# Scatter the points, using Cloudiness
plt.scatter(Long, Lat, label=None,
            c=cloud, cmap='binary',
            linewidth=0, alpha=0.5)

plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.colorbar(label='Cloudiness %')
plt.clim(0, 100)
 
plt.title(f'Latitude vs Cloudiness %  {time.strftime("%m/%d/%Y")}');

# Save the figure
plt.savefig('Latitude vs.Cloudiness.png')

# %%
#'Latitude vs Cloudiness %' utlizes color to show cloudiness % distribution 
#   by Latitude, and, to a lesser degree, by Longitude. The plot visually
#   confers that cloudiness is not primarily determined by latitude...longitude
#   appears to be the primary determinant of cloudiness.

# %%
clean_weather_df.sort_values(by=['Wind Speed'], ascending=False)
# Out:
#                City    Lat    Long  Cloudiness  Humidity  Max Temp  \
# 133           vardo  70.37   31.11          75        80     33.80
# 269       batsfjord  70.63   29.72          75        92     30.20
# 23        ostrovnoy  68.05   39.51           8        94     24.91
# 307      morant bay  17.90  -76.43          75        74     78.80
# 56   severo-kurilsk  50.68  156.12          88        87     26.11
# ..              ...    ...     ...         ...       ...       ...
# 532     niquelandia -14.47  -48.46         100        65     83.17
# 207         fortuna  40.60 -124.16         100        97     51.01
# 239        flinders -34.58  150.86          67        76     63.00
# 288           chara  56.91  118.26         100        76     -3.59
# 450    quirinopolis -18.45  -50.45           3        43     92.44
#
#      Wind Speed        Date
# 133       35.57  1607526623
# 269       34.45  1607526650
# 23        27.18  1607526596
# 307       25.28  1607526658
# 56        24.36  1607526604
# ..          ...         ...
# 532        1.01  1607526704
# 207        1.01  1607526638
# 239        1.01  1607526644
# 288        0.76  1607526654
# 450        0.07  1607526688
#
# [529 rows x 8 columns]

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# Plotting cities by Lat and Long and visualizing wind speed by color gave a more useful plot 
#    than latitude and tempertaure alone.
# Two dimensional scatterplot located in regression section.

# Extract the data we're interested in
Lat, Long = clean_weather_df['Lat'], clean_weather_df['Long']
wind = clean_weather_df['Wind Speed']

# Scatter the points, using temperature color
plt.scatter(Long, Lat, label=None,
            c=wind, cmap='Blues',
            linewidth=0, alpha=0.5)

plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.colorbar(label='Wind Speed (mph)')
plt.clim(0, 40)
 
plt.title(f'Latitude vs Wind Speed (mph) {time.strftime("%m/%d/%Y")}');

# Save the figure
plt.savefig('Latitude vs.Wind Speed.png')

# %%
#'Latitude vs Wind Speed' utlizes color to show wind speed distribution 
#   by Latitude, and, to a lesser degree, by Longitude. The plot visually
#   confers that wind speed is greater at the subtropical jets and indicated
#   by darker blue colors.

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Dataframe for Northern Hemisphere cities
northtemp_df = weather_df[weather_df['Lat'] >= 0]
northtemp_df.sort_values(by=['Lat'])
# Out:
#              City    Lat    Long  Cloudiness  Humidity  Max Temp  Wind Speed  \
# 519        macapa   0.04  -51.07          90        83     80.60        8.05
# 435        kamuli   0.95   33.12          94        52     79.00        1.07
# 496       kuching   1.55  110.33          20        94     78.80        4.70
# 518     mogadishu   2.04   45.34          20        54     84.20       17.22
# 377        moroto   2.53   34.67          29        35     78.37       19.39
# ..            ...    ...     ...         ...       ...       ...         ...
# 229      khatanga  71.97  102.50          64        85    -31.18        1.03
# 80      upernavik  72.79  -56.15         100        97     23.25        8.48
# 251        dikson  73.51   80.55          89        88     -9.00        9.53
# 97        qaanaaq  77.48  -69.36         100        85      0.70        2.57
# 72   longyearbyen  78.22   15.64          75        74     28.40       13.87
#
#            Date
# 519  1607526701
# 435  1607526685
# 496  1607526514
# 518  1607526701
# 377  1607526674
# ..          ...
# 229  1607526642
# 80   1607526611
# 251  1607526646
# 97   1607526616
# 72   1607526609
#
# [394 rows x 8 columns]

# %%
# Northern Hemisphere - Max Temp vs. Latitude Linear Regression
t= np.arange(394)  # Color scale matched with number of data points
plt.scatter(northtemp_df['Lat'], northtemp_df['Max Temp'], s=5, c=t)

# Title and Labels
plt.xlabel('Latitude')
plt.ylabel('Temperature (F)')
plt.title(f'Northern Latitudes vs.Temperature (F) {time.strftime("%m/%d/%Y")}')

plt.grid(True)

# Print out the r-squared value along with the plot.
print(f"The r-squared is: {rvalue**2}")

# Regression Line
x_values = northtemp_df['Lat']
y_values = northtemp_df['Max Temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(0,0),fontsize=15,color="darkblue")

plt.show()

# Save the figure
plt.savefig('North Latitude vs.Temperature Reg.png')
# Out:
# The r-squared is: 0.012656128840767234

# %%
# For every unit of change in latitude the temperature drops -1.31 units. 
# Approximately 73% of the data fit into the model.

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Dataframe for Southern Hemisphere cities
south_df = weather_df[weather_df['Lat'] <= 0]
south_df.sort_values(by=['Lat'])
# Out:
#                         City    Lat    Long  Cloudiness  Humidity  Max Temp  \
# 46                   ushuaia -54.80  -68.30          75        66     53.60
# 52                     bluff -46.60  168.33          51        87     53.15
# 162               kaitangata -46.28  169.85          35        77     57.00
# 86                   mataura -46.19  168.86          20        86     45.68
# 114                tuatapere -46.13  167.68          28        89     49.33
# ..                       ...    ...     ...         ...       ...       ...
# 449              salinopolis  -0.61  -47.36          91        65     85.35
# 106                hithadhoo  -0.60   73.08          43        68     82.42
# 345  santo antonio do amparo  -0.59  -80.00         100        79     78.89
# 200                   japura  -0.32  102.35          57        93     74.95
# 17                 pontianak  -0.03  109.33          88        89     78.01
#
#      Wind Speed        Date
# 46        14.99  1607526458
# 52        10.65  1607526603
# 162        1.99  1607526629
# 86         1.59  1607526613
# 114        3.42  1607526619
# ..          ...         ...
# 449       13.65  1607526688
# 106        6.40  1607526618
# 345        2.95  1607526668
# 200        1.57  1607526637
# 17         6.64  1607526595
#
# [148 rows x 8 columns]

# %%
# Southern Hemisphere - Max Temp vs. Latitude Linear Regression
t= np.arange(148)  # Color scale matched with number of data points
plt.scatter(south_df['Lat'], south_df['Max Temp'], s=5, c=t)

# Title and Labels
plt.xlabel('Latitude')
plt.ylabel('Temperature (F)')
plt.title(f'Southern Latitudes vs.Temperature (F) {time.strftime("%m/%d/%Y")}')

plt.grid(True)

# Print out the r-squared value along with the plot.
print(f"The r-squared is: {rvalue**2}")

# Regression Line
x_values = south_df['Lat']
y_values = south_df['Max Temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-27,55),fontsize=15,color="darkblue")

plt.show()

# Save the figure
plt.savefig('South Latitude vs.Temperature Reg.png')
# Out:
# The r-squared is: 0.734970007803583

# %%
# For every unit of change in latitude the temperature rises by a half unit. 
# Approximately 40% of the data fit into the model.
# The implication is that the southern hemisphere model is not as predictive
#  as the northern model had.

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Northern Hemisphere - Humidity vs. Latitude Linear Regression
t= np.arange(394)  # Color scale matched with number of data points
plt.scatter(northtemp_df['Lat'], northtemp_df['Humidity'], s=5, c=t)

# Title and Labels
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.title(f'Northern Latitudes vs.Humidity {time.strftime("%m/%d/%Y")}')

plt.grid(True)

# Print out the r-squared value along with the plot.
print(f"The r-squared is: {rvalue**2}")

# Regression Line
x_values = northtemp_df['Lat']
y_values = northtemp_df['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(40,20),fontsize=15,color="darkblue")

plt.show()

# Save the figure
plt.savefig('North Latitude vs.Humidity Reg.png')
# Out:
# The r-squared is: 0.4044205869465541

# %%
# For every unit of change in latitude the humidity rises by a half unit. 
# Approximately 24% of the data fit into the model.
# The implication is that the model offers poor predicatability of results.
# Visually this is observed in the wide scatter of datapoints.

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Southern Hemisphere - Humidity vs. Latitude Linear Regression
t= np.arange(148)  # Color scale matched with number of data points
plt.scatter(south_df['Lat'], south_df['Humidity'], s=5, c=t)

# Title and Labels
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title(f'Southern Latitudes vs.Humidity (%) {time.strftime("%m/%d/%Y")}')

plt.grid(True)

# Print out the r-squared value along with the plot.
print(f"The r-squared is: {rvalue**2}")

# Regression Line
x_values = south_df['Lat']
y_values = south_df['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-55,22),fontsize=15,color="darkblue")

plt.show()

# Save the figure
plt.savefig('South Latitude vs.Humidity Reg.png')
# Out:
# The r-squared is: 0.23969109962380888

# %%
# For every unit of change in latitude the humidity rises by a 1/5 unit. 
# Approximately 1% of the data fit into the model.
# The implication is that the model offers poor predicatability of results.
# Visually this is observed in the wide scatter of datapoints, eg high variance.

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Northern Hemisphere - Cloudiness vs. Latitude Linear Regression
t= np.arange(394)  # Color scale matched with number of data points
plt.scatter(northtemp_df['Lat'], northtemp_df['Cloudiness'], s=5, c=t)

# Title and Labels
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.title(f'Northern Latitudes vs.Cloudiness {time.strftime("%m/%d/%Y")}')

plt.grid(True)

# Print out the r-squared value along with the plot.
print(f"The r-squared is: {rvalue**2}")

# Regression Line
x_values = northtemp_df['Lat']
y_values = northtemp_df['Cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(45,40),fontsize=15,color="darkblue")

plt.show()

# Save the figure
plt.savefig('North Latitude vs.Cloudiness Reg.png')
# Out:
# The r-squared is: 0.012656128840767234

# %%
# For every unit of change in latitude the cloudiness rises by a 1/3 unit. 
# Approximately 3% of the data fit into the model.
# The implication is that the model offers poor predicatability of results.
# Visually this is observed in the wide scatter of datapoints, eg high 
#    variance, with large distributions at the extreme ends of the y-axis.

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression
t= np.arange(148)  # Color scale matched with number of data points
plt.scatter(south_df['Lat'], south_df['Cloudiness'], s=5, c=t)

# Title and Labels
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title(f'Southern Latitudes vs.Cloudiness (%) {time.strftime("%m/%d/%Y")}')

plt.grid(True)

# Print out the r-squared value along with the plot.
print(f"The r-squared is: {rvalue**2}")

# Regression Line
x_values = south_df['Lat']
y_values = south_df['Cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-55,54),fontsize=15,color="darkblue")

plt.show()

# Save the figure
plt.savefig('South Latitude vs.Cloudiness Reg.png')
# Out:
# The r-squared is: 0.03052626584658477

# %%
# For every unit of change in latitude the cloudiness rises by a one unit. 
# Approximately 13% of the data fit into the model.
# The implication is that the model offers poor predicatability of results.
# Visually this is observed in the wide scatter of datapoints, eg high 
#    variance, with relatively large distributions at the extreme ends of the y-axis.

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Northern Hemisphere - Wind Speed vs. Latitude Linear Regression
t= np.arange(394)  # Color scale matched with number of data points
plt.scatter(northtemp_df['Lat'], northtemp_df['Wind Speed'], s=5, c=t)

# Title and Labels
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title(f'Northern Latitudes vs.Wind Speed (mph) {time.strftime("%m/%d/%Y")}')

plt.grid(True)

# Print out the r-squared value along with the plot.
print(f"The r-squared is: {rvalue**2}")

# Regression Line
x_values = northtemp_df['Lat']
y_values = northtemp_df['Wind Speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(5,30),fontsize=15,color="darkblue")

plt.show()

# Save the figure
plt.savefig('North Latitude vs.Wind Speed Reg.png')
# Out:
# The r-squared is: 0.13246989252632457

# %%
# For every unit of change in latitude the wind speed rises by almost zero...a nearly flat line. 
# Approximately 4% of the data fit into the model.
# The implication is that the model offers poor predicatability of results.
# Visually this is observed in the wide scatter of datapoints, eg high 
#    variance.

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
t= np.arange(148)  # Color scale matched with number of data points
plt.scatter(south_df['Lat'], south_df['Wind Speed'], s=5, c=t)

# Title and Labels
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title(f'Southern Latitudes vs.Wind Speed (mph) {time.strftime("%m/%d/%Y")}')

plt.grid(True)

# Print out the r-squared value along with the plot.
print(f"The r-squared is: {rvalue**2}")

# Regression Line
x_values = south_df['Lat']
y_values = south_df['Wind Speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-55,13),fontsize=15,color="darkblue")

plt.show()

# Save the figure
plt.savefig('South Latitude vs.Wind Speed Reg.png')
# Out:
# The r-squared is: 0.001524934302389643

# %%
# For every unit of change in latitude the wind speed declines by a tenth of a unit. 
# Approximately 4% of the data fit into the model.
# The implication is that the model offers poor predicatability of results.
# Visually this is observed in the wide scatter of datapoints, eg high 
#    variance.
