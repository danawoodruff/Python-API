# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 604

# %%
print(cities)
# Out:
# ['rikitea', 'ahuimanu', 'sechura', 'boa vista', 'amderma', 'asau', 'stromness', 'kamenskoye', 'kaitangata', 'ushuaia', 'olafsvik', 'washougal', 'punta arenas', 'chifeng', 'sorvag', 'new norfolk', 'puerto ayora', 'buala', 'kruisfontein', 'harsud', 'lompoc', 'attawapiskat', 'tsihombe', 'viligili', 'chatra', 'russell', 'arraial do cabo', 'fortuna', 'bluff', 'damietta', 'nizhneyansk', 'naifaru', 'mehamn', 'nouadhibou', 'ust-ilimsk', 'kapaa', 'novi troyany', 'tir pol', 'bredasdorp', 'mahebourg', 'sorong', 'dong xoai', 'mataura', 'hermanus', 'salalah', 'ojinaga', 'torbay', 'bengkulu', 'rubtsovsk', 'taolanaro', 'chuy', 'ekhabi', 'manokwari', 'west wendover', 'joao pinheiro', 'gat', 'forbes', 'sao filipe', 'srednekolymsk', 'hilo', 'vaini', 'synya', 'tuktoyaktuk', 'longyearbyen', 'lockport', 'honningsvag', 'jamestown', 'uvat', 'rorvik', 'pevek', 'santander jimenez', 'cairns', 'bumba', 'pisco', 'tumannyy', 'omboue', 'busselton', 'akot', 'ranau', 'iqaluit', 'hami', 'luderitz', 'saint anthony', 'chernyshevskiy', 'sentyabrskiy', 'aasiaat', 'port alfred', 'havre-saint-pierre', 'illoqqortoormiut', 'east london', 'vokhma', 'ribeira grande', 'palana', 'gayeri', 'traralgon', 'port blair', 'dingle', 'jertih', 'bathsheba', 'bonthe', 'mar del plata', 'tiksi', 'margate', 'barrow', 'albany', 'sungaipenuh', 'narayanganj', 'bousso', 'airai', 'fallon', 'mackenzie', 'ostrovnoy', 'san cristobal', 'churapcha', 'axim', 'karlskrona', 'beyneu', 'carnarvon', 'fort nelson', 'diego de almagro', 'grindavik', 'bethel', 'novyy urengoy', 'atuona', 'turukhansk', 'geraldton', 'saint-francois', 'matane', 'doctor pedro p. pena', 'rockhampton', 'cape town', 'mao', 'victoria', 'dikson', 'kununurra', 'bastia', 'tenenkou', 'jalingo', 'barentsburg', 'thompson', 'georgetown', 'pahrump', 'khatanga', 'tasiilaq', 'dunedin', 'sawakin', 'jintur', 'freeport', 'taikang', 'diu', 'eucaliptus', 'harper', 'ipixuna', 'el cope', 'mandera', 'ilulissat', 'namatanai', 'clyde river', 'laguna', 'sur', 'port lincoln', 'itarema', 'oussouye', 'borba', 'auki', 'liverpool', 'ust-nera', 'caravelas', 'pleasanton', 'san patricio', 'hobyo', 'kemijarvi', 'yellowknife', 'turan', 'hithadhoo', 'chagda', 'cidreira', 'aklavik', 'robertsport', 'quelimane', 'nushki', 'aksarka', 'ponta do sol', 'husavik', 'paita', 'fort myers beach', 'lebu', 'caucaia', 'faanui', 'klaksvik', 'tessalit', 'kavieng', 'grand centre', 'moanda', 'cervo', 'belushya guba', 'nikolskoye', 'narsaq', 'dibrugarh', 'batemans bay', 'kyren', 'ruatoria', 'griffith', 'mayor pablo lagerenza', 'talnakh', 'bradford', 'san rafael', 'san quintin', 'innisfail', 'sitka', 'leningradskiy', 'tausa', 'savannah bight', 'kodiak', 'fort frances', 'tucupita', 'beloha', 'nanortalik', 'hobart', 'waingapu', 'saalfelden', 'varnavino', 'katsuura', 'lavrentiya', 'ornskoldsvik', 'zhezkazgan', 'provideniya', 'butaritari', 'mayo', 'shingu', 'poum', 'ahipara', 'guamuchil', 'moron', 'banda aceh', 'mys shmidta', 'bambous virieux', 'luanda', 'darhan', 'skalistyy', 'cabo san lucas', 'castro', 'anori', 'port elizabeth', 'flinders', 'alice springs', 'bermeo', 'mandali', 'severo-kurilsk', 'xuanhua', 'lagoa', 'te anau', 'birao', 'dali', 'hukuntsi', 'husum', 'lorengau', 'munster', 'nyurba', 'cherskiy', 'fatwa', 'mount isa', 'port hedland', 'saint george', 'antofagasta', 'bubaque', 'tautira', 'temaraia', 'mana', 'toliary', 'isangel', 'hasaki', 'chokurdakh', 'inirida', 'sibu', 'mandalgovi', 'genteng', 'boca do acre', 'piacabucu', 'saint-philippe', 'rosetta', 'karacabey', 'vila', 'bilibino', 'avarua', 'rio gallegos', 'kudahuvadhoo', 'ayagoz', 'qarchak', 'whitehorse', 'arklow', 'grand river south east', 'veraval', 'santa cruz de tenerife', 'cam ranh', 'santa cruz', 'jieshi', 'nyazepetrovsk', 'durant', 'portland', 'shimoda', 'ambunti', 'pochutla', 'port-gentil', 'amga', 'egvekinot', 'basco', 'burmakino', 'ketchikan', 'rio verde de mato grosso', 'sao jose da coroa grande', 'tchibanga', 'blackburn', 'lasa', 'codrington', 'bangangte', 'hit', 'vestmannaeyjar', 'qaanaaq', 'yura', 'bilma', ...

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
import json
import requests

from api_keys import weather_api_key
from urllib.error import HTTPError
#weather_api_key = a48e24767ec9494ca8be13ca3d87fa76

# Build query URL
query_url = f"http://api.openweathermap.org/data/2.5/weather?appid="+ weather_api_key +"&units=imperial&q="

# Lists for the dataframe
citylist = []
cloudiness = []
dates = []
humidity = []
lats = []
longs = []
max_temps = []
windspeeds = []
countries = []

# Initial counters
counter = 0

# Loop for calling data city by city
for city in cities:
    try:
        response = requests.get(query_url + city.replace(" ","&")).json()
        cloudiness.append(response['clouds']['all'])
        dates.append(response['dt'])
        humidity.append(response['main']['humidity'])
        lats.append(response['coord']['lat'])
        longs.append(response['coord']['lon'])
        max_temps.append(response['main']['temp_max'])
        windspeeds.append(response['wind']['speed'])
        countries.append(response['sys']['country'])
        citylist.append(city)
        counter = counter + 1   
        
        print(f"Processing Record {counter} | {city}")
    except Exception:
        print("City way too small for wx data. Skipping...")
# Out:
# Processing Record 1 | rikitea
# Processing Record 2 | ahuimanu
# Processing Record 3 | sechura
# Processing Record 4 | boa vista
# City way too small for wx data. Skipping...
# Processing Record 5 | asau
# Processing Record 6 | stromness
# City way too small for wx data. Skipping...
# Processing Record 7 | kaitangata
# Processing Record 8 | ushuaia
# Processing Record 9 | olafsvik
# Processing Record 10 | washougal
# Processing Record 11 | punta arenas
# Processing Record 12 | chifeng
# City way too small for wx data. Skipping...
# Processing Record 13 | new norfolk
# Processing Record 14 | puerto ayora
# Processing Record 15 | buala
# Processing Record 16 | kruisfontein
# Processing Record 17 | harsud
# Processing Record 18 | lompoc
# City way too small for wx data. Skipping...
# City way too small for wx data. Skipping...
# City way too small for wx data. Skipping...
# Processing Record 19 | chatra
# Processing Record 20 | russell
# Processing Record 21 | arraial do cabo
# Processing Record 22 | fortuna
# Processing Record 23 | bluff
# Processing Record 24 | damietta
# City way too small for wx data. Skipping...
# Processing Record 25 | naifaru
# Processing Record 26 | mehamn
# Processing Record 27 | nouadhibou
# Processing Record 28 | ust-ilimsk
# Processing Record 29 | kapaa
# Processing Record 30 | novi troyany
# Processing Record 31 | tir pol
# Processing Record 32 | bredasdorp
# Processing Record 33 | mahebourg
# Processing Record 34 | sorong
# Processing Record 35 | dong xoai
# Processing Record 36 | mataura
# Processing Record 37 | hermanus
# Processing Record 38 | salalah
# Processing Record 39 | ojinaga
# Processing Record 40 | torbay
# Processing Record 41 | bengkulu
# Processing Record 42 | rubtsovsk
# City way too small for wx data. Skipping...
# Processing Record 43 | chuy
# Processing Record 44 | ekhabi
# Processing Record 45 | manokwari
# Processing Record 46 | west wendover
# City way too small for wx data. Skipping...
# Processing Record 47 | gat
# Processing Record 48 | forbes
# Processing Record 49 | sao filipe
# Processing Record 50 | srednekolymsk
# Processing Record 51 | hilo
# Processing Record 52 | vaini
# Processing Record 53 | synya
# Processing Record 54 | tuktoyaktuk
# Processing Record 55 | longyearbyen
# Processing Record 56 | lockport
# Processing Record 57 | honningsvag
# Processing Record 58 | jamestown
# Processing Record 59 | uvat
# Processing Record 60 | rorvik
# Processing Record 61 | pevek
# Processing Record 62 | santander jimenez
# Processing Record 63 | cairns
# Processing Record 64 | bumba
# Processing Record 65 | pisco
# City way too small for wx data. Skipping...
# Processing Record 66 | omboue
# Processing Record 67 | busselton
# Processing Record 68 | akot
# Processing Record 69 | ranau
# Processing Record 70 | iqaluit
# Processing Record 71 | hami
# Processing Record 72 | luderitz
# City way too small for wx data. Skipping...
# Processing Record 73 | chernyshevskiy
# City way too small for wx data. Skipping...
# Processing Record 74 | aasiaat
# Processing Record 75 | port alfred
# Processing Record 76 | havre-saint-pierre
# City way too small for wx data. Skipping...
# Processing Record 77 | east london
# Processing Record 78 | vokhma
# Processing Record 79 | ribeira grande
# Processing Record 80 | palana
# Processing Record 81 | gayeri
# Processing Record 82 | traralgon
# Processing Record 83 | port blair
# Processing Record 84 | dingle
# Processing Record 85 | jertih
# Processing Record 86 | bathsheba
# Processing Record 87 | bonthe
# Processing Record 88 | mar del plata
# Processing Record 89 | tiksi
# Processing Record 90 | margate
# Processing Record 91 | barrow
# Processing Record 92 | albany
# Processing Record 93 | sungaipenuh
# Processing Record 94 | narayanganj
# Processing Record 95 | bousso
# Processing Record 96 | airai
# Processing Record 97 | fallon
# Processing Record 98 | mackenzie
# Processing Record 99 | ostrovnoy
# Processing Record 100 | san cristobal
# Processing Record 101 | churapcha
# Processing Record 102 | axim
# Processing Record 103 | karlskrona
# Processing Record 104 | beyneu
# Processing Record 105 | carnarvon
# Processing Record 106 | fort nelson
# City way too small for wx data. Skipping...
# Processing Record 107 | grindavik
# Processing Record 108 | bethel
# Processing Record 109 | novyy urengoy
# Processing Record 110 | atuona
# Processing Record 111 | turukhansk
# Processing Record 112 | geraldton
# Processing Record 113 | saint-francois
# Processing Record 114 | matane
# City way too small for wx data. Skipping...
# Processing Record 115 | rockhampton
# Processing Record 116 | cape town
# Processing Record 117 | mao
# Processing Record 118 | victoria
# Processing Record 119 | dikson
# Processing Record 120 | kununurra
# Processing Record 121 | bastia
# Processing Record 122 | tenenkou
# Processing Record 123 | jalingo
# City way too small for wx data. Skipping...
# Processing Record 124 | thompson
# Processing Record 125 | georgetown
# Processing Record 126 | pahrump
# Processing Record 127 | khatanga
# Processing Record 128 | tasiilaq
# Processing Record 129 | dunedin
# Processing Record 130 | sawakin
# Processing Record 131 | jintur
# Processing Record 132 | freeport
# Processing Record 133 | taikang
# Processing Record 134 | diu
# Processing Record 135 | eucaliptus
# Processing Record 136 | harper
# Processing Record 137 | ipixuna
# City way too small for wx data. Skipping...
# Processing Record 138 | mandera
# Processing Record 139 | ilulissat
# Processing Record 140 | namatanai
# Processing Record 141 | clyde river
# Processing Record 142 | laguna
# Processing Record 143 | sur
# Processing Record 144 | port lincoln
# Processing Record 145 | itarema
# Processing Record 146 | oussouye
# Processing Record 147 | borba
# Processing Record 148 | auki
# Processing Record 149 | liverpool
# Processing Record 150 | ust-nera
# Processing Record 151 | caravelas
# Processing Record 152 | pleasanton
# Processing Record 153 | san patricio
# Processing Record 154 | hobyo
# Processing Record 155 | kemijarvi
# Processing Record 156 | yellowknife
# Processing Record 157 | turan
# Processing Record 158 | hithadhoo
# City way too small for wx data. Skipping...
# Processing Record 159 | cidreira
# Processing Record 160 | aklavik
# Processing Record 161 | robertsport
# Processing Record 162 | quelimane
# Processing Record 163 | nushki
# Processing Record 164 | aksarka
# Processing Record 165 | ponta do sol
# Processing Record 166 | husavik
# Processing Record 167 | paita
# Processing Record 168 | fort myers beach
# Processing Record 169 | lebu
# Processing Record 170 | caucaia
# Processing Record 171 | faanui
# Processing Record 172 | klaksvik
# Processing Record 173 | tessalit
# Processing Record 174 | kavieng
# Processing Record 175 | grand centre
# Processing Record 176 | moanda
# Processing Record 177 | cervo
# City way too small for wx data. Skipping...
# Processing Record 178 | nikolskoye
# Processing Record 179 | narsaq
# Processing Record 180 | dibrugarh
# City way too small for wx data. Skipping...
# Processing Record 181 | kyren
# City way too small for wx data. Skipping...
# Processing Record 182 | griffith
# City way too small for wx data. Skipping...
# Processing Record 183 | talnakh
# Processing Record 184 | bradford
# Processing Record 185 | san rafael
# Processing Record 186 | san quintin
# Processing Record 187 | innisfail
# Processing Record 188 | sitka
# Processing Record 189 | leningradskiy
# Processing Record 190 | tausa
# Processing Record 191 | savannah bight
# Processing Record 192 | kodiak
# Processing Record 193 | fort frances
# Processing Record 194 | tucupita
# Processing Record 195 | beloha
# Processing Record 196 | nanortalik
# Processing Record 197 | hobart
# Processing Record 198 | waingapu
# City way too small for wx data. Skipping...
# Processing Record 199 | varnavino
# Processing Record 200 | katsuura
# Processing Record 201 | lavrentiya
# Processing Record 202 | ornskoldsvik
# Processing Record 203 | zhezkazgan
# Processing Record 204 | provideniya
# Processing Record 205 | butaritari
# Processing Record 206 | mayo
# Processing Record 207 | shingu
# Processing Record 208 | poum
# Processing Record 209 | ahipara
# Processing Record 210 | guamuchil
# Processing Record 211 | moron
# Processing Record 212 | banda aceh
# Processing Record 213 | mys shmidta
# Processing Record 214 | bambous virieux
# Processing Record 215 | luanda
# Processing Record 216 | darhan
# City way too small for wx data. Skipping...
# Processing Record 217 | cabo san lucas
# Processing Record 218 | castro
# Processing Record 219 | anori
# Processing Record 220 | port elizabeth
# Processing Record 221 | flinders
# Processing Record 222 | alice springs
# Processing Record 223 | bermeo
# Processing Record 224 | mandali
# Processing Record 225 | severo-kurilsk
# Processing Record 226 | xuanhua
# Processing Record 227 | lagoa
# City way too small for wx data. Skipping...
# Processing Record 228 | birao
# Processing Record 229 | dali
# Processing Record 230 | hukuntsi
# Processing Record 231 | husum
# Processing Record 232 | lorengau
# Processing Record 233 | munster
# Processing Record 234 | nyurba
# Processing Record 235 | cherskiy
# Processing Record 236 | fatwa
# Processing Record 237 | mount isa
# Processing Record 238 | port hedland
# City way too small for wx data. Skipping...
# Processing Record 239 | antofagasta
# Processing Record 240 | bubaque
# Processing Record 241 | tautira
# City way too small for wx data. Skipping...
# Processing Record 242 | mana
# City way too small for wx data. Skipping...
# Processing Record 243 | isangel
# Processing Record 244 | hasaki
# Processing Record 245 | chokurdakh
# Processing Record 246 | inirida
# Processing Record 247 | sibu
# Processing Record 248 | mandalgovi
# Processing Record 249 | genteng
# Processing Record 250 | boca do acre
# Processing Record 251 | piacabucu
# Processing Record 252 | saint-philippe
# Processing Record 253 | rosetta
# Processing Record 254 | karacabey
# Processing Record 255 | vila
# Processing Record 256 | bilibino
# Processing Record 257 | avarua
# Processing Record 258 | rio gallegos
# Processing Record 259 | kudahuvadhoo
# Processing Record 260 | ayagoz
# Processing Record 261 | qarchak
# Processing Record 262 | whitehorse
# Processing Record 263 | arklow
# Processing Record 264 | grand river south east
# Processing Record 265 | veraval
# Processing Record 266 | santa cruz de tenerife
# Processing Record 267 | cam ranh
# Processing Record 268 | santa cruz
# Processing Record 269 | jieshi
# Processing Record 270 | nyazepetrovsk
# Processing Record 271 | durant
# Processing Record 272 | portland
# Processing Record 273 | shimoda
# Processing Record 274 | ambunti
# Processing Record 275 | pochutla
# Processing Record 276 | port-gentil
# Processing Record 277 | amga
# Processing Record 278 | egvekinot
# Processing Record 279 | basco
# Processing Record 280 | burmakino
# Processing Record 281 | ketchikan
# Processing Record 282 | rio verde de mato grosso
# Processing Record 283 | sao jose da coroa grande
# Processing Record 284 | tchibanga
# Processing Record 285 | blackburn
# Processing Record 286 | lasa
# Processing Record 287 | codrington
# Processing Record 288 | bangangte
# Processing Record 289 | hit
# Processing Record 290 | vestmannaeyjar
# Processing Record 291 | qaanaaq
# Processing Record 292 | yura
# Processing Record 293 | bilma
# Processing Record 294 | ilhabela
# Processing Record 295 | kapoeta
# Processing Record 296 | mount gambier
# Processing Record 297 | bulungu
# Processing Record 298 | tabuk
# Processing Record 299 | gesztely
# Processing Record 300 | barguzin
# Processing Record 301 | kargopol
# Processing Record 302 | hernani
# Processing Record 303 | komsomolskiy
# Processing Record 304 | noumea
# Processing Record 305 | luba
# Processing Record 306 | anadyr
# Processing Record 307 | goderich
# City way too small for wx data. Skipping...
# Processing Record 308 | belyy yar
# Processing Record 309 | beausejour
# Processing Record 310 | tazovskiy
# Processing Record 311 | tiznit
# Processing Record 312 | sao felipe
# Processing Record 313 | puerto del rosario
# Processing Record 314 | maryville
# Processing Record 315 | kahului
# Processing Record 316 | katangli
# Processing Record 317 | fereydunshahr
# Processing Record 318 | upernavik
# City way too small for wx data. Skipping...
# Processing Record 319 | sorland
# Processing Record 320 | khuzhir
# Processing Record 321 | lubbock
# City way too small for wx data. Skipping...
# Processing Record 322 | richards bay
# Processing Record 323 | stepnogorsk
# Processing Record 324 | marsh harbour
# Processing Record 325 | imbituba
# Processing Record 326 | yamada
# Processing Record 327 | namibe
# Processing Record 328 | urumqi
# City way too small for wx data. Skipping...
# Processing Record 329 | juquia
# Processing Record 330 | shevchenkove
# Processing Record 331 | kaeo
# Processing Record 332 | port macquarie
# Processing Record 333 | vanimo
# Processing Record 334 | hambantota
# Processing Record 335 | guerrero negro
# Processing Record 336 | aden
# Processing Record 337 | carballo
# Processing Record 338 | puerto baquerizo moreno
# Processing Record 339 | burley
# Processing Record 340 | plymouth
# Processing Record 341 | rundu
# Processing Record 342 | zyryanka
# Processing Record 343 | changqing
# Processing Record 344 | hun
# City way too small for wx data. Skipping...
# Processing Record 345 | yerbogachen
# Processing Record 346 | chapais
# Processing Record 347 | balarampur
# Processing Record 348 | biak
# City way too small for wx data. Skipping...
# Processing Record 349 | mufulira
# Processing Record 350 | morgan city
# Processing Record 351 | manakara
# Processing Record 352 | cap malheureux
# Processing Record 353 | mantua
# Processing Record 354 | coquimbo
# Processing Record 355 | verkhnevilyuysk
# Processing Record 356 | marienburg
# Processing Record 357 | saskylakh
# Processing Record 358 | igurubi
# Processing Record 359 | berdigestyakh
# Processing Record 360 | akniste
# Processing Record 361 | eskil
# Processing Record 362 | sulecin
# Processing Record 363 | caruray
# Processing Record 364 | dharchula
# Processing Record 365 | ranong
# Processing Record 366 | oeiras do para
# Processing Record 367 | anloga
# Processing Record 368 | toora-khem
# Processing Record 369 | gannan
# Processing Record 370 | sinnamary
# Processing Record 371 | xining
# Processing Record 372 | nuuk
# Processing Record 373 | otjiwarongo
# Processing Record 374 | samarai
# Processing Record 375 | norman wells
# Processing Record 376 | roros
# Processing Record 377 | garowe
# Processing Record 378 | aleppo
# Processing Record 379 | ystad
# Processing Record 380 | lazaro cardenas
# Processing Record 381 | deputatskiy
# City way too small for wx data. Skipping...
# Processing Record 382 | ust-kulom
# Processing Record 383 | semikarakorsk
# Processing Record 384 | itupiranga
# Processing Record 385 | neyshabur
# City way too small for wx data. Skipping...
# City way too small for wx data. Skipping...
# Processing Record 386 | haines junction
# City way too small for wx data. Skipping...
# Processing Record 387 | sao joao da barra
# Processing Record 388 | kiama
# Processing Record 389 | vao
# Processing Record 390 | college
# Processing Record 391 | lagos
# City way too small for wx data. Skipping...
# Processing Record 392 | berlevag
# Processing Record 393 | pangnirtung
# Processing Record 394 | archidona
# Processing Record 395 | praya
# Processing Record 396 | cuenca
# Processing Record 397 | tateyama
# Processing Record 398 | borger
# Processing Record 399 | marrakesh
# Processing Record 400 | lakes entrance
# Processing Record 401 | mersing
# Processing Record 402 | alice
# City way too small for wx data. Skipping...
# Processing Record 403 | roald
# Processing Record 404 | krasnoselkup
# Processing Record 405 | cabo rojo
# Processing Record 406 | ancud
# Processing Record 407 | saskatoon
# City way too small for wx data. Skipping...
# Processing Record 408 | iquique
# Processing Record 409 | beringovskiy
# Processing Record 410 | saldanha
# Processing Record 411 | pueblo nuevo
# Processing Record 412 | gravdal
# Processing Record 413 | warrnambool
# Processing Record 414 | port hardy
# Processing Record 415 | kilindoni
# Processing Record 416 | atbasar
# Processing Record 417 | broome
# Processing Record 418 | nishihara
# Processing Record 419 | souillac
# City way too small for wx data. Skipping...
# Processing Record 420 | baykit
# City way too small for wx data. Skipping...
# City way too small for wx data. Skipping...
# City way too small for wx data. Skipping...
# Processing Record 421 | zapadnaya dvina
# Processing Record 422 | santa maria
# Processing Record 423 | port moresby
# Processing Record 424 | tromso
# Processing Record 425 | ballangen
# Processing Record 426 | hamilton
# Processing Record 427 | nouakchott
# Processing Record 428 | jerusalem
# Processing Record 429 | rantepao
# Processing Record 430 | humaita
# Processing Record 431 | lokosovo
# Processing Record 432 | coahuayana
# Processing Record 433 | igrim
# Processing Record 434 | marzuq
# Processing Record 435 | pishva
# Processing Record 436 | fuxin
# Processing Record 437 | statesboro
# Processing Record 438 | yumen
# Processing Record 439 | camocim
# City way too small for wx data. Skipping...
# Processing Record 440 | sistranda
# Processing Record 441 | kingston
# Processing Record 442 | narva-joesuu
# Processing Record 443 | wukari
# Processing Record 444 | sharjah
# Processing Record 445 | melfi
# Processing Record 446 | xapuri
# Processing Record 447 | krasnohrad
# Processing Record 448 | waddan
# Processing Record 449 | manati
# Processing Record 450 | laredo
# Processing Record 451 | abeche
# Processing Record 452 | lodja
# Processing Record 453 | bandarbeyla
# Processing Record 454 | palmas
# Processing Record 455 | sale
# Processing Record 456 | palmer
# Processing Record 457 | puerto leguizamo
# Processing Record 458 | junction city
# Processing Record 459 | cabinda
# Processing Record 460 | virginia beach
# Processing Record 461 | fort-shevchenko
# Processing Record 462 | yulara
# Processing Record 463 | port keats
# Processing Record 464 | jackson
# City way too small for wx data. Skipping...
# Processing Record 465 | batagay-alyta
# Processing Record 466 | nantucket
# Processing Record 467 | anshun
# Processing Record 468 | contamana
# Processing Record 469 | esperance
# Processing Record 470 | vila velha
# Processing Record 471 | cockburn town
# Processing Record 472 | wiwili
# Processing Record 473 | marawi
# Processing Record 474 | avera
# Processing Record 475 | vardo
# Processing Record 476 | camiri
# Processing Record 477 | morlaix
# Processing Record 478 | scarborough
# Processing Record 479 | winnemucca
# Processing Record 480 | bhag
# Processing Record 481 | constitucion
# Processing Record 482 | ponta delgada
# Processing Record 483 | kalangala
# Processing Record 484 | lata
# Processing Record 485 | goma
# Processing Record 486 | douglas
# Processing Record 487 | bayevo
# Processing Record 488 | brae
# Processing Record 489 | emba
# City way too small for wx data. Skipping...
# Processing Record 490 | pljevlja
# Processing Record 491 | kingston upon hull
# City way too small for wx data. Skipping...
# City way too small for wx data. Skipping...
# Processing Record 492 | heinola
# Processing Record 493 | daitari
# Processing Record 494 | batagay
# Processing Record 495 | vostok
# Processing Record 496 | karaton
# Processing Record 497 | vila franca do campo
# Processing Record 498 | san policarpo
# City way too small for wx data. Skipping...
# Processing Record 499 | along
# Processing Record 500 | chimoio
# Processing Record 501 | soyo
# City way too small for wx data. Skipping...
# Processing Record 502 | muros
# Processing Record 503 | chkalovskoye
# City way too small for wx data. Skipping...
# Processing Record 504 | niquelandia
# Processing Record 505 | altay
# Processing Record 506 | champerico
# Processing Record 507 | wanning
# Processing Record 508 | harrison
# Processing Record 509 | oranjemund
# Processing Record 510 | naryan-mar
# Processing Record 511 | ust-maya
# City way too small for wx data. Skipping...
# Processing Record 512 | saint-leu
# Processing Record 513 | rudsar
# Processing Record 514 | naze
# Processing Record 515 | mecca
# Processing Record 516 | fairbanks
# Processing Record 517 | estelle
# Processing Record 518 | gombong
# Processing Record 519 | nador
# City way too small for wx data. Skipping...
# Processing Record 520 | takhtamygda
# Processing Record 521 | huicungo
# Processing Record 522 | bucerias
# Processing Record 523 | cabedelo
# Processing Record 524 | noshiro
# City way too small for wx data. Skipping...
# City way too small for wx data. Skipping...
# Processing Record 525 | nioro
# City way too small for wx data. Skipping...
# Processing Record 526 | san nicolas guadalupe
# Processing Record 527 | apatou
# Processing Record 528 | omsukchan
# City way too small for wx data. Skipping...
# City way too small for wx data. Skipping...
# Processing Record 529 | nome
# Processing Record 530 | diffa
# Processing Record 531 | itoman
# Processing Record 532 | nemuro
# City way too small for wx data. Skipping...
# Processing Record 533 | ewa beach
# City way too small for wx data. Skipping...
# Processing Record 534 | sonoita
# Processing Record 535 | victoria point
# Processing Record 536 | verkhnetulomskiy
# Processing Record 537 | christchurch
# Processing Record 538 | pacific grove
# Processing Record 539 | niihama
# Processing Record 540 | evensk
# Processing Record 541 | cayenne
# Processing Record 542 | malakal

# %%
# Data retrieval verification

print(f"The windspeed information received is: {windspeeds}")
# Out:
# The windspeed information received is: [13.29, 4.7, 16.6, 4.16, 1.7, 34.45, 11.01, 11.41, 22.53, 17.22, 6.04, 2.57, 3.71, 16.11, 4.9, 1.01, 2.93, 5.82, 4.43, 2.24, 12.75, 1.01, 14.38, 9.48, 9.1, 2.24, 12.75, 3.38, 5.82, 4, 2.24, 2.24, 11.41, 8.43, 5.82, 4.92, 4.29, 8.05, 4.7, 3.36, 4.47, 9.15, 9.48, 7.52, 4.23, 13.87, 0.38, 5.01, 9.4, 4.43, 8.05, 9.17, 9.62, 12.75, 6.93, 12.75, 16.11, 6.93, 5.19, 13.87, 7, 2.24, 8.05, 0.87, 6.93, 8.12, 4, 5.17, 5.82, 13.87, 1.32, 14.74, 0.94, 6.96, 8.01, 5.82, 3.36, 4.56, 9.17, 7.49, 7.92, 3.15, 8.01, 4.65, 2.98, 16.11, 7.7, 2.24, 6.49, 8.01, 9.17, 8.68, 1.59, 5.82, 5.48, 1.68, 0.87, 4.7, 20.65, 9.33, 4.05, 6.02, 8.05, 5.77, 13.87, 3, 13.87, 8.05, 8.95, 21.79, 2.8, 6.93, 2.24, 7.85, 6.93, 4.7, 10.29, 5.01, 16.37, 2.24, 3.36, 11.61, 2.42, 11.41, 3.36, 5.01, 8.03, 4.7, 7, 10.89, 7.45, 12.75, 8.1, 4.88, 17.05, 5.95, 10.29, 5.48, 12.75, 5.32, 4, 4.45, 7.99, 8.01, 15.28, 4.7, 4.34, 2.75, 13.87, 4.12, 12.26, 1.01, 9.33, 16.71, 8.43, 8.05, 7.36, 12.35, 14.09, 2.24, 10.29, 3.36, 3.27, 9.64, 17.22, 6.93, 16.58, 3, 10.94, 12.75, 15.5, 24.16, 9.15, 7.92, 4.7, 2.3, 5.01, 6.71, 4.92, 2.59, 1.34, 10.29, 8.95, 16.11, 9.33, 9.33, 3.76, 12.75, 7.45, 8.05, 4.7, 5.82, 3, 5.79, 10.58, 7.52, 11.41, 4.94, 5.19, 3.36, 9.44, 4.7, 5.99, 11.18, 8.48, 5.82, 5.5, 18.92, 7.74, 1.99, 13.87, 2.62, 6.55, 11.41, 10.29, 0.81, 12.75, 3.27, 3.83, 8.01, 4, 12.75, 4.7, 7.78, 16.64, 3.27, 22.17, 5.19, 4.68, 3.53, 6.93, 5.93, 2.24, 3.71, 3.11, 3.53, 5.99, 8.01, 13.87, 10.92, 23.04, 10.38, 16.06, 1.12, 8.01, 3.27, 1.12, 4.79, 1.9, 1.01, 15.35, 13.87, 4.7, 4.7, 5.01, 3.56, 16.11, 6.91, 5.28, 5.39, 4.7, 4.7, 9.98, 4.7, 6.29, 4.38, 26.4, 4.38, 8.05, 2.08, 14.99, 8.05, 8.39, 1.59, 7.07, 11.41, 1.68, 3.96, 16.73, 4.47, 11.41, 6.91, 9.4, 3.15, 8.01, 1.12, 12.19, 5.66, 7.81, 28.3, 2.89, 13.87, 8.48, 6.13, 5.61, 5.99, 2.57, 1.54, 5.82, 2.15, 7.34, 5.82, 4.7, 8.05, 5.82, 15.66, 9.17, 9.13, 10, 3.67, 1.9, 9.4, 16.11, 4.7, 6.67, 5.3, 2.26, 6.96, 6.93, 11.77, 11.41, 17.22, 8.14, 5.99, 14.99, 4.72, 8.3, 2.24, 4.43, 15.66, 5.99, 8.01, 4.52, 13.22, 2.75, 9.06, 10.29, 16.11, 6.93, 18.34, 4.76, 5.41, 2.28, 3.8, 1.72, 8.05, 2.37, 1.19, 1.99, 5.82, 7.47, 6.93, 3.56, 16.11, 3.71, 6.11, 13.85, 5.21, 3.71, 8.95, 16.46, 5.19, 4.27, 7.87, 3.65, 1.45, 11.41, 1.39, 7.63, 10.71, 1.34, 9.17, 11.52, 5.7, 11.41, 11.41, 14.97, 4.21, 8.05, 2.73, 4.36, 6.46, 17.9, 2.24, 3.22, 12.75, 9.4, 1.01, 18.3, 1.3, 6.51, 10.29, 2.93, 2.24, 19.46, 14.99, 3.36, 7, 4.7, 9.17, 8.05, 12.75, 19.46, 6.02, 12.75, 9.17, 6.93, 14.99, 16.78, 4.7, 11.41, 6.93, 12.5, 8.01, 13.51, 4.72, 4.7, 6.93, 11.41, 1.52, 0.31, 4.38, 8.01, 6.93, 13.87, 4.32, 8.05, 0.81, 1.36, 5.19, 5.82, 11.41, 5.84, 1.52, 13.87, 5.66, 3.58, 17.07, 18.5, 19.46, 9.17, 11.83, 0.96, 4.7, 12.75, 3.36, 15.7, 4.43, 3, 13.87, 10.09, 0.76, 16.98, 5.82, 8.05, 14.99, 16.11, 14.99, 6.46, 2.8, 12.57, 9.17, 8.01, 8.05, 1.77, 17.22, 3.33, 6.46, 13.87, 5.01, 16.11, 4.7, 5.99, 5.82, 13.87, 4.7, 16.11, 4, 3.36, 3.76, 12.66, 17.22, 2.24, 4, 3.2, 11.41, 10.71, 26.4, 5.35, 1.12, 9.17, 9.17, 2.04, 1.88, 3.51, 6.93, 5.01, 9.33, 1.48, 6.93, 7.94, 3, 4.18, 3.56, 0.67, 6.93, 8.93, 6.93, 9.66, 20.67, 2.75, 13.87, 8.12, 13.87, 1.01, 1.12, 10.29, 0.89, 12.75, 3.36, 5.82, 4.7, 12.75, 1.32, 6.53, 9.33, 3.18, 1.07, 4.7, 5.79, 9.17, 11.68, 7.43, 15.79, 5.01, 4.47, 8.05, 5.35, 3.47, 15.66, 11.41, 4.03]

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#Create a dataframe to store the data
wx = {"City":citylist,"Country":countries,"Lat":lats,"Long":longs,"Cloudiness":cloudiness,"Humidity":humidity,"Max Temp":max_temps,"Wind Speed":windspeeds, "Date":dates,}

weather_df = pd.DataFrame(wx)
weather_df.to_csv(r'output_data/cities.csv', index=False)

# %%
#Preview the dataframe
weather_df.head()
# Out:
#         City Country    Lat    Long  Cloudiness  Humidity  Max Temp  \
# 0    rikitea      PF -23.12 -134.97           3        81     76.73
# 1   ahuimanu      US  21.44 -157.84           1        78     78.01
# 2    sechura      PE  -5.56  -80.82          92        60     77.74
# 3  boa vista      CM   4.43    8.97          97        82     78.49
# 4       asau      RO  46.43   26.40          90        89     32.00
#
#    Wind Speed        Date
# 0       13.29  1607630278
# 1        4.70  1607630278
# 2       16.60  1607630279
# 3        4.16  1607630279
# 4        1.70  1607630279

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
weather_df.sort_values(by=['Humidity'], ascending=False)
# Out:
#              City Country    Lat    Long  Cloudiness  Humidity  Max Temp  \
# 355    marienburg      PL  54.04   19.03          99       100     28.99
# 119     kununurra      AU -15.77  128.73         100       100     77.00
# 304          luba      GQ   3.46    8.55          20       100     78.80
# 201  ornskoldsvik      SE  63.29   18.72         100       100     37.40
# 308    beausejour      CA  50.06  -96.52         100       100     28.00
# ..            ...     ...    ...     ...         ...       ...       ...
# 184    san rafael      ML  13.30   -4.90           0        17     82.17
# 94         bousso      TD  10.48   16.71         100        16     81.54
# 80         gayeri      BF  12.65    0.49          22        16     82.35
# 426    nouakchott      MR  18.09  -15.98          97        13     75.20
# 125       pahrump      US  36.21 -115.98          24        13     64.00
#
#      Wind Speed        Date
# 355        6.11  1607630348
# 119        2.24  1607630302
# 304        5.82  1607630337
# 201        4.70  1607630318
# 308       10.00  1607630338
# ..          ...         ...
# 184        9.33  1607630153
# 94         5.48  1607630297
# 80         7.92  1607630295
# 426        8.05  1607630362
# 125        5.01  1607630278
#
# [542 rows x 9 columns]

# %%
#  Get the indices of cities that have humidity over 100%.
weather_df[weather_df['Humidity'] == 100]
# Out:
#                   City Country    Lat    Long  Cloudiness  Humidity  Max Temp  \
# 61   santander jimenez      ES  43.46   -3.80          40       100     54.00
# 78      ribeira grande      ES  42.75   -8.44          90       100     57.99
# 87       mar del plata      ES  43.40   -4.01          40       100     55.99
# 102         karlskrona      SE  56.16   15.59          75       100     33.80
# 104          carnarvon      AU -24.87  113.63          90       100     73.40
# 119          kununurra      AU -15.77  128.73         100       100     77.00
# 183           bradford      GB  53.79   -1.75          90       100     42.01
# 201       ornskoldsvik      SE  63.29   18.72         100       100     37.40
# 222             bermeo      ES  43.42   -2.72          75       100     53.01
# 243             hasaki      JP  35.73  140.83          20       100     39.20
# 246               sibu      MY   2.30  111.82          20       100     77.00
# 304               luba      GQ   3.46    8.55          20       100     78.80
# 308         beausejour      CA  50.06  -96.52         100       100     28.00
# 336           carballo      ES  43.21   -8.69          75       100     59.00
# 355         marienburg      PL  54.04   19.03          99       100     28.99
# 383         itupiranga      BR  -5.13  -49.33          40       100     77.00
# 400            mersing      MY   2.43  103.84          96       100     73.40
# 499            chimoio      MZ -19.12   33.48          20       100     73.40
# 512             rudsar      IR  37.14   50.29          90       100     44.60
#
#      Wind Speed        Date
# 61         2.24  1607630291
# 78         9.17  1607630294
# 87         2.24  1607630296
# 102        8.05  1607630002
# 104       13.87  1607630299
# 119        2.24  1607630302
# 183       16.11  1607630215
# 201        4.70  1607630318
# 222        4.70  1607630072
# 243        1.12  1607630326
# 246        1.12  1607630327
# 304        5.82  1607630337
# 308       10.00  1607630338
# 336       10.29  1607630344
# 355        6.11  1607630348
# 383        2.24  1607630353
# 400        8.05  1607630356
# 499        6.93  1607630376
# 512        8.12  1607630379

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.

clean_weather_df = weather_df[weather_df['Humidity'] != 100]
clean_weather_df.sort_values(by=['Humidity'], ascending=False)
# Out:
#                  City Country    Lat    Long  Cloudiness  Humidity  Max Temp  \
# 287         bangangte      CM   5.14   10.52          99        99     64.17
# 273           ambunti      PG  -4.24  142.84         100        99     73.58
# 494            vostok      RU  46.49  135.88         100        98     10.47
# 79             palana      RU  59.12  159.97         100        98     17.47
# 535  verkhnetulomskiy      RU  68.61   31.80          75        98     32.00
# ..                ...     ...    ...     ...         ...       ...       ...
# 99      san cristobal      ML  13.30   -4.90           0        17     82.17
# 80             gayeri      BF  12.65    0.49          22        16     82.35
# 94             bousso      TD  10.48   16.71         100        16     81.54
# 125           pahrump      US  36.21 -115.98          24        13     64.00
# 426        nouakchott      MR  18.09  -15.98          97        13     75.20
#
#      Wind Speed        Date
# 287        5.66  1607630334
# 273        1.59  1607630332
# 494        3.51  1607630375
# 79         7.49  1607630294
# 535        4.47  1607630385
# ..          ...         ...
# 99         9.33  1607630153
# 80         7.92  1607630295
# 94         5.48  1607630297
# 125        5.01  1607630278
# 426        8.05  1607630362
#
# [523 rows x 9 columns]

# %%
clean_weather_df.sort_values(by=['Max Temp'], ascending=False)
# Out:
#               City Country    Lat    Long  Cloudiness  Humidity  Max Temp  \
# 467      contamana      PE  -7.33  -75.02          51        39     96.82
# 210          moron      AR -34.65  -58.62           0        28     96.01
# 520       huicungo      PE  -7.28  -76.80          40        56     93.20
# 475         camiri      BO -20.05  -63.52          40        26     93.20
# 505     champerico      GT  14.30  -91.92          40        55     89.60
# ..             ...     ...    ...     ...         ...       ...       ...
# 276           amga      RU  60.90  131.96          93        81    -35.05
# 149       ust-nera      RU  64.57  143.20          62        72    -35.88
# 358  berdigestyakh      RU  62.10  126.70          99        82    -36.96
# 493        batagay      RU  67.63  134.63          70        77    -37.16
# 100      churapcha      RU  62.00  132.43         100        81    -38.33
#
#      Wind Speed        Date
# 467        6.46  1607630370
# 210       13.87  1607630320
# 520        5.82  1607630381
# 475        4.70  1607630372
# 505        6.93  1607630378
# ..          ...         ...
# 276        1.68  1607630332
# 149        4.12  1607630308
# 358        3.71  1607630348
# 493        1.88  1607630375
# 100        4.05  1607630298
#
# [523 rows x 9 columns]

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# Plotting cities by Lat and Long and visualizing tempertaure by color gave a more useful plot 
#    than latitude and tempertaure alone.

# Extract the data we're interested in
Lat, Long = clean_weather_df['Lat'], clean_weather_df['Long']
temperature = clean_weather_df['Max Temp']

# Scatter the points, using temperature color
plt.scatter(Long, Lat, label=None,
            c=temperature, cmap='rainbow',
            linewidth=0, alpha=0.5)

# Title and Labels
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.colorbar(label='Temperature')
plt.clim(-40, 110)
 
plt.title(f'Latitude vs Temperature (F)  {time.strftime("%m/%d/%Y")}');

# Save the figure
plt.savefig('Latitude vs.Temperature v1.png')

# %%
#'Latitude vs Temperature (F)' utlizes color to show maximum temperature distribution 
#   by Latitude, and, to a lesser degree, by Longitude. As expected the bands are relatively 
#   uniform horizontally with the exception of some longitudes with particularly cooler temperatures.

# %%
# Build a boring, less useful scatter plot 'Latitude vs.Temperature (F)'

# Number of cities in cleaned dataframe
n = len(clean_weather_df. index)
t= np.arange(n)  # color scale matched with number of data points

plt.scatter(clean_weather_df['Lat'], clean_weather_df['Max Temp'], s=5, c=t)

# Title and Labels
plt.xlabel('Latitude')
plt.ylabel('Temperature (F)')
plt.title(f'Latitude vs.Temperature (F) {time.strftime("%m/%d/%Y")}')

plt.grid(True)

# Save the figure
plt.savefig('Latitude vs.Temperature v2.png')

plt.show()

# %%
#'Latitude vs Temperature (F)' utlizes color to show maximum temperature distribution 
#   by Latitude. This is a less visually educational plot because all latitudes are 
#   grouped together but the colors do show temperature distribution.

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# Plotting cities by Lat and Long and visualizing humidity by color gave a more useful plot 
#    than latitude and tempertaure alone.
# Two dimensional scatterplot located in regression section.

# Extract the data we're interested in
Lat, Long = clean_weather_df['Lat'], clean_weather_df['Long']
hum = clean_weather_df['Humidity']

# Scatter the points, using Humidity
plt.scatter(Long, Lat, label=None,
            c=hum, cmap='rainbow',
            linewidth=0, alpha=0.5)

plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.colorbar(label='Humidity %')
plt.clim(0, 100)
 
plt.title(f'Latitude vs Humidity %  {time.strftime("%m/%d/%Y")}');

# Save the figure
plt.savefig('Latitude vs.Humidity.png')

# %%
#'Latitude vs Humidity %' utlizes color to show humidity % distribution 
#   by Latitude, and, to a lesser degree, by Longitude. The plot visually
#   confers that humidity is not determined by latitude alone...longitude
#   plays an important role in the humidity a city will experience.

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# Plotting cities by Lat and Long and visualizing cloudiness by color gave a more useful plot 
#    than latitude and tempertaure alone.
# Two dimensional scatterplot located in regression section.

# Extract the data we're interested in
Lat, Long = clean_weather_df['Lat'], clean_weather_df['Long']
cloud = clean_weather_df['Cloudiness']

# Scatter the points, using Cloudiness
plt.scatter(Long, Lat, label=None,
            c=cloud, cmap='binary',
            linewidth=0, alpha=0.5)

plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.colorbar(label='Cloudiness %')
plt.clim(0, 100)
 
plt.title(f'Latitude vs Cloudiness %  {time.strftime("%m/%d/%Y")}');

# Save the figure
plt.savefig('Latitude vs.Cloudiness.png')

# %%
#'Latitude vs Cloudiness %' utlizes color to show cloudiness % distribution 
#   by Latitude, and, to a lesser degree, by Longitude. The plot visually
#   confers that cloudiness is not primarily determined by latitude...longitude
#   appears to be the primary determinant of cloudiness.

# %%
clean_weather_df.sort_values(by=['Wind Speed'], ascending=False)
# Out:
#                City Country    Lat    Long  Cloudiness  Humidity  Max Temp  \
# 479  vestmannaeyjar      IS  63.44  -20.27          90        93     42.80
# 118           lagoa      PT  39.05  -27.98          95        90     64.08
# 477            brae      GB  60.40   -1.35          40        81     46.40
# 340  saint-philippe      RE -21.36   55.77          20        78     75.20
# 506       vestmanna      FO  62.16   -7.17         100        93     44.60
# ..              ...     ...    ...     ...         ...       ...       ...
# 323           kharp      RU  66.80   65.81         100        93      4.23
# 70         dong hoi      CM   4.89   12.01          76        37     88.63
# 481         boyabat      TR  41.47   34.77          93        59     45.59
# 141        montrose      US  38.42 -108.27          40        53     35.01
# 456       kathmandu      NP  27.72   85.32          20        87     53.60
#
#      Wind Speed        Date
# 479       27.51  1607616046
# 118       25.50  1607615946
# 477       24.16  1607616046
# 340       24.16  1607615989
# 506       24.16  1607616054
# ..          ...         ...
# 323        0.74  1607615986
# 70         0.69  1607615935
# 481        0.63  1607616047
# 141        0.63  1607615950
# 456        0.60  1607615786
#
# [538 rows x 9 columns]

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# Plotting cities by Lat and Long and visualizing wind speed by color gave a more useful plot 
#    than latitude and tempertaure alone.
# Two dimensional scatterplot located in regression section.

# Extract the data we're interested in
Lat, Long = clean_weather_df['Lat'], clean_weather_df['Long']
wind = clean_weather_df['Wind Speed']

# Scatter the points, using temperature color
plt.scatter(Long, Lat, label=None,
            c=wind, cmap='Blues',
            linewidth=0, alpha=0.5)

plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.colorbar(label='Wind Speed (mph)')
plt.clim(0, 40)
 
plt.title(f'Latitude vs Wind Speed (mph) {time.strftime("%m/%d/%Y")}');

# Save the figure
plt.savefig('Latitude vs.Wind Speed.png')

# %%
#'Latitude vs Wind Speed' utlizes color to show wind speed distribution 
#   by Latitude, and, to a lesser degree, by Longitude. The plot visually
#   confers that wind speed is greater at the subtropical jets and indicated
#   by darker blue colors.

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Dataframe for Northern Hemisphere cities
northtemp_df = weather_df[weather_df['Lat'] >= 0]
northtemp_df.sort_values(by=['Lat'])
# Out:
#              City Country    Lat    Long  Cloudiness  Humidity  Max Temp  \
# 325     kisangani      CD   0.52   25.20         100        92     75.67
# 26         mitzic      GA   0.78   11.55          81        74     79.84
# 499       ternate      ID   0.80  127.40          23        76     82.17
# 467     pemangkat      ID   1.17  108.97         100        86     79.43
# 333          mitu      CO   1.20  -70.17          94        53     88.75
# ..            ...     ...    ...     ...         ...       ...       ...
# 411      khatanga      RU  71.97  102.50          90        84    -31.40
# 219     upernavik      GL  72.79  -56.15         100        97     24.37
# 142        dikson      RU  73.51   80.55          39        91    -12.28
# 27        qaanaaq      GL  77.48  -69.36         100        91      9.48
# 214  longyearbyen      SJ  78.22   15.64          75        66     15.80
#
#      Wind Speed        Date
# 325        2.93  1607615986
# 26         3.31  1607615927
# 499        4.72  1607616052
# 467        7.58  1607615959
# 333        4.23  1607615988
# ..          ...         ...
# 411        8.34  1607616025
# 219        9.35  1607615965
# 142       13.65  1607615950
# 27         3.11  1607615928
# 214       12.75  1607615964
#
# [407 rows x 9 columns]

# %%
# Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# Number of cities in cleaned northern hemisphere dataframe
n1 = len(northtemp_df. index)

t= np.arange(n1)  # Color scale matched with number of data points
plt.scatter(northtemp_df['Lat'], northtemp_df['Max Temp'], s=5, c=t)

# Title and Labels
plt.xlabel('Latitude')
plt.ylabel('Temperature (F)')
plt.title(f'Northern Latitudes vs.Temperature (F) {time.strftime("%m/%d/%Y")}')

plt.grid(True)

# Regression Line
x_values = northtemp_df['Lat']
y_values = northtemp_df['Max Temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(0,0),fontsize=15,color="darkblue")

# Print out the r-squared value along with the plot.
print(f"The r-squared is: {rvalue**2}")

# Save the figure
plt.savefig('N Latitude vs.Temperature.png')

plt.show()
# Out:
# The r-squared is: 0.7373832881983907

# %%
print('For every unit of change in latitude the temperature drops ' + str(round(slope,2)) +' units.') 
print('Approximately '+ str(round(rvalue**2,2)*100) + '% of the data fit into the model.')
# Out:
# For every unit of change in latitude the temperature drops -1.3 units.
# Approximately 74.0% of the data fit into the model.

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Dataframe for Southern Hemisphere cities
south_df = weather_df[weather_df['Lat'] <= 0]
south_df.sort_values(by=['Lat'])
# Out:
#             City Country    Lat    Long  Cloudiness  Humidity  Max Temp  \
# 24       ushuaia      AR -54.80  -68.30          75        58     57.20
# 17         bluff      NZ -46.60  168.33         100        94     44.01
# 95    kaitangata      NZ -46.28  169.85         100        93     48.00
# 37       mataura      NZ -46.19  168.86         100        94     44.01
# 231    tuatapere      NZ -46.13  167.68         100        94     44.01
# ..           ...     ...    ...     ...         ...       ...       ...
# 4      manokwari      ID  -0.87  134.08          74        76     80.67
# 394  port-gentil      GA  -0.72    8.78          40        74     84.20
# 92     hithadhoo      MV  -0.60   73.08          45        73     82.35
# 194      kismayo      SO  -0.36   42.55          11        73     80.83
# 482      mazagao      BR  -0.12  -51.29          75        70     87.80
#
#      Wind Speed        Date
# 24         5.82  1607615927
# 17         8.01  1607615926
# 95        11.99  1607615941
# 37         8.01  1607615929
# 231        8.01  1607615968
# ..          ...         ...
# 4          1.43  1607615923
# 394       13.87  1607615783
# 92        10.96  1607615940
# 194       14.07  1607615960
# 482        9.17  1607616047
#
# [145 rows x 9 columns]

# %%
# Southern Hemisphere - Max Temp vs. Latitude Linear Regression
# Number of cities in cleaned southern hemisphere dataframe
n2 = len(south_df. index)
t= np.arange(n2)  # Color scale matched with number of data points
plt.scatter(south_df['Lat'], south_df['Max Temp'], s=5, c=t)

# Title and Labels
plt.xlabel('Latitude')
plt.ylabel('Temperature (F)')
plt.title(f'Southern Latitudes vs.Temperature (F) {time.strftime("%m/%d/%Y")}')

plt.grid(True)

# Print out the r-squared value along with the plot.
print(f"The r-squared is: {rvalue**2}")

# Regression Line
x_values = south_df['Lat']
y_values = south_df['Max Temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-27,55),fontsize=15,color="darkblue")

# Save the figure
plt.savefig('S Latitude vs.Temperature Reg.png')

plt.show()
# Out:
# The r-squared is: 0.7373832881983907

# %%
print('For every unit of change in latitude the temperature rises.') 
print('A relatively high percentage of the data fit into the model as opposed to other regressions.')
# Out:
# For every unit of change in latitude the temperature rises.
# A relatively high percentage of the data fit into the model as opposed to other regressions.

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Northern Hemisphere - Humidity vs. Latitude Linear Regression

# Number of cities in cleaned northern hemisphere dataframe
n1 = len(northtemp_df. index)
t= np.arange(n1)  # Color scale matched with number of data points
plt.scatter(northtemp_df['Lat'], northtemp_df['Humidity'], s=5, c=t)

# Title and Labels
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.title(f'Northern Latitudes vs.Humidity {time.strftime("%m/%d/%Y")}')

plt.grid(True)

# Print out the r-squared value along with the plot.
print(f"The r-squared is: {rvalue**2}")

# Regression Line
x_values = northtemp_df['Lat']
y_values = northtemp_df['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(40,20),fontsize=15,color="darkblue")

# Save the figure
plt.savefig('N Latitude vs.Humidity Reg.png')

plt.show()
# Out:
# The r-squared is: 0.42521072224049566

# %%
print('For every unit of change in latitude the humidity rises.') 
print('There is a wide distribution of datapoints.')
print('The implication of the r-squared value is that the model offers poor predicatability of results.')
print('Visually this is observed in the wide scatter of datapoints.')
# Out:
# For every unit of change in latitude the humidity rises.
# There is a wide distribution of datapoints.
# The implication of the r-squared value is that the model offers poor predicatability of results.
# Visually this is observed in the wide scatter of datapoints.

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Southern Hemisphere - Humidity vs. Latitude Linear Regression
# Number of cities in cleaned southern hemisphere dataframe
n2 = len(south_df. index)
t= np.arange(n2)  # Color scale matched with number of data points
plt.scatter(south_df['Lat'], south_df['Humidity'], s=5, c=t)

# Title and Labels
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title(f'Southern Latitudes vs.Humidity (%) {time.strftime("%m/%d/%Y")}')

plt.grid(True)

# Print out the r-squared value along with the plot.
print(f"The r-squared is: {rvalue**2}")

# Regression Line
x_values = south_df['Lat']
y_values = south_df['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-55,22),fontsize=15,color="darkblue")

# Save the figure
plt.savefig('S Latitude vs.Humidity Reg.png')

plt.show()
# Out:
# The r-squared is: 0.17714435373886653

# %%
print('For every unit of change in latitude the humidity increases ' + str(round(slope,2)) +' units.') 
print('The implication of the r-squared value is that the model offers poor predicatability of results.')
print('Visually this is observed in the wide scatter of datapoints, eg high variance.')
# Out:
# For every unit of change in latitude the humidity increases 0.14 units.
# The implication of the r-squared value is that the model offers poor predicatability of results.
# Visually this is observed in the wide scatter of datapoints, eg high variance.

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Northern Hemisphere - Cloudiness vs. Latitude Linear Regression
# Number of cities in cleaned northern hemisphere dataframe
n1 = len(northtemp_df. index)
t= np.arange(n1)  # Color scale matched with number of data points
plt.scatter(northtemp_df['Lat'], northtemp_df['Cloudiness'], s=5, c=t)

# Title and Labels
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.title(f'Northern Latitudes vs.Cloudiness {time.strftime("%m/%d/%Y")}')

plt.grid(True)

# Print out the r-squared value along with the plot.
print(f"The r-squared is: {rvalue**2}")

# Regression Line
x_values = northtemp_df['Lat']
y_values = northtemp_df['Cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(45,40),fontsize=15,color="darkblue")

# Save the figure
plt.savefig('N Latitude vs.Cloudiness Reg.png')

plt.show()
# Out:
# The r-squared is: 0.04236546162455296

# %%
print('For every unit of change in latitude the cloudiness increases ' + str(round(slope,2)) +' units.') 
print('The implication of the r-squared value is that the model offers poor predicatability of results.')
print('Visually this is observed in the wide scatter of datapoints , eg high')
print('  variance, with large distributions at the extreme ends of the y-axis.')
# Out:
# For every unit of change in latitude the cloudiness increases 0.36 units.
# The implication of the r-squared value is that the model offers poor predicatability of results.
# Visually this is observed in the wide scatter of datapoints , eg high
#   variance, with large distributions at the extreme ends of the y-axis.

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression
# Number of cities in cleaned southern hemisphere dataframe
n2 = len(south_df. index)
t= np.arange(n2)  # Color scale matched with number of data points
plt.scatter(south_df['Lat'], south_df['Cloudiness'], s=5, c=t)

# Title and Labels
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title(f'Southern Latitudes vs.Cloudiness (%) {time.strftime("%m/%d/%Y")}')

plt.grid(True)

# Print out the r-squared value along with the plot.
print(f"The r-squared is: {rvalue**2}")

# Regression Line
x_values = south_df['Lat']
y_values = south_df['Cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-55,60),fontsize=15,color="darkblue")

# Save the figure
plt.savefig('S Latitude vs.Cloudiness Reg.png')

plt.show()
# Out:
# The r-squared is: 0.034912391154491164

# %%
print('For every unit of change in latitude the cloudiness increases ' + str(round(slope,2)) +' units.') 
print('The implication of the r-squared value is that the model offers poor predicatability of results.')
print('Visually this is observed in the wide scatter of datapoints , eg high')
print('  variance, with large distributions at the extreme ends of the y-axis.')
# Out:
# For every unit of change in latitude the cloudiness increases 0.55 units.
# The implication of the r-squared value is that the model offers poor predicatability of results.
# Visually this is observed in the wide scatter of datapoints , eg high
#   variance, with large distributions at the extreme ends of the y-axis.

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Northern Hemisphere - Wind Speed vs. Latitude Linear Regression
# Number of cities in cleaned northern hemisphere dataframe
n1 = len(northtemp_df. index)
t= np.arange(n1)  # Color scale matched with number of data points
plt.scatter(northtemp_df['Lat'], northtemp_df['Wind Speed'], s=5, c=t)

# Title and Labels
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title(f'Northern Latitudes vs.Wind Speed (mph) {time.strftime("%m/%d/%Y")}')

plt.grid(True)

# Print out the r-squared value along with the plot.
print(f"The r-squared is: {rvalue**2}")

# Regression Line
x_values = northtemp_df['Lat']
y_values = northtemp_df['Wind Speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(5,20),fontsize=15,color="darkblue")

# Save the figure
plt.savefig('N Latitude vs.Wind Speed Reg.png')

plt.show()
# Out:
# The r-squared is: 0.04236546162455296

# %%
print('For every unit of change in latitude the cloudiness increases ' + str(round(slope,2)) +' units...nearly a flat line.') 
print('The implication of the r-squared value is that the model offers poor predicatability of results.')
print('Visually this is observed in the wide scatter of datapoints , eg high')
print('  variance, with large distributions at the extreme ends of the y-axis.')
# Out:
# For every unit of change in latitude the cloudiness increases 0.01 units...nearly a flat line.
# The implication of the r-squared value is that the model offers poor predicatability of results.
# Visually this is observed in the wide scatter of datapoints , eg high
#   variance, with large distributions at the extreme ends of the y-axis.

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
# Number of cities in cleaned southern hemisphere dataframe
n2 = len(south_df. index)
t= np.arange(n2)  # Color scale matched with number of data points
plt.scatter(south_df['Lat'], south_df['Wind Speed'], s=5, c=t)

# Title and Labels
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title(f'Southern Latitudes vs.Wind Speed (mph) {time.strftime("%m/%d/%Y")}')

plt.grid(True)

# Print out the r-squared value along with the plot.
print(f"The r-squared is: {rvalue**2}")

# Regression Line
x_values = south_df['Lat']
y_values = south_df['Wind Speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-55,13),fontsize=15,color="darkblue")

# Save the figure
plt.savefig('S Latitude vs.Wind Speed Reg.png')

plt.show()
# Out:
# The r-squared is: 0.0014935508551827859

# %%
print('For every unit of change in latitude the cloudiness increases ' + str(round(slope,2)) +' units.') 
print('The implication of the r-squared value is that the model offers poor predicatability of results.')
print('Visually this is observed in the wide scatter of datapoints , eg high')
print('  variance, with large distributions at the extreme ends of the y-axis.')
# Out:
# For every unit of change in latitude the cloudiness increases -0.06 units.
# The implication of the r-squared value is that the model offers poor predicatability of results.
# Visually this is observed in the wide scatter of datapoints , eg high
#   variance, with large distributions at the extreme ends of the y-axis.
