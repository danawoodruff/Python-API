# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 623

# %%
print(cities)
# Out:
# ['rikitea', 'vaitupu', 'severo-kurilsk', 'amderma', 'te anau', 'mataura', 'san carlos de bariloche', 'puerto ayora', 'noumea', 'khatanga', 'cape town', 'bluff', 'yellowknife', 'sulangan', 'samusu', 'pingliang', 'port elizabeth', 'palabuhanratu', 'parana', 'airai', 'leh', 'hermanus', 'izhmorskiy', 'wulanhaote', 'isangel', 'sinnamary', 'hayvoron', 'pryozerne', 'faanui', 'kyabram', 'barentsburg', 'pinega', 'kaili', 'qaanaaq', 'kavieng', 'petropavlovsk-kamchatskiy', 'imeni poliny osipenko', 'vila franca do campo', 'chuy', 'nikolskoye', 'goderich', 'ponta do sol', 'busselton', 'pisco', 'la ronge', 'burnie', 'luderitz', 'atuona', 'illoqqortoormiut', 'taolanaro', 'siilinjarvi', 'bethel', 'port alfred', 'akdepe', 'porbandar', 'cockburn town', 'olenino', 'ushuaia', 'bilma', 'tikrit', 'albany', 'grand river south east', 'san policarpo', 'atar', 'palmer', 'benguela', 'bredasdorp', 'saleaula', 'kapaa', 'abha', 'lebu', 'punta arenas', 'palembang', 'lompoc', 'cherskiy', 'hithadhoo', 'bhusawal', 'inderborskiy', 'mattru', 'maiduguri', 'chokurdakh', 'camopi', 'provideniya', 'bosaso', 'comodoro rivadavia', 'kosa', 'umm durman', 'mandurah', 'garowe', 'belushya guba', 'nushki', 'georgetown', 'pacific grove', 'dzhusaly', 'taltal', 'sesheke', 'castro alves', 'ciudad real', 'inhambane', 'east london', 'aksu', 'ayni', 'khorramshahr', 'filadelfia', 'mys shmidta', 'vallenar', 'nazarovo', 'ambilobe', 'amahai', 'college', 'barrow', 'huntington', 'umzimvubu', 'rio grande', 'presidencia roque saenz pena', 'palaikastron', 'juybar', 'lagoa', 'tomatlan', 'jiujiang', 'rayadrug', 'gainsborough', 'mariveles', 'madingou', 'husavik', 'arequipa', 'komsomolskiy', 'asau', 'katsuura', 'jawhar', 'melilla', 'minas', 'port hedland', 'jamestown', 'vila velha', 'tasiilaq', 'mount isa', 'hobart', 'pecos', 'avarua', 'souillac', 'yuncheng', 'tabiauea', 'namatanai', 'krasnyy chikoy', 'new norfolk', 'qui nhon', 'walvis bay', 'kruisfontein', 'novyy urengoy', 'bambous virieux', 'ganzhou', 'westport', 'arraial do cabo', 'vaini', 'harper', 'praya', 'klaksvik', 'hilo', 'roma', 'iqaluit', 'east stroudsburg', 'ulagan', 'florianopolis', 'galesong', 'tilichiki', 'zanjan', 'acapulco', 'aswan', 'aalen', 'dingle', 'thompson', 'taywarah', 'kloulklubed', 'adeje', 'yola', 'kamenskoye', 'constitucion', 'rudbar', 'mar del plata', 'salinas', 'alofi', 'kahului', 'hirara', 'shingu', 'dolbeau', 'kawalu', 'kieta', 'fare', 'grindavik', 'calvinia', 'aras', 'upernavik', 'fortuna', 'khushab', 'awjilah', 'mayo', 'haines junction', 'kodiak', 'srivardhan', 'gondanglegi', 'longyearbyen', 'sechura', 'muscat', 'nizhneyansk', 'kamojima', 'tiksi', 'tiznit', 'zhangjiakou', 'marcona', 'codrington', 'mecca', 'hamilton', 'kita', 'pacifica', 'dikson', 'praia da vitoria', 'rock sound', 'ahipara', 'sibolga', 'moroni', 'bartica', 'del rio', 'samarai', 'tuatapere', 'moerai', 'vila', 'kuusamo', 'igrim', 'makakilo city', 'kaitangata', 'floriano', 'astana', 'oranjemund', 'viedma', 'saint-philippe', 'santo antonio de padua', 'saskylakh', 'bontang', 'saldanha', 'salalah', 'bahia blanca', 'samalaeulu', 'natal', 'udachnyy', 'cedar city', 'mihaileni', 'vardo', 'buchanan', 'tumannyy', 'carnarvon', 'tautira', 'canora', 'tucumcari', 'avera', 'talnakh', 'lolodorf', 'hobyo', 'tsihombe', 'sidi ali', 'ilulissat', 'mehamn', 'altamira', 'turukhansk', 'cabo san lucas', 'bairiki', 'piet retief', 'ketchikan', 'ribeira grande', 'aliverion', 'dosso', 'vestmanna', 'shu', 'khandyga', 'nara', 'olafsvik', 'caravelas', 'mahajanga', 'yankton', 'griffith', 'san quintin', 'ancud', 'leningradskiy', 'nanortalik', 'ayoquezco', 'marang', 'tebingtinggi', 'clyde river', 'varhaug', 'eureka', 'ayorou', 'dunedin', 'caibarien', 'henties bay', 'butaritari', 'lyuban', 'nguiu', 'felidhoo', 'keskin', 'geraldton', 'torbay', 'jalu', 'sakakah', 'tarauaca', 'tuktoyaktuk', 'cervo', 'victoria', 'sentyabrskiy', 'kutum', 'guisa', 'tommot', 'aykhal', 'ginir', 'san bartolome de tirajana', 'raga', 'sao joao da barra', 'saint anthony', 'half moon bay', 'chara', 'tarko-sale', ...

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
import json
import requests

from api_keys import weather_api_key
from urllib.error import HTTPError
#weather_api_key = a48e24767ec9494ca8be13ca3d87fa76
# Build query URL
query_url = f"http://api.openweathermap.org/data/2.5/weather?appid="+ weather_api_key +"&units=imperial&q="

# Lists for the dataframe
citylist = []
cloudiness = []
dates = []
humidity = []
lats = []
longs = []
max_temps = []
windspeeds = []
countries = []

# Initial counters
counter = 0

# Loop for calling data city by city
for city in cities:
    try:
        response = requests.get(query_url + city.replace(" ","&")).json()
        cloudiness.append(response['clouds']['all'])
        dates.append(response['dt'])
        humidity.append(response['main']['humidity'])
        lats.append(response['coord']['lat'])
        longs.append(response['coord']['lon'])
        max_temps.append(response['main']['temp_max'])
        windspeeds.append(response['wind']['speed'])
        countries.append(response['sys']['country'])
        citylist.append(city)
        counter = counter + 1   
        
        print(f"Processing Record {counter} | {city}")
    except Exception:
        print("City way too small for wx data. Skipping...")
# Out:
# Processing Record 1 | rikitea
# City way too small for wx data. Skipping...
# Processing Record 2 | severo-kurilsk
# City way too small for wx data. Skipping...
# City way too small for wx data. Skipping...
# Processing Record 3 | mataura
# Processing Record 4 | san carlos de bariloche
# Processing Record 5 | puerto ayora
# Processing Record 6 | noumea
# Processing Record 7 | khatanga
# Processing Record 8 | cape town
# Processing Record 9 | bluff
# Processing Record 10 | yellowknife
# Processing Record 11 | sulangan
# City way too small for wx data. Skipping...
# Processing Record 12 | pingliang
# Processing Record 13 | port elizabeth
# City way too small for wx data. Skipping...
# Processing Record 14 | parana
# Processing Record 15 | airai
# Processing Record 16 | leh
# Processing Record 17 | hermanus
# Processing Record 18 | izhmorskiy
# City way too small for wx data. Skipping...
# Processing Record 19 | isangel
# Processing Record 20 | sinnamary
# Processing Record 21 | hayvoron
# Processing Record 22 | pryozerne
# Processing Record 23 | faanui
# Processing Record 24 | kyabram
# City way too small for wx data. Skipping...
# Processing Record 25 | pinega
# Processing Record 26 | kaili
# Processing Record 27 | qaanaaq
# Processing Record 28 | kavieng
# Processing Record 29 | petropavlovsk-kamchatskiy
# Processing Record 30 | imeni poliny osipenko
# Processing Record 31 | vila franca do campo
# Processing Record 32 | chuy
# Processing Record 33 | nikolskoye
# Processing Record 34 | goderich
# Processing Record 35 | ponta do sol
# Processing Record 36 | busselton
# Processing Record 37 | pisco
# City way too small for wx data. Skipping...
# Processing Record 38 | burnie
# Processing Record 39 | luderitz
# Processing Record 40 | atuona
# City way too small for wx data. Skipping...
# City way too small for wx data. Skipping...
# Processing Record 41 | siilinjarvi
# Processing Record 42 | bethel
# Processing Record 43 | port alfred
# Processing Record 44 | akdepe
# Processing Record 45 | porbandar
# Processing Record 46 | cockburn town
# Processing Record 47 | olenino
# Processing Record 48 | ushuaia
# Processing Record 49 | bilma
# Processing Record 50 | tikrit
# Processing Record 51 | albany
# Processing Record 52 | grand river south east
# Processing Record 53 | san policarpo
# Processing Record 54 | atar
# Processing Record 55 | palmer
# Processing Record 56 | benguela
# Processing Record 57 | bredasdorp
# City way too small for wx data. Skipping...
# Processing Record 58 | kapaa
# Processing Record 59 | abha
# Processing Record 60 | lebu
# Processing Record 61 | punta arenas
# Processing Record 62 | palembang
# Processing Record 63 | lompoc
# Processing Record 64 | cherskiy
# Processing Record 65 | hithadhoo
# Processing Record 66 | bhusawal
# City way too small for wx data. Skipping...
# Processing Record 67 | mattru
# Processing Record 68 | maiduguri
# Processing Record 69 | chokurdakh
# Processing Record 70 | camopi
# Processing Record 71 | provideniya
# Processing Record 72 | bosaso
# Processing Record 73 | comodoro rivadavia
# Processing Record 74 | kosa
# City way too small for wx data. Skipping...
# Processing Record 75 | mandurah
# Processing Record 76 | garowe
# City way too small for wx data. Skipping...
# Processing Record 77 | nushki
# Processing Record 78 | georgetown
# Processing Record 79 | pacific grove
# City way too small for wx data. Skipping...
# Processing Record 80 | taltal
# Processing Record 81 | sesheke
# Processing Record 82 | castro alves
# City way too small for wx data. Skipping...
# Processing Record 83 | inhambane
# Processing Record 84 | east london
# Processing Record 85 | aksu
# Processing Record 86 | ayni
# Processing Record 87 | khorramshahr
# Processing Record 88 | filadelfia
# Processing Record 89 | mys shmidta
# Processing Record 90 | vallenar
# Processing Record 91 | nazarovo
# Processing Record 92 | ambilobe
# Processing Record 93 | amahai
# Processing Record 94 | college
# Processing Record 95 | barrow
# Processing Record 96 | huntington
# City way too small for wx data. Skipping...
# Processing Record 97 | rio grande
# City way too small for wx data. Skipping...
# Processing Record 98 | palaikastron
# Processing Record 99 | juybar
# Processing Record 100 | lagoa
# Processing Record 101 | tomatlan
# Processing Record 102 | jiujiang
# Processing Record 103 | rayadrug
# Processing Record 104 | gainsborough
# Processing Record 105 | mariveles
# Processing Record 106 | madingou
# Processing Record 107 | husavik
# Processing Record 108 | arequipa
# Processing Record 109 | komsomolskiy
# Processing Record 110 | asau
# Processing Record 111 | katsuura
# Processing Record 112 | jawhar
# Processing Record 113 | melilla
# Processing Record 114 | minas
# Processing Record 115 | port hedland
# Processing Record 116 | jamestown
# Processing Record 117 | vila velha
# Processing Record 118 | tasiilaq
# Processing Record 119 | mount isa
# Processing Record 120 | hobart
# Processing Record 121 | pecos
# Processing Record 122 | avarua
# Processing Record 123 | souillac
# Processing Record 124 | yuncheng
# City way too small for wx data. Skipping...
# Processing Record 125 | namatanai
# Processing Record 126 | krasnyy chikoy
# Processing Record 127 | new norfolk
# Processing Record 128 | qui nhon
# City way too small for wx data. Skipping...
# Processing Record 129 | kruisfontein
# Processing Record 130 | novyy urengoy
# Processing Record 131 | bambous virieux
# Processing Record 132 | ganzhou
# Processing Record 133 | westport
# Processing Record 134 | arraial do cabo
# Processing Record 135 | vaini
# Processing Record 136 | harper
# Processing Record 137 | praya
# Processing Record 138 | klaksvik
# Processing Record 139 | hilo
# Processing Record 140 | roma
# Processing Record 141 | iqaluit
# Processing Record 142 | east stroudsburg
# Processing Record 143 | ulagan
# Processing Record 144 | florianopolis
# Processing Record 145 | galesong
# Processing Record 146 | tilichiki
# Processing Record 147 | zanjan
# Processing Record 148 | acapulco
# Processing Record 149 | aswan
# Processing Record 150 | aalen
# Processing Record 151 | dingle
# Processing Record 152 | thompson
# Processing Record 153 | taywarah
# Processing Record 154 | kloulklubed
# Processing Record 155 | adeje
# Processing Record 156 | yola
# City way too small for wx data. Skipping...
# Processing Record 157 | constitucion
# Processing Record 158 | rudbar
# Processing Record 159 | mar del plata
# Processing Record 160 | salinas
# Processing Record 161 | alofi
# Processing Record 162 | kahului
# Processing Record 163 | hirara
# Processing Record 164 | shingu
# City way too small for wx data. Skipping...
# Processing Record 165 | kawalu
# Processing Record 166 | kieta
# Processing Record 167 | fare
# Processing Record 168 | grindavik
# Processing Record 169 | calvinia
# Processing Record 170 | aras
# Processing Record 171 | upernavik
# Processing Record 172 | fortuna
# Processing Record 173 | khushab
# Processing Record 174 | awjilah
# Processing Record 175 | mayo
# Processing Record 176 | haines junction
# Processing Record 177 | kodiak
# Processing Record 178 | srivardhan
# Processing Record 179 | gondanglegi
# Processing Record 180 | longyearbyen
# Processing Record 181 | sechura
# Processing Record 182 | muscat
# City way too small for wx data. Skipping...
# Processing Record 183 | kamojima
# Processing Record 184 | tiksi
# Processing Record 185 | tiznit
# Processing Record 186 | zhangjiakou
# City way too small for wx data. Skipping...
# Processing Record 187 | codrington
# Processing Record 188 | mecca
# Processing Record 189 | hamilton
# Processing Record 190 | kita
# Processing Record 191 | pacifica
# Processing Record 192 | dikson
# Processing Record 193 | praia da vitoria
# Processing Record 194 | rock sound
# Processing Record 195 | ahipara
# Processing Record 196 | sibolga
# Processing Record 197 | moroni
# Processing Record 198 | bartica
# Processing Record 199 | del rio
# Processing Record 200 | samarai
# Processing Record 201 | tuatapere
# Processing Record 202 | moerai
# Processing Record 203 | vila
# Processing Record 204 | kuusamo
# Processing Record 205 | igrim
# Processing Record 206 | makakilo city
# Processing Record 207 | kaitangata
# Processing Record 208 | floriano
# Processing Record 209 | astana
# Processing Record 210 | oranjemund
# Processing Record 211 | viedma
# Processing Record 212 | saint-philippe
# Processing Record 213 | santo antonio de padua
# Processing Record 214 | saskylakh
# Processing Record 215 | bontang
# Processing Record 216 | saldanha
# Processing Record 217 | salalah
# Processing Record 218 | bahia blanca
# City way too small for wx data. Skipping...
# Processing Record 219 | natal
# Processing Record 220 | udachnyy
# Processing Record 221 | cedar city
# Processing Record 222 | mihaileni
# Processing Record 223 | vardo
# Processing Record 224 | buchanan
# City way too small for wx data. Skipping...
# Processing Record 225 | carnarvon
# Processing Record 226 | tautira
# Processing Record 227 | canora
# Processing Record 228 | tucumcari
# Processing Record 229 | avera
# Processing Record 230 | talnakh
# Processing Record 231 | lolodorf
# Processing Record 232 | hobyo
# City way too small for wx data. Skipping...
# Processing Record 233 | sidi ali
# Processing Record 234 | ilulissat
# Processing Record 235 | mehamn
# Processing Record 236 | altamira
# Processing Record 237 | turukhansk
# Processing Record 238 | cabo san lucas
# Processing Record 239 | bairiki
# City way too small for wx data. Skipping...
# Processing Record 240 | ketchikan
# Processing Record 241 | ribeira grande
# City way too small for wx data. Skipping...
# Processing Record 242 | dosso
# Processing Record 243 | vestmanna
# Processing Record 244 | shu
# Processing Record 245 | khandyga
# Processing Record 246 | nara
# Processing Record 247 | olafsvik
# Processing Record 248 | caravelas
# Processing Record 249 | mahajanga
# Processing Record 250 | yankton
# Processing Record 251 | griffith
# Processing Record 252 | san quintin
# Processing Record 253 | ancud
# Processing Record 254 | leningradskiy
# Processing Record 255 | nanortalik
# City way too small for wx data. Skipping...
# Processing Record 256 | marang
# Processing Record 257 | tebingtinggi
# Processing Record 258 | clyde river
# Processing Record 259 | varhaug
# Processing Record 260 | eureka
# Processing Record 261 | ayorou
# Processing Record 262 | dunedin
# Processing Record 263 | caibarien
# City way too small for wx data. Skipping...
# Processing Record 264 | butaritari
# Processing Record 265 | lyuban
# City way too small for wx data. Skipping...
# City way too small for wx data. Skipping...
# Processing Record 266 | keskin
# Processing Record 267 | geraldton
# Processing Record 268 | torbay
# Processing Record 269 | jalu
# Processing Record 270 | sakakah
# Processing Record 271 | tarauaca
# Processing Record 272 | tuktoyaktuk
# Processing Record 273 | cervo
# Processing Record 274 | victoria
# City way too small for wx data. Skipping...
# Processing Record 275 | kutum
# Processing Record 276 | guisa
# Processing Record 277 | tommot
# Processing Record 278 | aykhal
# Processing Record 279 | ginir
# Processing Record 280 | san bartolome de tirajana
# Processing Record 281 | raga
# Processing Record 282 | sao joao da barra
# City way too small for wx data. Skipping...
# Processing Record 283 | half moon bay
# Processing Record 284 | chara
# Processing Record 285 | tarko-sale
# Processing Record 286 | hindoria
# City way too small for wx data. Skipping...
# Processing Record 287 | mahebourg
# Processing Record 288 | kirovsk
# Processing Record 289 | laguna
# Processing Record 290 | egvekinot
# Processing Record 291 | castro
# Processing Record 292 | arawa
# Processing Record 293 | lorengau
# City way too small for wx data. Skipping...
# Processing Record 294 | bilibino
# Processing Record 295 | povenets
# Processing Record 296 | west fargo
# Processing Record 297 | turbat
# Processing Record 298 | huallanca
# Processing Record 299 | kedrovyy
# Processing Record 300 | nurota
# Processing Record 301 | tongren
# City way too small for wx data. Skipping...
# Processing Record 302 | pritomskiy
# City way too small for wx data. Skipping...
# Processing Record 303 | cabinda
# Processing Record 304 | espanola
# Processing Record 305 | slawno
# Processing Record 306 | lodwar
# Processing Record 307 | verkhneyarkeyevo
# Processing Record 308 | zarubino
# City way too small for wx data. Skipping...
# Processing Record 309 | krasnoselkup
# Processing Record 310 | valparaiso
# Processing Record 311 | northam
# Processing Record 312 | werota
# Processing Record 313 | pevek
# Processing Record 314 | mitu
# Processing Record 315 | tena
# Processing Record 316 | dwarka
# Processing Record 317 | mpongwe
# Processing Record 318 | mount gambier
# Processing Record 319 | peniche
# City way too small for wx data. Skipping...
# Processing Record 320 | arman
# Processing Record 321 | honningsvag
# Processing Record 322 | birin
# Processing Record 323 | davila
# Processing Record 324 | parkhill
# Processing Record 325 | podolinec
# Processing Record 326 | phan rang
# Processing Record 327 | churapcha
# Processing Record 328 | nouadhibou
# Processing Record 329 | russell
# Processing Record 330 | port blair
# Processing Record 331 | virginia beach
# Processing Record 332 | nantucket
# Processing Record 333 | san ignacio
# Processing Record 334 | hofn
# Processing Record 335 | camargo
# Processing Record 336 | liverpool
# Processing Record 337 | kununurra
# Processing Record 338 | karpogory
# Processing Record 339 | nemuro
# Processing Record 340 | sur
# Processing Record 341 | fort nelson
# Processing Record 342 | aqtobe
# Processing Record 343 | kapit
# City way too small for wx data. Skipping...
# Processing Record 344 | bandarbeyla
# Processing Record 345 | lavrentiya
# Processing Record 346 | mujiayingzi
# Processing Record 347 | bertoua
# Processing Record 348 | vao
# Processing Record 349 | namibe
# Processing Record 350 | robertsport
# Processing Record 351 | bulnes
# Processing Record 352 | bocas del toro
# Processing Record 353 | luohe
# Processing Record 354 | deputatskiy
# Processing Record 355 | lasa
# Processing Record 356 | madridejos
# Processing Record 357 | yeniseysk
# Processing Record 358 | jumla
# Processing Record 359 | tabas
# Processing Record 360 | felanitx
# Processing Record 361 | taoudenni
# Processing Record 362 | puerto narino
# Processing Record 363 | yaan
# Processing Record 364 | coquimbo
# Processing Record 365 | port lincoln
# Processing Record 366 | gorontalo
# Processing Record 367 | haimen
# Processing Record 368 | tigil
# Processing Record 369 | tripoli
# Processing Record 370 | reconquista
# Processing Record 371 | meulaboh
# Processing Record 372 | miandrivazo
# Processing Record 373 | nome
# Processing Record 374 | dillon
# Processing Record 375 | nueva granada
# Processing Record 376 | akureyri
# Processing Record 377 | bakchar
# Processing Record 378 | cenei
# Processing Record 379 | taseyevo
# City way too small for wx data. Skipping...
# Processing Record 380 | kumluca
# Processing Record 381 | jieshi
# Processing Record 382 | bouca
# Processing Record 383 | sao miguel do araguaia
# Processing Record 384 | shubarkuduk
# Processing Record 385 | jinchang
# Processing Record 386 | colares
# Processing Record 387 | ulmeni
# Processing Record 388 | pareora
# City way too small for wx data. Skipping...
# Processing Record 389 | pangai
# Processing Record 390 | adana
# Processing Record 391 | grand gaube
# City way too small for wx data. Skipping...
# Processing Record 392 | teya
# Processing Record 393 | zolotukhino
# Processing Record 394 | esperance
# Processing Record 395 | virden
# Processing Record 396 | meadow lake
# Processing Record 397 | narsaq
# Processing Record 398 | kumano
# Processing Record 399 | tsabong
# Processing Record 400 | kindersley
# Processing Record 401 | andenes
# Processing Record 402 | lovozero
# Processing Record 403 | phangnga
# Processing Record 404 | tahoua
# Processing Record 405 | hovd
# Processing Record 406 | rochegda
# Processing Record 407 | cambrils
# Processing Record 408 | kansanshi
# Processing Record 409 | mokhsogollokh
# Processing Record 410 | tateyama
# Processing Record 411 | lloydminster
# Processing Record 412 | lofthus
# Processing Record 413 | wakkanai
# Processing Record 414 | banjar
# Processing Record 415 | ialibu
# Processing Record 416 | novomikhaylovskiy
# Processing Record 417 | sao filipe
# Processing Record 418 | maunabo
# Processing Record 419 | ostrovnoy
# Processing Record 420 | atasu
# Processing Record 421 | ambanja
# Processing Record 422 | pervomayskiy
# Processing Record 423 | saint-francois
# Processing Record 424 | nabire
# City way too small for wx data. Skipping...
# Processing Record 425 | beaverlodge
# Processing Record 426 | yambio
# Processing Record 427 | pangnirtung
# Processing Record 428 | balad
# Processing Record 429 | touho
# Processing Record 430 | takoradi
# Processing Record 431 | champerico
# Processing Record 432 | kanelovskaya
# Processing Record 433 | berdigestyakh
# Processing Record 434 | nioro
# Processing Record 435 | slatina
# Processing Record 436 | mayya
# Processing Record 437 | pauini
# Processing Record 438 | dongying
# City way too small for wx data. Skipping...
# Processing Record 439 | beidao
# City way too small for wx data. Skipping...
# Processing Record 440 | jiuquan
# Processing Record 441 | mount pleasant
# Processing Record 442 | monte cristi
# Processing Record 443 | beringovskiy
# Processing Record 444 | freetown
# Processing Record 445 | praia
# Processing Record 446 | madang
# Processing Record 447 | norman wells
# Processing Record 448 | sonamukhi
# Processing Record 449 | shimoda
# Processing Record 450 | bonavista
# Processing Record 451 | kaeo
# Processing Record 452 | balkhash
# City way too small for wx data. Skipping...
# Processing Record 453 | westerly
# Processing Record 454 | campo largo
# Processing Record 455 | tsiroanomandidy
# Processing Record 456 | brae
# Processing Record 457 | oussouye
# Processing Record 458 | oktyabrskiy
# City way too small for wx data. Skipping...
# Processing Record 459 | guadalupe y calvo
# Processing Record 460 | beloha
# Processing Record 461 | yulara
# Processing Record 462 | matara
# Processing Record 463 | drumnadrochit
# Processing Record 464 | krasnyy oktyabr
# Processing Record 465 | saint-pierre
# Processing Record 466 | kailua
# Processing Record 467 | riyadh
# Processing Record 468 | goma
# Processing Record 469 | solnechnyy
# Processing Record 470 | upata
# Processing Record 471 | evensk
# Processing Record 472 | acarau
# Processing Record 473 | abrau-dyurso
# Processing Record 474 | xining
# Processing Record 475 | eidfjord
# Processing Record 476 | boa esperanca
# Processing Record 477 | christchurch
# City way too small for wx data. Skipping...
# Processing Record 478 | magadan
# City way too small for wx data. Skipping...
# City way too small for wx data. Skipping...
# Processing Record 479 | richards bay
# Processing Record 480 | angoche
# Processing Record 481 | dabakala
# Processing Record 482 | tamworth
# Processing Record 483 | marrakesh
# Processing Record 484 | sochi
# City way too small for wx data. Skipping...
# Processing Record 485 | ourem
# Processing Record 486 | poronaysk
# Processing Record 487 | hambantota
# Processing Record 488 | ibra
# Processing Record 489 | ubinskoye
# Processing Record 490 | hillsborough
# Processing Record 491 | oriximina
# Processing Record 492 | buta
# City way too small for wx data. Skipping...
# Processing Record 493 | voi
# Processing Record 494 | flin flon
# Processing Record 495 | riachao das neves
# Processing Record 496 | trimbak
# Processing Record 497 | zhigansk
# City way too small for wx data. Skipping...
# Processing Record 498 | toora-khem
# Processing Record 499 | sept-iles
# Processing Record 500 | cidreira
# Processing Record 501 | zhangye
# Processing Record 502 | kemijarvi
# Processing Record 503 | santa maria
# Processing Record 504 | naze
# City way too small for wx data. Skipping...
# Processing Record 505 | ukiah
# Processing Record 506 | kushiro
# Processing Record 507 | zhuhai
# Processing Record 508 | danielskuil
# Processing Record 509 | san cristobal
# Processing Record 510 | ardakan
# Processing Record 511 | tashla
# Processing Record 512 | port hardy
# Processing Record 513 | monywa
# Processing Record 514 | ouesso
# Processing Record 515 | belmonte
# Processing Record 516 | concordia
# Processing Record 517 | calatayud
# Processing Record 518 | paamiut
# Processing Record 519 | qeshm
# Processing Record 520 | ushibuka
# Processing Record 521 | yamada
# Processing Record 522 | burgersdorp
# Processing Record 523 | psebay
# City way too small for wx data. Skipping...
# Processing Record 524 | pitiquito
# Processing Record 525 | buzdyak
# Processing Record 526 | paita
# Processing Record 527 | faya
# Processing Record 528 | stawell
# Processing Record 529 | barkhan
# Processing Record 530 | canavieiras
# Processing Record 531 | ust-kuyga
# Processing Record 532 | san fernando
# Processing Record 533 | necochea
# Processing Record 534 | katherine
# Processing Record 535 | taraz
# Processing Record 536 | saryozek
# Processing Record 537 | tabou
# Processing Record 538 | xuddur
# Processing Record 539 | haverfordwest
# Processing Record 540 | acari
# Processing Record 541 | bengkulu
# Processing Record 542 | plettenberg bay
# Processing Record 543 | kavaratti
# Processing Record 544 | pando
# City way too small for wx data. Skipping...
# Processing Record 545 | moose factory
# Processing Record 546 | lubao
# Processing Record 547 | gilbues
# Processing Record 548 | buraydah
# Processing Record 549 | bukama
# Processing Record 550 | yayva
# Processing Record 551 | abu kamal
# Processing Record 552 | innisfail
# Processing Record 553 | otane
# City way too small for wx data. Skipping...
# Processing Record 554 | anadyr
# Processing Record 555 | albert town
# Processing Record 556 | guerrero negro
# Processing Record 557 | palauig
# Processing Record 558 | galiakot
# Processing Record 559 | salamiyah
# Processing Record 560 | malinovskiy
# Processing Record 561 | maniitsoq
# Processing Record 562 | guarapari
# Processing Record 563 | catuday

# %%
# Data retrieval verification

print(f"The windspeed information received is: {windspeeds}")
# Out:
# The windspeed information received is: [16.33, 22.55, 15.01, 10.71, 3.36, 5.82, 1.68, 11.41, 15.01, 4.7, 6.44, 1.99, 8.55, 5.44, 2.71, 4.47, 3.51, 10.27, 15.95, 9.13, 10.27, 3.56, 17.07, 5.01, 10.67, 2.3, 3.38, 4.36, 8.95, 3.62, 7, 8.21, 8.95, 10.29, 21.16, 5.01, 20.8, 15.99, 11.97, 17.76, 11.41, 4.7, 9.26, 9.17, 8.21, 18.34, 7.63, 9.17, 6.85, 8.23, 3.36, 3.36, 11.16, 10.87, 4.38, 4.25, 3.36, 8.05, 1.05, 13.53, 7.78, 4.7, 8.05, 4.25, 9.19, 4.52, 1.5, 7.05, 3.27, 3.31, 4.47, 4.85, 4.07, 4.18, 1.01, 8.88, 0.63, 6.73, 2.51, 2.8, 2.26, 3.76, 6.04, 5.82, 0.98, 4.61, 4.25, 9.17, 5.79, 4.63, 4.38, 1.83, 0.92, 4.7, 13.87, 6.93, 6.93, 15.19, 6.44, 22.32, 3.4, 4.68, 4.65, 6.93, 12.62, 0.72, 6.93, 11.41, 2.24, 3.42, 11.41, 12.46, 10.29, 3.36, 8.55, 9.17, 7, 4.34, 1.01, 19.46, 5.82, 10.29, 12.75, 0.78, 5.37, 10.09, 1.03, 12.75, 1.01, 6.71, 12.75, 2.8, 9.17, 13.87, 14.99, 6.4, 19.46, 18.34, 11.41, 4.7, 12.75, 5.82, 2.51, 8.05, 5.82, 11.01, 4.7, 8.05, 7.87, 3, 3.96, 8.05, 3.04, 6.93, 6.93, 2.82, 17.54, 4.41, 13.87, 11.41, 23.04, 10.29, 8.05, 6.93, 0.96, 6.58, 17.45, 19.46, 1.59, 6.93, 8.93, 1.01, 3, 11.86, 6.89, 12.75, 10.29, 5.26, 3.91, 11.41, 17.13, 3.36, 11.41, 10.71, 2.59, 3.62, 17.22, 0.87, 3.36, 5.03, 5.82, 3.18, 19.46, 4.81, 13.35, 3.02, 4.03, 4.7, 6.93, 7.83, 15.01, 12.77, 7, 10.29, 6.42, 5.82, 11.01, 3.4, 4.47, 6.78, 14.63, 12.75, 5.95, 14.85, 3.13, 5.82, 16.11, 2.98, 6.93, 4.47, 3.36, 10.29, 31.92, 6.46, 14.99, 14.99, 2.24, 3.36, 3.36, 6.71, 2.19, 16.98, 2.62, 2.24, 16.11, 1.74, 6.98, 6.93, 10.29, 4.7, 8.05, 8.3, 18.34, 2.73, 0.63, 1.12, 33.71, 13.27, 2.24, 3.36, 3.27, 11.16, 3.36, 2.28, 6.6, 2.24, 2.24, 2.98, 6.93, 7, 9.28, 15.99, 3.36, 10.74, 11.74, 1.01, 2.24, 14.99, 10.87, 6.6, 3.09, 4.7, 18.99, 5.01, 8.63, 5.82, 0.65, 4.47, 5.93, 10.71, 3.09, 7.18, 3.58, 2.01, 14.05, 0.31, 12.75, 14.34, 5.82, 1.48, 3.06, 4.32, 4.34, 4.07, 10.8, 4.7, 16.89, 4.41, 2.24, 2.24, 1.54, 2.44, 1.59, 5.82, 7.25, 8.9, 5.75, 7.61, 9.1, 18.34, 14, 4.21, 2.17, 1.74, 2.24, 10, 4.03, 1.01, 18.01, 8.05, 16.11, 3.18, 3.36, 11.01, 4.7, 2.01, 2.39, 18.34, 3.94, 9.26, 6.98, 9.17, 10.71, 9.75, 4.21, 12.75, 5.82, 7.81, 5.82, 5.03, 7.45, 1.16, 0.96, 15.57, 7.45, 9.04, 1.66, 15.05, 8.61, 7.7, 11.41, 5.82, 3.53, 2.06, 8.05, 1.01, 3, 3.51, 2.24, 3.36, 10.83, 3.36, 9.15, 9.17, 8.55, 0.87, 5.97, 6.73, 20.85, 7.23, 4.41, 3.98, 11.41, 4.7, 14.99, 6.93, 7.7, 12.75, 2.93, 6.06, 1.99, 2.53, 7.18, 3.47, 3.38, 14, 12.75, 7.4, 18.34, 2.24, 3.36, 4.03, 10.51, 18.34, 3.29, 6.2, 17.22, 1.12, 9.66, 13.87, 17.22, 5.91, 4.7, 2.24, 0.94, 4.99, 12.75, 2.68, 1.34, 11.41, 14.99, 1.01, 2.24, 11.41, 3.18, 6.98, 7.45, 3.18, 29.15, 3.11, 2.75, 7.92, 4.7, 3.06, 6.93, 1.95, 6.93, 4.52, 15.55, 9.08, 4.7, 15.12, 2.35, 7.43, 12.75, 2.24, 1.81, 5.14, 1.59, 2.98, 1.01, 4.7, 2.06, 4.47, 19.46, 4.63, 5.82, 4.23, 14.99, 6.93, 15.99, 5.23, 3.36, 13.87, 1.5, 24.16, 4.7, 4.47, 6.93, 11.03, 5.82, 5.3, 4.07, 10.09, 12.75, 4.7, 3.42, 3.44, 2.53, 4, 15.23, 15.28, 6.71, 1.88, 5.84, 3.2, 16.11, 7.25, 4.7, 4.72, 5.73, 10.29, 2.24, 11.18, 8.1, 3.96, 8.97, 3.74, 12.15, 5.82, 1.79, 1.59, 2.37, 3.36, 3.69, 4, 2.48, 1.45, 1.12, 7.38, 5.03, 13, 3.44, 11.41, 4.7, 1.12, 9.17, 2.46, 10.71, 2.24, 6.55, 8.55, 3.6, 2.86, 8.05, 6.06, 5.82, 5.44, 6.93, 7.92, 6.49, 4.27, 3.04, 3, 5.97, 12.75, 1.39, 17.45, 1.41, 9.62, 7.31, 11.16, 7.52, 4.7, 2.24, 1.41, 6.22, 15.99, 13.87, 4.18, 3.33, 2.39, 14.16, 5.82, 3.89, 7.05, 1.16, 11.41, 0.89, 3.33, 5.06, 6.46, 9.98, 8.95, 14.99, 0.56, 3.51, 5.44, 1.16, 7.47, 1.61, 4.7, 9.17]

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#Create a dataframe to store the data
wx = {"City":citylist,"Lat":lats,"Long":longs,"Cloudiness":cloudiness,"Humidity":humidity,"Max Temp":max_temps,"Wind Speed":windspeeds, "Date":dates,}

weather_df = pd.DataFrame(wx)
weather_df.to_csv(r'output_data/cities.csv', index=False)

# %%
#Preview the dataframe
weather_df.head()
# Out:
#                       City    Lat    Long  Cloudiness  Humidity  Max Temp  \
# 0                  rikitea -23.12 -134.97          51        79     77.81
# 1           severo-kurilsk  50.68  156.12          74        86     26.96
# 2                  mataura -46.19  168.86          99        69     64.00
# 3  san carlos de bariloche  13.30   -4.90           0        21     75.81
# 4             puerto ayora  36.59   -6.23          40        93     59.00
#
#    Wind Speed        Date
# 0       16.33  1607558690
# 1       22.55  1607558690
# 2       15.01  1607558691
# 3       10.71  1607558557
# 4        3.36  1607558692

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
weather_df.sort_values(by=['Humidity'], ascending=False)
# Out:
#           City    Lat    Long  Cloudiness  Humidity  Max Temp  Wind Speed  \
# 385    colares  38.80   -9.45          85       100     60.01       14.00
# 325  phan rang  19.55   99.74          60       100     57.20        2.01
# 434    slatina  44.43   24.37          90       100     35.01       12.75
# 162     hirara  24.80  125.28          75       100     71.60        8.05
# 61   palembang  -2.92  104.75          40       100     77.00        4.70
# ..         ...    ...     ...         ...       ...       ...         ...
# 241      dosso  13.05    3.19           8        17     77.72        8.30
# 303   espanola  35.99 -106.08           1        16     53.60        5.82
# 120      pecos  31.42 -103.49           1        14     69.80        5.82
# 227  tucumcari  35.17 -103.72           1        13     62.60        3.36
# 109       asau  46.43   26.40         100        13     30.00        3.42
#
#            Date
# 385  1607558783
# 325  1607558770
# 434  1607558793
# 162  1607558729
# 61   1607558707
# ..          ...
# 241  1607558746
# 303  1607558577
# 120  1607558721
# 227  1607558743
# 109  1607558719
#
# [563 rows x 8 columns]

# %%
#  Get the indices of cities that have humidity over 100%.
weather_df[weather_df['Humidity'] == 100]
# Out:
#               City    Lat    Long  Cloudiness  Humidity  Max Temp  Wind Speed  \
# 61       palembang  -2.92  104.75          40       100     77.00        4.70
# 162         hirara  24.80  125.28          75       100     71.60        8.05
# 198        del rio  38.79   45.07          90       100     33.80        6.93
# 221      mihaileni  47.97   26.15          90       100     30.99       10.29
# 239      ketchikan  55.34 -131.65          40       100     39.20        4.70
# 256   tebingtinggi   3.33   99.16          40       100     75.20        2.24
# 325      phan rang  19.55   99.74          60       100     57.20        2.01
# 377          cenei  45.72   20.90          90       100     43.00       12.75
# 385        colares  38.80   -9.45          85       100     60.01       14.00
# 389          adana  36.98   35.29          13       100     46.40        2.24
# 417        maunabo  18.01  -65.90          24       100     78.01        3.18
# 434        slatina  44.43   24.37          90       100     35.01       12.75
# 453    campo largo  41.19   -8.46          75       100     59.00       13.87
# 538  haverfordwest  51.80   -4.97         100       100     46.40       13.87
# 554    albert town  50.00    2.65          90       100     35.60       14.99
#
#            Date
# 61   1607558707
# 162  1607558729
# 198  1607558737
# 221  1607558741
# 239  1607558525
# 256  1607558749
# 325  1607558770
# 377  1607558780
# 385  1607558783
# 389  1607558784
# 417  1607558790
# 434  1607558793
# 453  1607558798
# 538  1607558816
# 554  1607558819

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.

clean_weather_df = weather_df[weather_df['Humidity'] != 100]
clean_weather_df.sort_values(by=['Humidity'], ascending=False)
# Out:
#                       City    Lat    Long  Cloudiness  Humidity  Max Temp  \
# 72      comodoro rivadavia -13.66  -59.79          90        98     69.42
# 34            ponta do sol  38.73  -28.27          99        97     59.32
# 145              tilichiki  60.47  166.10          97        97     10.92
# 29   imeni poliny osipenko   7.32    5.96         100        97     72.82
# 149                  aalen  48.84   10.09         100        97     30.00
# ..                     ...    ...     ...         ...       ...       ...
# 241                  dosso  13.05    3.19           8        17     77.72
# 303               espanola  35.99 -106.08           1        16     53.60
# 120                  pecos  31.42 -103.49           1        14     69.80
# 109                   asau  46.43   26.40         100        13     30.00
# 227              tucumcari  35.17 -103.72           1        13     62.60
#
#      Wind Speed        Date
# 72         4.07  1607558710
# 34        21.16  1607558699
# 145       11.01  1607558726
# 29         3.62  1607558698
# 149        3.00  1607558727
# ..          ...         ...
# 241        8.30  1607558746
# 303        5.82  1607558577
# 120        5.82  1607558721
# 109        3.42  1607558719
# 227        3.36  1607558743
#
# [548 rows x 8 columns]

# %%
clean_weather_df.sort_values(by=['Max Temp'], ascending=False)
# Out:
#               City    Lat    Long  Cloudiness  Humidity  Max Temp  Wind Speed  \
# 533      katherine -14.47  132.27          88        62     87.80        4.70
# 161        kahului  20.89 -156.47          40        45     87.80       10.29
# 5           noumea -22.28  166.46           2        62     87.01        5.82
# 291          arawa  -6.21  155.54          56        67     86.95        4.32
# 292       lorengau  -2.02  147.27          84        60     86.72        4.34
# ..             ...    ...     ...         ...       ...       ...         ...
# 432  berdigestyakh  62.10  126.70          16        82    -35.50        2.35
# 496       zhigansk  66.77  123.37          10        81    -38.16        2.48
# 277         aykhal  66.00  111.50           0        64    -41.80        4.47
# 219       udachnyy  66.42  112.40           0        64    -41.80        4.47
# 435          mayya  61.73  130.28          90        64    -43.60        2.24
#
#            Date
# 533  1607558815
# 161  1607558727
# 5    1607558582
# 291  1607558759
# 292  1607558759
# ..          ...
# 432  1607558581
# 496  1607558807
# 277  1607558754
# 219  1607558741
# 435  1607558794
#
# [548 rows x 8 columns]

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# Plotting cities by Lat and Long and visualizing tempertaure by color gave a more useful plot 
#    than latitude and tempertaure alone.

# Extract the data we're interested in
Lat, Long = clean_weather_df['Lat'], clean_weather_df['Long']
temperature = clean_weather_df['Max Temp']

# Scatter the points, using temperature color
plt.scatter(Long, Lat, label=None,
            c=temperature, cmap='rainbow',
            linewidth=0, alpha=0.5)

# Title and Labels
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.colorbar(label='Temperature')
plt.clim(-40, 110)
 
plt.title(f'Latitude vs Temperature (F)  {time.strftime("%m/%d/%Y")}');

# Save the figure
plt.savefig('Latitude vs.Temperature v1.png')

# %%
#'Latitude vs Temperature (F)' utlizes color to show maximum temperature distribution 
#   by Latitude, and, to a lesser degree, by Longitude. As expected the bands are relatively 
#   uniform horizontally with the exception of some longitudes with particularly cooler temperatures.

# %%
# Build a boring, less useful scatter plot 'Latitude vs.Temperature (F)'

# Number of cities in cleaned dataframe
n = len(clean_weather_df. index)
t= np.arange(n)  # color scale matched with number of data points

plt.scatter(clean_weather_df['Lat'], clean_weather_df['Max Temp'], s=5, c=t)

# Title and Labels
plt.xlabel('Latitude')
plt.ylabel('Temperature (F)')
plt.title(f'Latitude vs.Temperature (F) {time.strftime("%m/%d/%Y")}')

plt.grid(True)

# Save the figure
plt.savefig('Latitude vs.Temperature v2.png')

plt.show()

# %%
#'Latitude vs Temperature (F)' utlizes color to show maximum temperature distribution 
#   by Latitude. This is a less visually educational plot because all latitudes are 
#   grouped together but the colors do show temperature distribution.

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# Plotting cities by Lat and Long and visualizing humidity by color gave a more useful plot 
#    than latitude and tempertaure alone.
# Two dimensional scatterplot located in regression section.

# Extract the data we're interested in
Lat, Long = clean_weather_df['Lat'], clean_weather_df['Long']
hum = clean_weather_df['Humidity']

# Scatter the points, using Humidity
plt.scatter(Long, Lat, label=None,
            c=hum, cmap='rainbow',
            linewidth=0, alpha=0.5)

plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.colorbar(label='Humidity %')
plt.clim(0, 100)
 
plt.title(f'Latitude vs Humidity %  {time.strftime("%m/%d/%Y")}');

# Save the figure
plt.savefig('Latitude vs.Humidity.png')

# %%
#'Latitude vs Humidity %' utlizes color to show humidity % distribution 
#   by Latitude, and, to a lesser degree, by Longitude. The plot visually
#   confers that humidity is not determined by latitude alone...longitude
#   plays an important role in the humidity a city will experience.

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# Plotting cities by Lat and Long and visualizing cloudiness by color gave a more useful plot 
#    than latitude and tempertaure alone.
# Two dimensional scatterplot located in regression section.

# Extract the data we're interested in
Lat, Long = clean_weather_df['Lat'], clean_weather_df['Long']
cloud = clean_weather_df['Cloudiness']

# Scatter the points, using Cloudiness
plt.scatter(Long, Lat, label=None,
            c=cloud, cmap='binary',
            linewidth=0, alpha=0.5)

plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.colorbar(label='Cloudiness %')
plt.clim(0, 100)
 
plt.title(f'Latitude vs Cloudiness %  {time.strftime("%m/%d/%Y")}');

# Save the figure
plt.savefig('Latitude vs.Cloudiness.png')

# %%
#'Latitude vs Cloudiness %' utlizes color to show cloudiness % distribution 
#   by Latitude, and, to a lesser degree, by Longitude. The plot visually
#   confers that cloudiness is not primarily determined by latitude...longitude
#   appears to be the primary determinant of cloudiness.

# %%
clean_weather_df.sort_values(by=['Wind Speed'], ascending=False)
# Out:
#                City    Lat    Long  Cloudiness  Humidity  Max Temp  \
# 246        olafsvik  64.89  -23.71         100        91     34.14
# 222           vardo  70.37   31.11         100        90     33.78
# 418       ostrovnoy  68.05   39.51           7        95     25.12
# 455            brae  60.40   -1.35          51        70     46.40
# 160           alofi -19.06 -169.92          75        74     84.20
# ..              ...    ...     ...         ...       ...       ...
# 276          tommot  58.96  126.29          99        90     -2.16
# 76           nushki  29.55   66.02           2        54     48.72
# 244        khandyga  62.67  135.60          89        79    -28.03
# 555  guerrero negro  17.67 -100.00          15        66     68.61
# 285        hindoria  23.90   79.57          16        53     59.45
#
#      Wind Speed        Date
# 246       33.71  1607558747
# 222       31.92  1607558569
# 418       29.15  1607558790
# 455       24.16  1607558532
# 160       23.04  1607558729
# ..          ...         ...
# 276        0.65  1607558754
# 76         0.63  1607558711
# 244        0.63  1607558747
# 555        0.56  1607558779
# 285        0.31  1607558756
#
# [548 rows x 8 columns]

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# Plotting cities by Lat and Long and visualizing wind speed by color gave a more useful plot 
#    than latitude and tempertaure alone.
# Two dimensional scatterplot located in regression section.

# Extract the data we're interested in
Lat, Long = clean_weather_df['Lat'], clean_weather_df['Long']
wind = clean_weather_df['Wind Speed']

# Scatter the points, using temperature color
plt.scatter(Long, Lat, label=None,
            c=wind, cmap='Blues',
            linewidth=0, alpha=0.5)

plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.colorbar(label='Wind Speed (mph)')
plt.clim(0, 40)
 
plt.title(f'Latitude vs Wind Speed (mph) {time.strftime("%m/%d/%Y")}');

# Save the figure
plt.savefig('Latitude vs.Wind Speed.png')

# %%
#'Latitude vs Wind Speed' utlizes color to show wind speed distribution 
#   by Latitude, and, to a lesser degree, by Longitude. The plot visually
#   confers that wind speed is greater at the subtropical jets and indicated
#   by darker blue colors.

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Dataframe for Northern Hemisphere cities
northtemp_df = weather_df[weather_df['Lat'] >= 0]
northtemp_df.sort_values(by=['Lat'])
# Out:
#              City    Lat    Long  Cloudiness  Humidity  Max Temp  Wind Speed  \
# 214       bontang   0.13  117.50          85        81     80.29        3.13
# 365     gorontalo   0.54  123.06          25        73     84.51        0.87
# 313          mitu   1.20  -70.17          94        95     74.30        1.74
# 238       bairiki   1.33  172.98          75        74     86.00       10.29
# 513        ouesso   1.61   16.05         100        88     73.35        2.86
# ..            ...    ...     ...         ...       ...       ...         ...
# 6        khatanga  71.97  102.50          56        85    -31.86        1.68
# 170     upernavik  72.79  -56.15         100        96     23.76        8.93
# 191        dikson  73.51   80.55           4        87    -11.79        3.18
# 26        qaanaaq  77.48  -69.36         100        88      2.77        3.38
# 179  longyearbyen  78.22   15.64          75        79     26.60       11.41
#
#            Date
# 214  1607558740
# 365  1607558778
# 313  1607558766
# 238  1607558745
# 513  1607558746
# ..          ...
# 6    1607558692
# 170  1607558731
# 191  1607558736
# 26   1607558697
# 179  1607558733
#
# [416 rows x 8 columns]

# %%
# Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# Number of cities in cleaned northern hemisphere dataframe
n1 = len(northtemp_df. index)

t= np.arange(n1)  # Color scale matched with number of data points
plt.scatter(northtemp_df['Lat'], northtemp_df['Max Temp'], s=5, c=t)

# Title and Labels
plt.xlabel('Latitude')
plt.ylabel('Temperature (F)')
plt.title(f'Northern Latitudes vs.Temperature (F) {time.strftime("%m/%d/%Y")}')

plt.grid(True)

# Regression Line
x_values = northtemp_df['Lat']
y_values = northtemp_df['Max Temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(0,0),fontsize=15,color="darkblue")

# Print out the r-squared value along with the plot.
print(f"The r-squared is: {rvalue**2}")

# Save the figure
plt.savefig('N Latitude vs.Temperature.png')

plt.show()
# Out:
# The r-squared is: 0.7197451228197433

# %%
print('For every unit of change in latitude the temperature drops ' + str(round(slope,2)) +' units.') 
print('Approximately '+ str(round(rvalue**2,2)) + '% of the data fit into the model.')
# Out:
# For every unit of change in latitude the temperature drops -1.22 units.
# Approximately 0.72% of the data fit into the model.

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Dataframe for Southern Hemisphere cities
south_df = weather_df[weather_df['Lat'] <= 0]
south_df.sort_values(by=['Lat'])
# Out:
#                        City    Lat    Long  Cloudiness  Humidity  Max Temp  \
# 47                  ushuaia -54.80  -68.30          90        93     44.60
# 8                     bluff -46.60  168.33          84        69     64.00
# 206              kaitangata -46.28  169.85          66        70     62.01
# 2                   mataura -46.19  168.86          99        69     64.00
# 200               tuatapere -46.13  167.68          96        69     64.00
# ..                      ...    ...     ...         ...       ...       ...
# 374           nueva granada  -1.72  -79.83          75        55     86.00
# 467                    goma  -1.68   29.22          97        77     62.60
# 314                    tena  -0.98  -77.82          75        94     75.20
# 64                hithadhoo  -0.60   73.08          67        71     81.70
# 212  santo antonio de padua  -0.59  -80.00          95        84     75.33
#
#      Wind Speed        Date
# 47         9.17  1607558467
# 8         15.01  1607558693
# 206       11.01  1607558738
# 2         15.01  1607558691
# 200       15.01  1607558737
# ..          ...         ...
# 374       14.99  1607558780
# 467        3.44  1607558801
# 314        2.24  1607558767
# 64         9.19  1607558690
# 212        5.95  1607558740
#
# [147 rows x 8 columns]

# %%
# Southern Hemisphere - Max Temp vs. Latitude Linear Regression
# Number of cities in cleaned southern hemisphere dataframe
n2 = len(south_df. index)
t= np.arange(n2)  # Color scale matched with number of data points
plt.scatter(south_df['Lat'], south_df['Max Temp'], s=5, c=t)

# Title and Labels
plt.xlabel('Latitude')
plt.ylabel('Temperature (F)')
plt.title(f'Southern Latitudes vs.Temperature (F) {time.strftime("%m/%d/%Y")}')

plt.grid(True)

# Print out the r-squared value along with the plot.
print(f"The r-squared is: {rvalue**2}")

# Regression Line
x_values = south_df['Lat']
y_values = south_df['Max Temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-27,55),fontsize=15,color="darkblue")

# Save the figure
plt.savefig('S Latitude vs.Temperature Reg.png')

plt.show()
# Out:
# The r-squared is: 0.7197451228197433

# %%
print('For every unit of change in latitude the temperature rises.') 
print('A relatively high percentage of the data fit into the model as opposed to other regressions.')
# Out:
# For every unit of change in latitude the temperature rises.
# A relatively high percentage of the data fit into the model as opposed to other regressions.

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Northern Hemisphere - Humidity vs. Latitude Linear Regression

# Number of cities in cleaned northern hemisphere dataframe
n1 = len(northtemp_df. index)
t= np.arange(n1)  # Color scale matched with number of data points
plt.scatter(northtemp_df['Lat'], northtemp_df['Humidity'], s=5, c=t)

# Title and Labels
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.title(f'Northern Latitudes vs.Humidity {time.strftime("%m/%d/%Y")}')

plt.grid(True)

# Print out the r-squared value along with the plot.
print(f"The r-squared is: {rvalue**2}")

# Regression Line
x_values = northtemp_df['Lat']
y_values = northtemp_df['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(40,20),fontsize=15,color="darkblue")

# Save the figure
plt.savefig('N Latitude vs.Humidity Reg.png')

plt.show()
# Out:
# The r-squared is: 0.28691612921745957

# %%
print('For every unit of change in latitude the humidity rises.') 
print('There is a wide distribution of datapoints.')
print('The implication of the r-squared value is that the model offers poor predicatability of results.')
print('Visually this is observed in the wide scatter of datapoints.')
# Out:
# For every unit of change in latitude the humidity rises.
# There is a wide distribution of datapoints.
# The implication of the r-squared value is that the model offers poor predicatability of results.
# Visually this is observed in the wide scatter of datapoints.

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Southern Hemisphere - Humidity vs. Latitude Linear Regression
# Number of cities in cleaned southern hemisphere dataframe
n2 = len(south_df. index)
t= np.arange(n2)  # Color scale matched with number of data points
plt.scatter(south_df['Lat'], south_df['Humidity'], s=5, c=t)

# Title and Labels
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title(f'Southern Latitudes vs.Humidity (%) {time.strftime("%m/%d/%Y")}')

plt.grid(True)

# Print out the r-squared value along with the plot.
print(f"The r-squared is: {rvalue**2}")

# Regression Line
x_values = south_df['Lat']
y_values = south_df['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-55,22),fontsize=15,color="darkblue")

# Save the figure
plt.savefig('S Latitude vs.Humidity Reg.png')

plt.show()
# Out:
# The r-squared is: 0.13187323573929205

# %%
print('For every unit of change in latitude the humidity increases ' + str(round(slope,2)) +' units.') 
print('The implication of the r-squared value is that the model offers poor predicatability of results.')
print('Visually this is observed in the wide scatter of datapoints, eg high variance.')
# Out:
# For every unit of change in latitude the humidity increases 0.4 units.
# The implication of the r-squared value is that the model offers poor predicatability of results.
# Visually this is observed in the wide scatter of datapoints, eg high variance.

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Northern Hemisphere - Cloudiness vs. Latitude Linear Regression
# Number of cities in cleaned northern hemisphere dataframe
n1 = len(northtemp_df. index)
t= np.arange(n1)  # Color scale matched with number of data points
plt.scatter(northtemp_df['Lat'], northtemp_df['Cloudiness'], s=5, c=t)

# Title and Labels
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.title(f'Northern Latitudes vs.Cloudiness {time.strftime("%m/%d/%Y")}')

plt.grid(True)

# Print out the r-squared value along with the plot.
print(f"The r-squared is: {rvalue**2}")

# Regression Line
x_values = northtemp_df['Lat']
y_values = northtemp_df['Cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(45,40),fontsize=15,color="darkblue")

# Save the figure
plt.savefig('N Latitude vs.Cloudiness Reg.png')

plt.show()
# Out:
# The r-squared is: 0.13387837743414102

# %%
print('For every unit of change in latitude the cloudiness increases ' + str(round(slope,2)) +' units.') 
print('The implication of the r-squared value is that the model offers poor predicatability of results.')
print('Visually this is observed in the wide scatter of datapoints , eg high')
print('  variance, with large distributions at the extreme ends of the y-axis.')
# Out:
# For every unit of change in latitude the cloudiness increases 0.36 units.
# The implication of the r-squared value is that the model offers poor predicatability of results.
# Visually this is observed in the wide scatter of datapoints , eg high
#   variance, with large distributions at the extreme ends of the y-axis.

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression
# Number of cities in cleaned southern hemisphere dataframe
n2 = len(south_df. index)
t= np.arange(n2)  # Color scale matched with number of data points
plt.scatter(south_df['Lat'], south_df['Cloudiness'], s=5, c=t)

# Title and Labels
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title(f'Southern Latitudes vs.Cloudiness (%) {time.strftime("%m/%d/%Y")}')

plt.grid(True)

# Print out the r-squared value along with the plot.
print(f"The r-squared is: {rvalue**2}")

# Regression Line
x_values = south_df['Lat']
y_values = south_df['Cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-55,54),fontsize=15,color="darkblue")

# Save the figure
plt.savefig('S Latitude vs.Cloudiness Reg.png')

plt.show()
# Out:
# The r-squared is: 0.03386122095786471

# %%
print('For every unit of change in latitude the cloudiness increases ' + str(round(slope,2)) +' units.') 
print('The implication of the r-squared value is that the model offers poor predicatability of results.')
print('Visually this is observed in the wide scatter of datapoints , eg high')
print('  variance, with large distributions at the extreme ends of the y-axis.')
# Out:
# For every unit of change in latitude the cloudiness increases 0.96 units.
# The implication of the r-squared value is that the model offers poor predicatability of results.
# Visually this is observed in the wide scatter of datapoints , eg high
#   variance, with large distributions at the extreme ends of the y-axis.

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Northern Hemisphere - Wind Speed vs. Latitude Linear Regression
# Number of cities in cleaned northern hemisphere dataframe
n1 = len(northtemp_df. index)
t= np.arange(n1)  # Color scale matched with number of data points
plt.scatter(northtemp_df['Lat'], northtemp_df['Wind Speed'], s=5, c=t)

# Title and Labels
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title(f'Northern Latitudes vs.Wind Speed (mph) {time.strftime("%m/%d/%Y")}')

plt.grid(True)

# Print out the r-squared value along with the plot.
print(f"The r-squared is: {rvalue**2}")

# Regression Line
x_values = northtemp_df['Lat']
y_values = northtemp_df['Wind Speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(5,30),fontsize=15,color="darkblue")

# Save the figure
plt.savefig('N Latitude vs.Wind Speed Reg.png')

plt.show()
# Out:
# The r-squared is: 0.11894584858843896

# %%
print('For every unit of change in latitude the cloudiness increases ' + str(round(slope,2)) +' units...nearly a flat line.') 
print('The implication of the r-squared value is that the model offers poor predicatability of results.')
print('Visually this is observed in the wide scatter of datapoints , eg high')
print('  variance, with large distributions at the extreme ends of the y-axis.')
# Out:
# For every unit of change in latitude the cloudiness increases 0.03 units...nearly a flat line.
# The implication of the r-squared value is that the model offers poor predicatability of results.
# Visually this is observed in the wide scatter of datapoints , eg high
#   variance, with large distributions at the extreme ends of the y-axis.

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
# Number of cities in cleaned southern hemisphere dataframe
n2 = len(south_df. index)
t= np.arange(n2)  # Color scale matched with number of data points
plt.scatter(south_df['Lat'], south_df['Wind Speed'], s=5, c=t)

# Title and Labels
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title(f'Southern Latitudes vs.Wind Speed (mph) {time.strftime("%m/%d/%Y")}')

plt.grid(True)

# Print out the r-squared value along with the plot.
print(f"The r-squared is: {rvalue**2}")

# Regression Line
x_values = south_df['Lat']
y_values = south_df['Wind Speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-55,13),fontsize=15,color="darkblue")

# Save the figure
plt.savefig('S Latitude vs.Wind Speed Reg.png')

plt.show()
# Out:
# The r-squared is: 0.015934533207744284

# %%
print('For every unit of change in latitude the cloudiness increases ' + str(round(slope,2)) +' units.') 
print('The implication of the r-squared value is that the model offers poor predicatability of results.')
print('Visually this is observed in the wide scatter of datapoints , eg high')
print('  variance, with large distributions at the extreme ends of the y-axis.')
# Out:
# For every unit of change in latitude the cloudiness increases -0.15 units.
# The implication of the r-squared value is that the model offers poor predicatability of results.
# Visually this is observed in the wide scatter of datapoints , eg high
#   variance, with large distributions at the extreme ends of the y-axis.
