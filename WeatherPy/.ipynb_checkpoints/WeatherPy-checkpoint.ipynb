# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Print the city count to confirm sufficient count
print('There are',len(cities),'cities.')
# Out:
# There are 632 cities.

# %%
print(cities)
# Out:
# ['sibolga', 'rikitea', 'tsihombe', 'lais', 'leh', 'khonuu', 'cidreira', 'labuhan', 'port shepstone', 'teguldet', 'berlevag', 'ponta do sol', 'atuona', 'port elizabeth', 'hilo', 'veraval', 'ketchikan', 'attawapiskat', 'new norfolk', 'kapaa', 'tiksi', 'taolanaro', 'tiznit', 'dikson', 'busselton', 'vaini', 'coahuayana', 'qaanaaq', 'bluff', 'hobart', 'sainte-maxime', 'ushuaia', 'coalinga', 'cape town', 'la ligua', 'barrow', 'albany', 'palmer', 'port alfred', 'hithadhoo', 'lulea', 'cherskiy', 'nikolskoye', 'vermilion', 'imbituba', 'muros', 'saint george', 'belushya guba', 'salalah', 'salamanca', 'bubaque', 'saint-pierre', 'illoqqortoormiut', 'mataura', 'balotra', 'kysyl-syr', 'victoria', 'laguna', 'chapais', 'kavieng', 'boda', 'yellowknife', 'talnakh', 'praia da vitoria', 'colares', 'filingue', 'mahebourg', 'guerrero negro', 'harbour breton', 'kailua', 'arraial do cabo', 'torbay', 'punta arenas', 'balsas', 'boende', 'labutta', 'pevek', 'georgetown', 'mareeba', 'bom jesus', 'zhanakorgan', 'radovis', 'nanma', 'waipawa', 'saint-felicien', 'aykhal', 'streletskoye', 'provideniya', 'butaritari', 'iisalmi', 'salinopolis', 'thompson', 'port hardy', 'birganj', 'de-kastri', 'penzance', 'vao', 'dongsheng', 'gat', 'mys shmidta', 'mezen', 'bengkulu', 'byron bay', 'san vicente', 'carnarvon', 'chokurdakh', 'moba', 'hualmay', 'umzimvubu', 'yanan', 'ribeira grande', 'great falls', 'hermanus', 'chicama', 'homer', 'barnstaple', 'banda aceh', 'khatanga', 'dakar', 'grand river south east', 'cartagena del chaira', 'wichian buri', 'porto-vecchio', 'poya', 'birao', 'clyde river', 'haines junction', 'airai', 'nizhneyansk', 'fonte boa', 'avera', 'vanimo', 'nobres', 'ayan', 'lasa', 'cabedelo', 'juba', 'koungheul', 'wajima', 'mogadishu', 'jamestown', 'nayoro', 'utiroa', 'severo-kurilsk', 'kamenskoye', 'hasaki', 'bambous virieux', 'gobabis', 'alofi', 'vaitupu', 'castro', 'fort nelson', 'longyearbyen', 'cockburn town', 'karaton', 'mandalgovi', 'guilin', 'dolbeau', 'warrnambool', 'popondetta', 'vila franca do campo', 'coquimbo', 'avarua', 'koran', 'ust-omchug', 'sao joao da barra', 'margate', 'nome', 'saldanha', 'gurupi', 'lavrentiya', 'vardo', 'matara', 'mar del plata', 'fukue', 'nurota', 'upernavik', 'manaure', 'lebu', 'sovetskiy', 'otradnoye', 'richards bay', 'ahipara', 'sri aman', 'hohhot', 'hazorasp', 'puerto ayora', 'lengshuijiang', 'galle', 'los llanos de aridane', 'aljustrel', 'stolin', 'hearst', 'bonthe', 'marcona', 'sao gabriel da cachoeira', 'aripuana', 'safranbolu', 'kenai', 'ancud', 'shingu', 'nantucket', 'ternate', 'bethel', 'atar', 'maltahohe', 'okha', 'qaqortoq', 'dingle', 'tadine', 'soyo', 'iguape', 'nelson bay', 'east london', 'beruwala', 'pangnirtung', 'fortuna', 'emerald', 'te anau', 'bianzhuang', 'juazeiro', 'saint-philippe', 'maldonado', 'kibaya', 'chumikan', 'pisco', 'sena madureira', 'amderma', 'vila velha', 'asfi', 'sao filipe', 'nyuksenitsa', 'esperance', 'chaman', 'sao felix do xingu', 'san patricio', 'luderitz', 'hobyo', 'hermitage', 'khani', 'kodiak', 'tumannyy', 'poum', 'gladstone', 'kondopoga', 'sentyabrskiy', 'norman wells', 'haibowan', 'amurzet', 'segezha', 'kholodnyy', 'cruzeiro do sul', 'nakusp', 'tuy hoa', 'evensk', 'mount isa', 'coihaique', 'marang', 'chuy', 'kahului', 'saskylakh', 'gimli', 'barentsburg', 'havoysund', 'novopskov', 'ust-tarka', 'tasiilaq', 'astakos', 'pouebo', 'beloha', 'lauterbach', 'balaguer', 'jingdezhen', 'marsh harbour', 'champerico', 'lima', 'asau', 'sawakin', 'manicore', 'codrington', 'madimba', 'havre', 'mold', 'bredasdorp', 'tuktoyaktuk', 'aloleng', 'aksarka', 'angicos', 'pringsewu', 'zhuhai', 'maghama', 'vihari', 'shache', 'palmares do sul', 'murakami', 'isiro', 'kawalu', 'pacific grove', 'roma', 'maceio', 'campbell river', 'san angelo', 'kathu', 'artyk', 'faanui', 'kruisfontein', 'viedma', 'goderich', 'nyurba', 'toora-khem', 'tapes', 'pilikwe', 'huron', 'kaitangata', 'kushima', 'saleaula', 'kjollefjord', 'touros', 'cabo san lucas', 'hoa binh', 'sergeyevka', 'narasannapeta', 'camacha', 'nemuro', 'tol ...

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
import json
import requests

from api_keys import weather_api_key
from urllib.error import HTTPError
#weather_api_key = a48e24767ec9494ca8be13ca3d87fa76

# Build query URL
query_url = f"http://api.openweathermap.org/data/2.5/weather?appid="+ weather_api_key +"&units=imperial&q="

# Lists for the dataframe
citylist = []
cloudiness = []
dates = []
humidity = []
lats = []
longs = []
max_temps = []
windspeeds = []
countries = []

# Initial counters
counter = 0

# Loop for calling data city by city
for city in cities:
    try:
        response = requests.get(query_url + city.replace(" ","&")).json()
        cloudiness.append(response['clouds']['all'])
        dates.append(response['dt'])
        humidity.append(response['main']['humidity'])
        lats.append(response['coord']['lat'])
        longs.append(response['coord']['lon'])
        max_temps.append(response['main']['temp_max'])
        windspeeds.append(response['wind']['speed'])
        countries.append(response['sys']['country'])
        citylist.append(city)
        counter = counter + 1   
        
        print(f"Processing Record {counter} | {city}")
    except Exception:
        print("City way too small for wx data. Skipping...")
# Out:
# Processing Record 1 | sibolga
# Processing Record 2 | rikitea
# City way too small for wx data. Skipping...
# Processing Record 3 | lais
# Processing Record 4 | leh
# City way too small for wx data. Skipping...
# Processing Record 5 | cidreira
# Processing Record 6 | labuhan
# Processing Record 7 | port shepstone
# Processing Record 8 | teguldet
# Processing Record 9 | berlevag
# Processing Record 10 | ponta do sol
# Processing Record 11 | atuona
# Processing Record 12 | port elizabeth
# Processing Record 13 | hilo
# Processing Record 14 | veraval
# Processing Record 15 | ketchikan
# City way too small for wx data. Skipping...
# Processing Record 16 | new norfolk
# Processing Record 17 | kapaa
# Processing Record 18 | tiksi
# City way too small for wx data. Skipping...
# Processing Record 19 | tiznit
# Processing Record 20 | dikson
# Processing Record 21 | busselton
# Processing Record 22 | vaini
# Processing Record 23 | coahuayana
# Processing Record 24 | qaanaaq
# Processing Record 25 | bluff
# Processing Record 26 | hobart
# Processing Record 27 | sainte-maxime
# Processing Record 28 | ushuaia
# Processing Record 29 | coalinga
# Processing Record 30 | cape town
# City way too small for wx data. Skipping...
# Processing Record 31 | barrow
# Processing Record 32 | albany
# Processing Record 33 | palmer
# Processing Record 34 | port alfred
# Processing Record 35 | hithadhoo
# Processing Record 36 | lulea
# Processing Record 37 | cherskiy
# Processing Record 38 | nikolskoye
# Processing Record 39 | vermilion
# Processing Record 40 | imbituba
# Processing Record 41 | muros
# City way too small for wx data. Skipping...
# City way too small for wx data. Skipping...
# Processing Record 42 | salalah
# Processing Record 43 | salamanca
# Processing Record 44 | bubaque
# Processing Record 45 | saint-pierre
# City way too small for wx data. Skipping...
# Processing Record 46 | mataura
# Processing Record 47 | balotra
# Processing Record 48 | kysyl-syr
# Processing Record 49 | victoria
# Processing Record 50 | laguna
# Processing Record 51 | chapais
# Processing Record 52 | kavieng
# Processing Record 53 | boda
# Processing Record 54 | yellowknife
# Processing Record 55 | talnakh
# Processing Record 56 | praia da vitoria
# Processing Record 57 | colares
# Processing Record 58 | filingue
# Processing Record 59 | mahebourg
# Processing Record 60 | guerrero negro
# Processing Record 61 | harbour breton
# Processing Record 62 | kailua
# Processing Record 63 | arraial do cabo
# Processing Record 64 | torbay
# Processing Record 65 | punta arenas
# Processing Record 66 | balsas
# Processing Record 67 | boende
# City way too small for wx data. Skipping...
# Processing Record 68 | pevek
# Processing Record 69 | georgetown
# Processing Record 70 | mareeba
# Processing Record 71 | bom jesus
# Processing Record 72 | zhanakorgan
# Processing Record 73 | radovis
# Processing Record 74 | nanma
# Processing Record 75 | waipawa
# Processing Record 76 | saint-felicien
# Processing Record 77 | aykhal
# Processing Record 78 | streletskoye
# Processing Record 79 | provideniya
# Processing Record 80 | butaritari
# Processing Record 81 | iisalmi
# Processing Record 82 | salinopolis
# Processing Record 83 | thompson
# Processing Record 84 | port hardy
# Processing Record 85 | birganj
# Processing Record 86 | de-kastri
# Processing Record 87 | penzance
# Processing Record 88 | vao
# Processing Record 89 | dongsheng
# Processing Record 90 | gat
# Processing Record 91 | mys shmidta
# Processing Record 92 | mezen
# Processing Record 93 | bengkulu
# Processing Record 94 | byron bay
# Processing Record 95 | san vicente
# Processing Record 96 | carnarvon
# Processing Record 97 | chokurdakh
# Processing Record 98 | moba
# Processing Record 99 | hualmay
# City way too small for wx data. Skipping...
# City way too small for wx data. Skipping...
# Processing Record 100 | ribeira grande
# City way too small for wx data. Skipping...
# Processing Record 101 | hermanus
# Processing Record 102 | chicama
# Processing Record 103 | homer
# Processing Record 104 | barnstaple
# Processing Record 105 | banda aceh
# Processing Record 106 | khatanga
# Processing Record 107 | dakar
# Processing Record 108 | grand river south east
# Processing Record 109 | cartagena del chaira
# City way too small for wx data. Skipping...
# Processing Record 110 | porto-vecchio
# Processing Record 111 | poya
# Processing Record 112 | birao
# Processing Record 113 | clyde river
# Processing Record 114 | haines junction
# Processing Record 115 | airai
# City way too small for wx data. Skipping...
# Processing Record 116 | fonte boa
# Processing Record 117 | avera
# Processing Record 118 | vanimo
# Processing Record 119 | nobres
# Processing Record 120 | ayan
# Processing Record 121 | lasa
# Processing Record 122 | cabedelo
# Processing Record 123 | juba
# Processing Record 124 | koungheul
# Processing Record 125 | wajima
# Processing Record 126 | mogadishu
# Processing Record 127 | jamestown
# Processing Record 128 | nayoro
# City way too small for wx data. Skipping...
# Processing Record 129 | severo-kurilsk
# City way too small for wx data. Skipping...
# Processing Record 130 | hasaki
# Processing Record 131 | bambous virieux
# Processing Record 132 | gobabis
# Processing Record 133 | alofi
# City way too small for wx data. Skipping...
# Processing Record 134 | castro
# Processing Record 135 | fort nelson
# Processing Record 136 | longyearbyen
# Processing Record 137 | cockburn town
# Processing Record 138 | karaton
# Processing Record 139 | mandalgovi
# Processing Record 140 | guilin
# City way too small for wx data. Skipping...
# Processing Record 141 | warrnambool
# Processing Record 142 | popondetta
# Processing Record 143 | vila franca do campo
# Processing Record 144 | coquimbo
# Processing Record 145 | avarua
# Processing Record 146 | koran
# Processing Record 147 | ust-omchug
# Processing Record 148 | sao joao da barra
# Processing Record 149 | margate
# Processing Record 150 | nome
# Processing Record 151 | saldanha
# Processing Record 152 | gurupi
# Processing Record 153 | lavrentiya
# Processing Record 154 | vardo
# Processing Record 155 | matara
# Processing Record 156 | mar del plata
# Processing Record 157 | fukue
# Processing Record 158 | nurota
# Processing Record 159 | upernavik
# Processing Record 160 | manaure
# Processing Record 161 | lebu
# Processing Record 162 | sovetskiy
# Processing Record 163 | otradnoye
# Processing Record 164 | richards bay
# Processing Record 165 | ahipara
# Processing Record 166 | sri aman
# Processing Record 167 | hohhot
# Processing Record 168 | hazorasp
# Processing Record 169 | puerto ayora
# Processing Record 170 | lengshuijiang
# Processing Record 171 | galle
# City way too small for wx data. Skipping...
# Processing Record 172 | aljustrel
# Processing Record 173 | stolin
# Processing Record 174 | hearst
# Processing Record 175 | bonthe
# City way too small for wx data. Skipping...
# Processing Record 176 | sao gabriel da cachoeira
# Processing Record 177 | aripuana
# Processing Record 178 | safranbolu
# Processing Record 179 | kenai
# Processing Record 180 | ancud
# Processing Record 181 | shingu
# Processing Record 182 | nantucket
# Processing Record 183 | ternate
# Processing Record 184 | bethel
# Processing Record 185 | atar
# Processing Record 186 | maltahohe
# Processing Record 187 | okha
# Processing Record 188 | qaqortoq
# Processing Record 189 | dingle
# Processing Record 190 | tadine
# Processing Record 191 | soyo
# Processing Record 192 | iguape
# Processing Record 193 | nelson bay
# Processing Record 194 | east london
# Processing Record 195 | beruwala
# Processing Record 196 | pangnirtung
# Processing Record 197 | fortuna
# Processing Record 198 | emerald
# City way too small for wx data. Skipping...
# Processing Record 199 | bianzhuang
# Processing Record 200 | juazeiro
# Processing Record 201 | saint-philippe
# Processing Record 202 | maldonado
# Processing Record 203 | kibaya
# Processing Record 204 | chumikan
# Processing Record 205 | pisco
# Processing Record 206 | sena madureira
# City way too small for wx data. Skipping...
# Processing Record 207 | vila velha
# Processing Record 208 | asfi
# Processing Record 209 | sao filipe
# Processing Record 210 | nyuksenitsa
# Processing Record 211 | esperance
# Processing Record 212 | chaman
# Processing Record 213 | sao felix do xingu
# Processing Record 214 | san patricio
# Processing Record 215 | luderitz
# Processing Record 216 | hobyo
# Processing Record 217 | hermitage
# Processing Record 218 | khani
# Processing Record 219 | kodiak
# City way too small for wx data. Skipping...
# Processing Record 220 | poum
# Processing Record 221 | gladstone
# Processing Record 222 | kondopoga
# City way too small for wx data. Skipping...
# Processing Record 223 | norman wells
# City way too small for wx data. Skipping...
# Processing Record 224 | amurzet
# Processing Record 225 | segezha
# Processing Record 226 | kholodnyy
# Processing Record 227 | cruzeiro do sul
# Processing Record 228 | nakusp
# Processing Record 229 | tuy hoa
# Processing Record 230 | evensk
# Processing Record 231 | mount isa
# Processing Record 232 | coihaique
# Processing Record 233 | marang
# Processing Record 234 | chuy
# Processing Record 235 | kahului
# Processing Record 236 | saskylakh
# Processing Record 237 | gimli
# City way too small for wx data. Skipping...
# Processing Record 238 | havoysund
# Processing Record 239 | novopskov
# Processing Record 240 | ust-tarka
# Processing Record 241 | tasiilaq
# Processing Record 242 | astakos
# Processing Record 243 | pouebo
# Processing Record 244 | beloha
# Processing Record 245 | lauterbach
# Processing Record 246 | balaguer
# Processing Record 247 | jingdezhen
# Processing Record 248 | marsh harbour
# Processing Record 249 | champerico
# Processing Record 250 | lima
# Processing Record 251 | asau
# Processing Record 252 | sawakin
# Processing Record 253 | manicore
# Processing Record 254 | codrington
# Processing Record 255 | madimba
# Processing Record 256 | havre
# Processing Record 257 | mold
# Processing Record 258 | bredasdorp
# Processing Record 259 | tuktoyaktuk
# Processing Record 260 | aloleng
# Processing Record 261 | aksarka
# Processing Record 262 | angicos
# Processing Record 263 | pringsewu
# Processing Record 264 | zhuhai
# City way too small for wx data. Skipping...
# Processing Record 265 | vihari
# Processing Record 266 | shache
# Processing Record 267 | palmares do sul
# Processing Record 268 | murakami
# Processing Record 269 | isiro
# Processing Record 270 | kawalu
# Processing Record 271 | pacific grove
# Processing Record 272 | roma
# Processing Record 273 | maceio
# Processing Record 274 | campbell river
# Processing Record 275 | san angelo
# Processing Record 276 | kathu
# City way too small for wx data. Skipping...
# Processing Record 277 | faanui
# Processing Record 278 | kruisfontein
# Processing Record 279 | viedma
# Processing Record 280 | goderich
# Processing Record 281 | nyurba
# Processing Record 282 | toora-khem
# Processing Record 283 | tapes
# Processing Record 284 | pilikwe
# Processing Record 285 | huron
# Processing Record 286 | kaitangata
# Processing Record 287 | kushima
# City way too small for wx data. Skipping...
# Processing Record 288 | kjollefjord
# Processing Record 289 | touros
# Processing Record 290 | cabo san lucas
# City way too small for wx data. Skipping...
# Processing Record 291 | sergeyevka
# Processing Record 292 | narasannapeta
# Processing Record 293 | camacha
# Processing Record 294 | nemuro
# City way too small for wx data. Skipping...
# Processing Record 295 | woodward
# Processing Record 296 | kanlagay
# Processing Record 297 | padang
# Processing Record 298 | isangel
# Processing Record 299 | andijon
# Processing Record 300 | lewistown
# Processing Record 301 | satana
# Processing Record 302 | brigham city
# Processing Record 303 | resavica
# Processing Record 304 | ndjole
# Processing Record 305 | ixtapa
# City way too small for wx data. Skipping...
# Processing Record 306 | trapani
# Processing Record 307 | jalu
# Processing Record 308 | saint-ambroise
# Processing Record 309 | boguchany
# Processing Record 310 | voh
# Processing Record 311 | makakilo city
# Processing Record 312 | fallon
# Processing Record 313 | pineville
# Processing Record 314 | aleksandrovka
# Processing Record 315 | tiarei
# Processing Record 316 | sinnamary
# Processing Record 317 | neiafu
# Processing Record 318 | oskemen
# City way too small for wx data. Skipping...
# Processing Record 319 | oliveira
# Processing Record 320 | aklavik
# Processing Record 321 | tucuma
# Processing Record 322 | puerto escondido
# Processing Record 323 | najran
# Processing Record 324 | adrar
# Processing Record 325 | srednekolymsk
# Processing Record 326 | manokwari
# Processing Record 327 | megion
# City way too small for wx data. Skipping...
# Processing Record 328 | troitskoye
# Processing Record 329 | tabas
# Processing Record 330 | yangshe
# Processing Record 331 | valle de allende
# Processing Record 332 | russell
# Processing Record 333 | constitucion
# Processing Record 334 | tilichiki
# Processing Record 335 | vigrestad
# Processing Record 336 | kandrian
# Processing Record 337 | yumen
# Processing Record 338 | lorengau
# Processing Record 339 | tutoia
# Processing Record 340 | hovd
# Processing Record 341 | samarai
# Processing Record 342 | san cristobal
# Processing Record 343 | marsa matruh
# Processing Record 344 | solnechnyy
# City way too small for wx data. Skipping...
# Processing Record 345 | ostrovnoy
# Processing Record 346 | seoul
# Processing Record 347 | erzin
# Processing Record 348 | kalianget
# Processing Record 349 | thinadhoo
# Processing Record 350 | tambacounda
# Processing Record 351 | ilulissat
# Processing Record 352 | katsuura
# Processing Record 353 | brae
# Processing Record 354 | faya
# Processing Record 355 | mugur-aksy
# Processing Record 356 | lata
# Processing Record 357 | kijang
# Processing Record 358 | bubanza
# Processing Record 359 | sitka
# Processing Record 360 | klyuchi
# Processing Record 361 | saint-georges
# Processing Record 362 | korla
# Processing Record 363 | moron
# City way too small for wx data. Skipping...
# City way too small for wx data. Skipping...
# Processing Record 364 | marawi
# Processing Record 365 | cap malheureux
# Processing Record 366 | sangmelima
# Processing Record 367 | caravelas
# Processing Record 368 | fomboni
# Processing Record 369 | sungaipenuh
# Processing Record 370 | vitoria
# Processing Record 371 | anadyr
# Processing Record 372 | rawson
# Processing Record 373 | soure
# Processing Record 374 | kande
# Processing Record 375 | willemstad
# Processing Record 376 | kismayo
# City way too small for wx data. Skipping...
# Processing Record 377 | klaksvik
# Processing Record 378 | mayumba
# Processing Record 379 | leningradskiy
# Processing Record 380 | sucua
# Processing Record 381 | mocuba
# Processing Record 382 | portland
# Processing Record 383 | willmar
# Processing Record 384 | smithers
# Processing Record 385 | hamilton
# Processing Record 386 | guangyuan
# Processing Record 387 | henderson
# Processing Record 388 | seddon
# Processing Record 389 | victoria point
# Processing Record 390 | kaabong
# Processing Record 391 | comodoro rivadavia
# Processing Record 392 | port keats
# Processing Record 393 | dunmanway
# City way too small for wx data. Skipping...
# Processing Record 394 | hambantota
# Processing Record 395 | yinchuan
# Processing Record 396 | loei
# Processing Record 397 | kokopo
# Processing Record 398 | lompoc
# Processing Record 399 | belyy yar
# Processing Record 400 | ormara
# Processing Record 401 | pangai
# Processing Record 402 | iqaluit
# Processing Record 403 | rovaniemi
# Processing Record 404 | burnie
# Processing Record 405 | trairi
# Processing Record 406 | husavik
# Processing Record 407 | anjiang
# Processing Record 408 | gerash
# Processing Record 409 | wynyard
# Processing Record 410 | geraldton
# City way too small for wx data. Skipping...
# Processing Record 411 | tulagi
# Processing Record 412 | dukat
# City way too small for wx data. Skipping...
# Processing Record 413 | khotkovo
# Processing Record 414 | broome
# Processing Record 415 | sorong
# Processing Record 416 | ayagoz
# Processing Record 417 | buzmeyin
# Processing Record 418 | puerto del rosario
# Processing Record 419 | oktyabrskiy
# Processing Record 420 | akyab
# Processing Record 421 | estevan
# Processing Record 422 | yuli
# Processing Record 423 | iskateley
# Processing Record 424 | pavlovsk
# Processing Record 425 | sungurlu
# Processing Record 426 | riosucio
# Processing Record 427 | alakurtti
# Processing Record 428 | voyvozh
# Processing Record 429 | eydhafushi
# Processing Record 430 | bur gabo
# Processing Record 431 | hami
# Processing Record 432 | bundibugyo
# City way too small for wx data. Skipping...
# Processing Record 433 | gao
# Processing Record 434 | lubango
# Processing Record 435 | port hedland
# Processing Record 436 | tohana
# Processing Record 437 | heishan
# Processing Record 438 | purwodadi
# Processing Record 439 | cairns
# Processing Record 440 | terrace
# Processing Record 441 | lagoa
# Processing Record 442 | idanre
# Processing Record 443 | dickinson
# Processing Record 444 | kamenka
# Processing Record 445 | atocha
# Processing Record 446 | athabasca
# Processing Record 447 | kavaratti
# Processing Record 448 | copiapo
# Processing Record 449 | port-gentil
# Processing Record 450 | petropavlovsk-kamchatskiy
# Processing Record 451 | atbasar
# Processing Record 452 | ampanihy
# Processing Record 453 | barra patuca
# Processing Record 454 | olinda
# Processing Record 455 | norsup
# Processing Record 456 | springfield
# City way too small for wx data. Skipping...
# Processing Record 457 | kolda
# Processing Record 458 | methoni
# Processing Record 459 | nanortalik
# Processing Record 460 | bako
# Processing Record 461 | daru
# Processing Record 462 | kula
# Processing Record 463 | karakol
# Processing Record 464 | guaruja
# Processing Record 465 | grand centre
# Processing Record 466 | dombarovskiy
# Processing Record 467 | cagayan de tawi-tawi
# Processing Record 468 | sistranda
# City way too small for wx data. Skipping...
# Processing Record 469 | cayenne
# Processing Record 470 | anloga
# Processing Record 471 | diamantino
# City way too small for wx data. Skipping...
# Processing Record 472 | taoudenni
# Processing Record 473 | taft
# Processing Record 474 | pochutla
# Processing Record 475 | hofn
# Processing Record 476 | vestmannaeyjar
# Processing Record 477 | madona
# Processing Record 478 | divnomorskoye
# Processing Record 479 | ust-kuyga
# Processing Record 480 | talcahuano
# Processing Record 481 | paamiut
# Processing Record 482 | muravlenko
# Processing Record 483 | davila
# Processing Record 484 | radhanpur
# City way too small for wx data. Skipping...
# Processing Record 485 | kuito
# Processing Record 486 | usinsk
# City way too small for wx data. Skipping...
# Processing Record 487 | sao jose da coroa grande
# Processing Record 488 | bowen
# Processing Record 489 | souillac
# Processing Record 490 | katherine
# Processing Record 491 | kupang
# Processing Record 492 | ruteng
# City way too small for wx data. Skipping...
# Processing Record 493 | egvekinot
# Processing Record 494 | bonavista
# Processing Record 495 | yulara
# Processing Record 496 | holzkirchen
# Processing Record 497 | garowe
# City way too small for wx data. Skipping...
# Processing Record 498 | lodja
# Processing Record 499 | trincomalee
# Processing Record 500 | kaeo
# City way too small for wx data. Skipping...
# Processing Record 501 | bima
# Processing Record 502 | bloomfield
# Processing Record 503 | amuntai
# Processing Record 504 | kluang
# City way too small for wx data. Skipping...
# Processing Record 505 | wittlich
# Processing Record 506 | hay river
# Processing Record 507 | eyl
# City way too small for wx data. Skipping...
# Processing Record 508 | mbanza-ngungu
# Processing Record 509 | urucurituba
# Processing Record 510 | poso
# Processing Record 511 | juelsminde
# Processing Record 512 | bathsheba
# Processing Record 513 | arman
# Processing Record 514 | sandnessjoen
# Processing Record 515 | almeirim
# Processing Record 516 | vagur
# Processing Record 517 | mandera
# Processing Record 518 | honningsvag
# Processing Record 519 | sechura
# Processing Record 520 | teguise
# Processing Record 521 | ucluelet
# Processing Record 522 | eston
# Processing Record 523 | borshchiv
# Processing Record 524 | vieste
# Processing Record 525 | roald
# Processing Record 526 | kharp
# Processing Record 527 | rio branco
# Processing Record 528 | brekstad
# Processing Record 529 | tuatapere
# Processing Record 530 | richmond
# Processing Record 531 | nalut
# City way too small for wx data. Skipping...
# Processing Record 532 | yarmouth
# Processing Record 533 | outjo
# Processing Record 534 | touba
# Processing Record 535 | fairbanks
# Processing Record 536 | yar-sale
# Processing Record 537 | tabou
# Processing Record 538 | tlalmanalco
# Processing Record 539 | tongchuan
# City way too small for wx data. Skipping...
# Processing Record 540 | krabi
# Processing Record 541 | komsomolskiy
# Processing Record 542 | svetlaya
# Processing Record 543 | trofors
# Processing Record 544 | wenling
# City way too small for wx data. Skipping...
# Processing Record 545 | santiago
# Processing Record 546 | ajdabiya
# City way too small for wx data. Skipping...
# Processing Record 547 | port macquarie
# Processing Record 548 | nicoya
# Processing Record 549 | shillong
# Processing Record 550 | otuzco
# Processing Record 551 | salvador
# Processing Record 552 | liverpool
# Processing Record 553 | yerbogachen
# Processing Record 554 | batagay-alyta
# Processing Record 555 | killybegs
# Processing Record 556 | pyapon
# Processing Record 557 | georgiyevka
# Processing Record 558 | atherton
# Processing Record 559 | abbeville
# Processing Record 560 | calvinia
# Processing Record 561 | harnosand
# Processing Record 562 | bud
# Processing Record 563 | zyryanka
# Processing Record 564 | zeya
# Processing Record 565 | muisne
# Processing Record 566 | paka
# Processing Record 567 | beringovskiy
# Processing Record 568 | izazi
# Processing Record 569 | torrington
# City way too small for wx data. Skipping...
# Processing Record 570 | belmonte
# Processing Record 571 | borovichi
# Processing Record 572 | half moon bay
# Processing Record 573 | puerto leguizamo
# Processing Record 574 | mangrol
# City way too small for wx data. Skipping...

# %%
# Data retrieval verification

print(f"The windspeed information received is: {windspeeds}")
# Out:
# The windspeed information received is: [3.31, 13.89, 2.19, 0.76, 15.08, 8.16, 9.6, 1.66, 10.29, 16.11, 20.98, 9.6, 4.7, 3.22, 9.17, 3.49, 4.7, 6.89, 2.51, 17.63, 4, 11.41, 11.41, 3.38, 8.99, 11.41, 3.98, 12.75, 2.33, 9.17, 14.09, 8.01, 16.11, 9.6, 12.73, 6.93, 2.95, 6.71, 8.05, 14.99, 1.01, 4.7, 10.29, 10.33, 20.8, 8.99, 7.36, 3.36, 5.99, 4.7, 8.05, 5.95, 2.62, 6.93, 4.47, 17.22, 12.75, 5.93, 9.17, 2.15, 1.7, 6.55, 11.41, 4.7, 6.04, 4.25, 1.43, 7.38, 4.7, 4.7, 6.58, 4.16, 2.62, 2.04, 19.46, 3.36, 4.47, 11.18, 11.18, 8.61, 6.93, 12.19, 8.05, 9.6, 3.18, 4.27, 19.46, 18.21, 11.05, 1.7, 6.46, 9.01, 4.79, 11.41, 9.82, 13.87, 7.67, 1.45, 8.93, 9.17, 3.87, 12.75, 4.7, 13, 1.88, 7.45, 13.87, 4.03, 13.87, 4.7, 5.35, 4.9, 4.7, 14.99, 1.66, 4.7, 4.7, 5.68, 3.71, 10.58, 3.36, 13.87, 3.27, 9.53, 1.07, 19.19, 4.7, 5.14, 16.58, 9.75, 9.17, 14.36, 16.11, 3.44, 4, 6.93, 17.22, 4.7, 6.15, 4.72, 14.2, 2.15, 7, 13.87, 19.46, 3.36, 2.13, 10.13, 8.01, 6.87, 4.7, 5.08, 9.13, 16.11, 4.54, 2.24, 10.87, 4.7, 5.66, 19.26, 10.78, 8.43, 6.71, 10.29, 7.18, 3.36, 4.47, 4.7, 16.11, 0.56, 5.08, 17.22, 10.78, 4.7, 8.1, 10.13, 0.69, 3.49, 3.36, 10.29, 5.14, 19.46, 4.32, 8.05, 9.4, 10.74, 7.43, 5.3, 4.59, 16.33, 8.25, 10.16, 3, 6.71, 3.56, 2.1, 1.99, 9.17, 1.77, 5.82, 20.8, 12.75, 4.34, 4.12, 14.99, 8.05, 7, 9.06, 10.13, 5.66, 12.75, 1.92, 10.13, 9.82, 14.14, 16.6, 5.82, 31.09, 3.36, 18.1, 5.82, 4.47, 11.41, 5.68, 8.77, 2.1, 6.93, 2.24, 2.24, 15.9, 4, 9.17, 1.12, 10.02, 3.36, 13.38, 8.05, 10.29, 10.56, 9.06, 7.34, 4.7, 14.05, 9.06, 3, 11.41, 1.77, 4, 9.17, 10.29, 1.3, 11.23, 1.36, 15.05, 8.84, 10.29, 9.17, 1.12, 13.87, 7.94, 10.6, 14.97, 1.45, 5.82, 6.89, 2.48, 8.16, 0.98, 0.74, 0.72, 3.85, 5.82, 14.99, 6.93, 9.82, 2.24, 15.43, 2.08, 12.26, 9.17, 3.6, 2.26, 12.97, 7.9, 8.05, 8.01, 5.99, 8.05, 13.87, 6.93, 4.14, 5.95, 6.93, 11.56, 4.7, 7.34, 3.51, 16.58, 4.47, 5.82, 2.64, 3.36, 1.7, 3.69, 6.93, 11.41, 9.64, 9.17, 3.4, 4.83, 5.64, 1.61, 6.93, 20.13, 8.05, 9.53, 12.75, 6.71, 0.87, 3.36, 7.58, 16.11, 1.99, 9.82, 4.88, 4.56, 8.95, 15.19, 2.24, 3.67, 1.99, 2.19, 13.94, 15.23, 11.41, 4.63, 19.26, 6.4, 12.91, 5.39, 4.72, 9.82, 16.11, 1.41, 19.91, 1.39, 5.23, 12.77, 9.55, 4.7, 6.2, 4.7, 28.86, 1.32, 4.72, 9.73, 3.36, 1.54, 11.41, 9.86, 16.11, 0.96, 11.01, 5.01, 10.29, 3.36, 12.08, 9.86, 2.35, 6.55, 6.71, 16.78, 15.26, 1.68, 9.17, 13.78, 25.28, 6.58, 7.96, 6.93, 2.08, 10.29, 20.8, 2.86, 6.93, 5.01, 5.82, 9.17, 7, 5.91, 2.17, 9.6, 12.75, 13, 3.22, 1.05, 9.48, 5.82, 8.61, 9.86, 16.11, 12.75, 10.29, 10, 10.71, 4.7, 1.66, 3.44, 10, 4.7, 2.24, 1.45, 8.95, 5.82, 8.43, 3.85, 4.7, 16.11, 3.2, 6.04, 12.75, 3.09, 20.65, 7.78, 3.18, 4.7, 1.01, 7.63, 9.78, 1.01, 2.93, 3.44, 9.24, 5.66, 9.6, 4.52, 6.89, 4.47, 4.7, 18.34, 22.48, 2.77, 11.41, 7.74, 9.15, 8.05, 15.46, 10.29, 11.41, 4.47, 4.59, 7.85, 8.52, 6.93, 1.12, 12.75, 3.11, 2.24, 7.2, 3.78, 5.73, 12.26, 4.47, 11.41, 4.03, 5.66, 12.03, 20.8, 8.05, 11.41, 4.43, 12.28, 2.24, 11.41, 11.88, 28.83, 8.32, 7.85, 5.75, 12.75, 9.01, 5.01, 10.42, 8.21, 7.78, 13.87, 10.13, 6.93, 9.17, 4.7, 9.17, 1.7, 5.14, 3.94, 5.82, 2.17, 11.92, 1.05, 10.38, 5.99, 3.65, 9.17, 0.07, 1.61, 1.43, 1.99, 17.9, 1.57, 3.51, 4.7, 10.29, 14.99, 6.44, 6.93, 7.38, 29.24, 5.5, 10.29, 15.93, 14.99, 6.93, 6.93, 4, 5.82, 19.46, 2.55, 7.78, 20.8, 11.01, 3.02, 7.96, 9.17, 13.87, 3.53, 1.66, 11.1, 6.76, 2.01, 0.43, 6.93, 4.7, 9.48, 1.12, 5.97, 6.93, 7.87, 9.6, 6.93, 0.96, 12.75, 9.17, 12.75, 1.23, 1.63, 17.22, 5.3, 2.24, 5.01, 13.98, 5.21, 4.7, 6.93, 5.19, 3.83, 12.75, 2.24, 16.75, 2.91, 3, 10.29, 8.61, 5.5, 16.11, 3.31]

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#Create a dataframe to store the data
wx = {"City":citylist,"Country":countries,"Lat":lats,"Long":longs,"Cloudiness":cloudiness,"Humidity":humidity,"Max Temp":max_temps,"Wind Speed":windspeeds, "Date":dates,}

weather_df = pd.DataFrame(wx)
weather_df.to_csv(r'output_data/cities.csv', index=False)

# %%
#Preview the dataframe
weather_df.head()
# Out:
#        City Country    Lat    Long  Cloudiness  Humidity  Max Temp  \
# 0   sibolga      ID   1.74   98.78         100        82     74.05
# 1   rikitea      PF -23.12 -134.97           2        81     76.95
# 2      lais      PH   6.33  125.65          66        73     81.23
# 3       leh      IN  34.17   77.58          71        80     10.96
# 4  cidreira      BR -30.18  -50.21           0        77     72.12
#
#    Wind Speed        Date
# 0        3.31  1607632769
# 1       13.89  1607632769
# 2        2.19  1607632770
# 3        0.76  1607632770
# 4       15.08  1607632770

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
weather_df.sort_values(by=['Humidity'], ascending=False)
# Out:
#                City Country    Lat    Long  Cloudiness  Humidity  Max Temp  \
# 99   ribeira grande      ES  42.75   -8.44          90       100     59.00
# 510      juelsminde      DK  55.71   10.02         100       100     37.99
# 402       rovaniemi      FI  66.50   25.72          90       100     28.40
# 86         penzance      GB  50.12   -5.54          75       100     51.80
# 548        shillong      IN  25.57   91.88          14       100     46.51
# ..              ...     ...    ...     ...         ...       ...       ...
# 386       henderson      US  36.04 -114.98           1        17     64.40
# 432             gao      ML  16.64    1.64           0        17     78.85
# 57         filingue      NE  14.35    3.32           0        15     81.93
# 131         gobabis      NA -22.45   18.97           0        15     78.53
# 302        resavica      RS  44.04   21.58          79         7     34.00
#
#      Wind Speed        Date
# 99         9.17  1607632789
# 510       10.29  1607632874
# 402       10.29  1607632851
# 86        19.46  1607632786
# 548        0.96  1607632771
# ..          ...         ...
# 386        5.82  1607632843
# 432        9.24  1607632857
# 57         5.93  1607632781
# 131       14.36  1607632795
# 302        1.70  1607632831
#
# [574 rows x 9 columns]

# %%
#  Get the indices of cities that have humidity over 100%.
weather_df[weather_df['Humidity'] == 100]
# Out:
#                City Country    Lat    Long  Cloudiness  Humidity  Max Temp  \
# 8          berlevag      NO  70.86   29.09          40       100     33.80
# 56          colares      PT  38.80   -9.45          75       100     62.01
# 86         penzance      GB  50.12   -5.54          75       100     51.80
# 95        carnarvon      AU -24.87  113.63          90       100     73.40
# 99   ribeira grande      ES  42.75   -8.44          90       100     59.00
# 102           homer      US  59.64 -151.55          90       100     32.00
# 129          hasaki      JP  35.73  140.83          20       100     37.40
# 145           koran      BA  43.81   18.57          40       100     39.20
# 155   mar del plata      ES  43.40   -4.01          40       100     55.99
# 313   aleksandrovka      UA  46.84   32.76          90       100     37.40
# 345           seoul      KR  37.57  126.98           1       100     33.80
# 364  cap malheureux      FR  49.27   -1.21          75       100     50.00
# 402       rovaniemi      FI  66.50   25.72          90       100     28.40
# 510      juelsminde      DK  55.71   10.02         100       100     37.99
# 548        shillong      IN  25.57   91.88          14       100     46.51
# 551       liverpool      GB  53.41   -2.98          75       100     45.00
#
#      Wind Speed        Date
# 8         10.29  1607632771
# 56        12.75  1607632780
# 86        19.46  1607632786
# 95        13.87  1607632788
# 99         9.17  1607632789
# 102        4.70  1607632512
# 129        9.75  1607632749
# 145        3.36  1607632798
# 155        2.24  1607632800
# 313       20.13  1607632833
# 345        1.39  1607632792
# 364       10.29  1607632843
# 402       10.29  1607632851
# 510       10.29  1607632874
# 548        0.96  1607632771
# 551       12.75  1607632859

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.

clean_weather_df = weather_df[weather_df['Humidity'] != 100]
clean_weather_df.sort_values(by=['Humidity'], ascending=False)
# Out:
#           City Country    Lat    Long  Cloudiness  Humidity  Max Temp  \
# 329    yangshe      CN  31.89  120.61          97        99     48.00
# 173     hearst      CA  49.68  -83.67         100        99     33.80
# 395       loei      TH  17.42  101.50          41        99     63.00
# 172     stolin      BY  51.89   26.85         100        98     32.00
# 422  iskateley      RU  67.68   53.15          96        98     26.87
# ..         ...     ...    ...     ...         ...       ...       ...
# 386  henderson      US  36.04 -114.98           1        17     64.40
# 432        gao      ML  16.64    1.64           0        17     78.85
# 57    filingue      NE  14.35    3.32           0        15     81.93
# 131    gobabis      NA -22.45   18.97           0        15     78.53
# 302   resavica      RS  44.04   21.58          79         7     34.00
#
#      Wind Speed        Date
# 329        3.67  1607632837
# 173        4.70  1607632707
# 395        1.05  1607632850
# 172       10.78  1607632806
# 422       20.65  1607632855
# ..          ...         ...
# 386        5.82  1607632843
# 432        9.24  1607632857
# 57         5.93  1607632781
# 131       14.36  1607632795
# 302        1.70  1607632831
#
# [558 rows x 9 columns]

# %%
clean_weather_df.sort_values(by=['Max Temp'], ascending=False)
# Out:
#            City Country    Lat    Long  Cloudiness  Humidity  Max Temp  \
# 362       moron      AR -34.65  -58.62           0        28     98.01
# 550    salvador      SV  13.83  -88.92           0        40     89.60
# 199    juazeiro      BR  -9.41  -40.50          20        43     89.60
# 248  champerico      GT  14.30  -91.92          40        55     89.60
# 547      nicoya      CR  10.15  -85.45          40        52     87.80
# ..          ...     ...    ...     ...         ...       ...       ...
# 54      talnakh      RU  69.49   88.40          20        66    -31.00
# 105    khatanga      RU  71.97  102.50          93        84    -32.49
# 478   ust-kuyga      RU  70.02  135.60          66        78    -38.00
# 47    kysyl-syr      RU  63.90  122.76          66        81    -38.40
# 76       aykhal      RU  66.00  111.50           0        65    -40.00
#
#      Wind Speed        Date
# 362       11.01  1607632780
# 550        9.17  1607632882
# 199        5.82  1607632811
# 248        9.17  1607632820
# 547        6.93  1607632881
# ..          ...         ...
# 54         4.47  1607632780
# 105        7.45  1607632790
# 478        5.75  1607632867
# 47         3.36  1607632779
# 76         4.47  1607632784
#
# [558 rows x 9 columns]

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# Plotting cities by Lat and Long and visualizing tempertaure by color gave a more useful plot 
#    than latitude and tempertaure alone.

# Extract the data we're interested in
Lat, Long = clean_weather_df['Lat'], clean_weather_df['Long']
temperature = clean_weather_df['Max Temp']

# Scatter the points, using temperature color
plt.scatter(Long, Lat, label=None,
            c=temperature, cmap='rainbow',
            linewidth=0, alpha=0.5)

# Title and Labels
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.colorbar(label='Temperature')
plt.clim(-40, 110)
 
plt.title(f'Latitude vs Temperature (F)  {time.strftime("%m/%d/%Y")}');

# Save the figure
plt.savefig('Latitude vs.Temperature v1.png')

# %%
#'Latitude vs Temperature (F)' utlizes color to show maximum temperature distribution 
#   by Latitude, and, to a lesser degree, by Longitude. As expected the bands are relatively 
#   uniform horizontally with the exception of some longitudes with particularly cooler temperatures.

# %%
# Build a boring, less useful scatter plot 'Latitude vs.Temperature (F)'

# Number of cities in cleaned dataframe
n = len(clean_weather_df. index)
t= np.arange(n)  # color scale matched with number of data points

plt.scatter(clean_weather_df['Lat'], clean_weather_df['Max Temp'], s=5, c=t)

# Title and Labels
plt.xlabel('Latitude')
plt.ylabel('Temperature (F)')
plt.title(f'Latitude vs.Temperature (F) {time.strftime("%m/%d/%Y")}')

plt.grid(True)

# Save the figure
plt.savefig('Latitude vs.Temperature v2.png')

plt.show()

# %%
#'Latitude vs Temperature (F)' utlizes color to show maximum temperature distribution 
#   by Latitude. This is a less visually educational plot because all latitudes are 
#   grouped together but the colors do show temperature distribution.

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# Plotting cities by Lat and Long and visualizing humidity by color gave a more useful plot 
#    than latitude and tempertaure alone.
# Two dimensional scatterplot located in regression section.

# Extract the data we're interested in
Lat, Long = clean_weather_df['Lat'], clean_weather_df['Long']
hum = clean_weather_df['Humidity']

# Scatter the points, using Humidity
plt.scatter(Long, Lat, label=None,
            c=hum, cmap='rainbow',
            linewidth=0, alpha=0.5)

plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.colorbar(label='Humidity %')
plt.clim(0, 100)
 
plt.title(f'Latitude vs Humidity %  {time.strftime("%m/%d/%Y")}');

# Save the figure
plt.savefig('Latitude vs.Humidity.png')

# %%
#'Latitude vs Humidity %' utlizes color to show humidity % distribution 
#   by Latitude, and, to a lesser degree, by Longitude. The plot visually
#   confers that humidity is not determined by latitude alone...longitude
#   plays an important role in the humidity a city will experience.

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# Plotting cities by Lat and Long and visualizing cloudiness by color gave a more useful plot 
#    than latitude and tempertaure alone.
# Two dimensional scatterplot located in regression section.

# Extract the data we're interested in
Lat, Long = clean_weather_df['Lat'], clean_weather_df['Long']
cloud = clean_weather_df['Cloudiness']

# Scatter the points, using Cloudiness
plt.scatter(Long, Lat, label=None,
            c=cloud, cmap='binary',
            linewidth=0, alpha=0.5)

plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.colorbar(label='Cloudiness %')
plt.clim(0, 100)
 
plt.title(f'Latitude vs Cloudiness %  {time.strftime("%m/%d/%Y")}');

# Save the figure
plt.savefig('Latitude vs.Cloudiness.png')

# %%
#'Latitude vs Cloudiness %' utlizes color to show cloudiness % distribution 
#   by Latitude, and, to a lesser degree, by Longitude. The plot visually
#   confers that cloudiness is not primarily determined by latitude...longitude
#   appears to be the primary determinant of cloudiness.

# %%
clean_weather_df.sort_values(by=['Wind Speed'], ascending=False)
# Out:
#                City Country    Lat    Long  Cloudiness  Humidity  Max Temp  \
# 217           khani      GE  41.96   42.96           0        71     46.40
# 515           vagur      FO  61.47   -6.81         100        87     47.12
# 352            brae      GB  60.40   -1.35         100        76     48.20
# 475  vestmannaeyjar      IS  63.44  -20.27         100        87     44.64
# 376        klaksvik      FO  62.23   -6.59         100        93     44.60
# ..              ...     ...    ...     ...         ...       ...       ...
# 269          kawalu      ID  -7.38  108.21          92        89     73.81
# 176        aripuana      BR  -9.17  -60.63         100        95     72.81
# 169   lengshuijiang      CN  27.69  111.43         100        81     48.81
# 538       tongchuan      CN  35.08  109.09         100        81     33.42
# 502         amuntai      ID  -2.42  115.25         100        89     75.81
#
#      Wind Speed        Date
# 217       31.09  1607632814
# 515       29.24  1607632874
# 352       28.86  1607632841
# 475       28.83  1607632866
# 376       25.28  1607632846
# ..          ...         ...
# 269        0.72  1607632825
# 176        0.69  1607632653
# 169        0.56  1607632805
# 538        0.43  1607632879
# 502        0.07  1607632872
#
# [558 rows x 9 columns]

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# Plotting cities by Lat and Long and visualizing wind speed by color gave a more useful plot 
#    than latitude and tempertaure alone.
# Two dimensional scatterplot located in regression section.

# Extract the data we're interested in
Lat, Long = clean_weather_df['Lat'], clean_weather_df['Long']
wind = clean_weather_df['Wind Speed']

# Scatter the points, using temperature color
plt.scatter(Long, Lat, label=None,
            c=wind, cmap='Blues',
            linewidth=0, alpha=0.5)

plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.colorbar(label='Wind Speed (mph)')
plt.clim(0, 40)
 
plt.title(f'Latitude vs Wind Speed (mph) {time.strftime("%m/%d/%Y")}');

# Save the figure
plt.savefig('Latitude vs.Wind Speed.png')

# %%
#'Latitude vs Wind Speed' utlizes color to show wind speed distribution 
#   by Latitude, and, to a lesser degree, by Longitude. The plot visually
#   confers that wind speed is greater at the subtropical jets and indicated
#   by darker blue colors.

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Dataframe for Northern Hemisphere cities
northtemp_df = weather_df[weather_df['Lat'] >= 0]
northtemp_df.sort_values(by=['Lat'])
# Out:
#              City Country    Lat    Long  Cloudiness  Humidity  Max Temp  \
# 348     thinadhoo      MV   0.53   72.93          14        71     82.00
# 564        muisne      EC   0.60  -80.03          75        79     84.20
# 431    bundibugyo      UG   0.74   30.04           6        60     69.76
# 182       ternate      ID   0.80  127.40          10        77     81.10
# 0         sibolga      ID   1.74   98.78         100        82     74.05
# ..            ...     ...    ...     ...         ...       ...       ...
# 105      khatanga      RU  71.97  102.50          93        84    -32.49
# 158     upernavik      GL  72.79  -56.15         100        95     24.46
# 19         dikson      RU  73.51   80.55         100        89     -9.67
# 23        qaanaaq      GL  77.48  -69.36         100        91     11.97
# 135  longyearbyen      SJ  78.22   15.64          75        72     14.00
#
#      Wind Speed        Date
# 348        9.55  1607632840
# 564       12.75  1607632884
# 431        3.44  1607632857
# 182        4.32  1607632808
# 0          3.31  1607632769
# ..          ...         ...
# 105        7.45  1607632790
# 158        5.66  1607632801
# 19        17.63  1607632773
# 23         3.38  1607632774
# 135        6.93  1607632796
#
# [406 rows x 9 columns]

# %%
# Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# Number of cities in cleaned northern hemisphere dataframe
n1 = len(northtemp_df. index)

t= np.arange(n1)  # Color scale matched with number of data points
plt.scatter(northtemp_df['Lat'], northtemp_df['Max Temp'], s=5, c=t)

# Title and Labels
plt.xlabel('Latitude')
plt.ylabel('Temperature (F)')
plt.title(f'Northern Latitudes vs.Temperature (F) {time.strftime("%m/%d/%Y")}')

plt.grid(True)

# Regression Line
x_values = northtemp_df['Lat']
y_values = northtemp_df['Max Temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(0,0),fontsize=15,color="darkblue")

# Print out the r-squared value along with the plot.
print(f"The r-squared is: {rvalue**2}")

# Save the figure
plt.savefig('N Latitude vs.Temperature.png')

plt.show()
# Out:
# The r-squared is: 0.7086290541302908

# %%
print('For every unit of change in latitude the temperature drops ' + str(round(slope,2)) +' units.') 
print('Approximately '+ str(round(rvalue**2,2)*100) + '% of the data fit into the model.')
# Out:
# For every unit of change in latitude the temperature drops -1.2 units.
# Approximately 71.0% of the data fit into the model.

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Dataframe for Southern Hemisphere cities
south_df = weather_df[weather_df['Lat'] <= 0]
south_df.sort_values(by=['Lat'])
# Out:
#            City Country    Lat    Long  Cloudiness  Humidity  Max Temp  \
# 27      ushuaia      AR -54.80  -68.30          40        36     62.60
# 24        bluff      NZ -46.60  168.33          98        82     48.99
# 285  kaitangata      NZ -46.28  169.85         100        91     46.00
# 45      mataura      NZ -46.19  168.86          99        82     48.99
# 528   tuatapere      NZ -46.13  167.68          99        77     50.00
# ..          ...     ...    ...     ...         ...       ...       ...
# 34    hithadhoo      MV  -0.60   73.08           1        75     81.68
# 375     kismayo      SO  -0.36   42.55           4        76     80.06
# 66       boende      CD  -0.22   20.87          90        84     73.29
# 303      ndjole      GA  -0.18   10.76         100        91     75.96
# 320      tucuma      BR  -0.18  -50.05          87        88     78.46
#
#      Wind Speed        Date
# 27        12.75  1607632653
# 24         8.99  1607632774
# 285        8.01  1607632828
# 45         8.99  1607632779
# 528       11.01  1607632877
# ..          ...         ...
# 34        12.73  1607632776
# 375       13.78  1607632846
# 66         1.43  1607632782
# 303        3.69  1607632831
# 320        7.58  1607632835
#
# [168 rows x 9 columns]

# %%
# Southern Hemisphere - Max Temp vs. Latitude Linear Regression
# Number of cities in cleaned southern hemisphere dataframe
n2 = len(south_df. index)
t= np.arange(n2)  # Color scale matched with number of data points
plt.scatter(south_df['Lat'], south_df['Max Temp'], s=5, c=t)

# Title and Labels
plt.xlabel('Latitude')
plt.ylabel('Temperature (F)')
plt.title(f'Southern Latitudes vs.Temperature (F) {time.strftime("%m/%d/%Y")}')

plt.grid(True)

# Print out the r-squared value along with the plot.
print(f"The r-squared is: {rvalue**2}")

# Regression Line
x_values = south_df['Lat']
y_values = south_df['Max Temp']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-27,55),fontsize=15,color="darkblue")

# Save the figure
plt.savefig('S Latitude vs.Temperature Reg.png')

plt.show()
# Out:
# The r-squared is: 0.7086290541302908

# %%
print('For every unit of change in latitude the temperature rises.') 
print('A relatively high percentage of the data fit into the model as opposed to other regressions.')
# Out:
# For every unit of change in latitude the temperature rises.
# A relatively high percentage of the data fit into the model as opposed to other regressions.

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Northern Hemisphere - Humidity vs. Latitude Linear Regression

# Number of cities in cleaned northern hemisphere dataframe
n1 = len(northtemp_df. index)
t= np.arange(n1)  # Color scale matched with number of data points
plt.scatter(northtemp_df['Lat'], northtemp_df['Humidity'], s=5, c=t)

# Title and Labels
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.title(f'Northern Latitudes vs.Humidity {time.strftime("%m/%d/%Y")}')

plt.grid(True)

# Print out the r-squared value along with the plot.
print(f"The r-squared is: {rvalue**2}")

# Regression Line
x_values = northtemp_df['Lat']
y_values = northtemp_df['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(40,20),fontsize=15,color="darkblue")

# Save the figure
plt.savefig('N Latitude vs.Humidity Reg.png')

plt.show()
# Out:
# The r-squared is: 0.33753302477032565

# %%
print('For every unit of change in latitude the humidity rises.') 
print('There is a wide distribution of datapoints.')
print('The implication of the r-squared value is that the model offers poor predicatability of results.')
print('Visually this is observed in the wide scatter of datapoints.')
# Out:
# For every unit of change in latitude the humidity rises.
# There is a wide distribution of datapoints.
# The implication of the r-squared value is that the model offers poor predicatability of results.
# Visually this is observed in the wide scatter of datapoints.

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Southern Hemisphere - Humidity vs. Latitude Linear Regression
# Number of cities in cleaned southern hemisphere dataframe
n2 = len(south_df. index)
t= np.arange(n2)  # Color scale matched with number of data points
plt.scatter(south_df['Lat'], south_df['Humidity'], s=5, c=t)

# Title and Labels
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title(f'Southern Latitudes vs.Humidity (%) {time.strftime("%m/%d/%Y")}')

plt.grid(True)

# Print out the r-squared value along with the plot.
print(f"The r-squared is: {rvalue**2}")

# Regression Line
x_values = south_df['Lat']
y_values = south_df['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-55,22),fontsize=15,color="darkblue")

# Save the figure
plt.savefig('S Latitude vs.Humidity Reg.png')

plt.show()
# Out:
# The r-squared is: 0.16480743431706524

# %%
print('For every unit of change in latitude the humidity increases ' + str(round(slope,2)) +' units.') 
print('The implication of the r-squared value is that the model offers poor predicatability of results.')
print('Visually this is observed in the wide scatter of datapoints, eg high variance.')
# Out:
# For every unit of change in latitude the humidity increases 0.37 units.
# The implication of the r-squared value is that the model offers poor predicatability of results.
# Visually this is observed in the wide scatter of datapoints, eg high variance.

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Northern Hemisphere - Cloudiness vs. Latitude Linear Regression
# Number of cities in cleaned northern hemisphere dataframe
n1 = len(northtemp_df. index)
t= np.arange(n1)  # Color scale matched with number of data points
plt.scatter(northtemp_df['Lat'], northtemp_df['Cloudiness'], s=5, c=t)

# Title and Labels
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.title(f'Northern Latitudes vs.Cloudiness {time.strftime("%m/%d/%Y")}')

plt.grid(True)

# Print out the r-squared value along with the plot.
print(f"The r-squared is: {rvalue**2}")

# Regression Line
x_values = northtemp_df['Lat']
y_values = northtemp_df['Cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(45,40),fontsize=15,color="darkblue")

# Save the figure
plt.savefig('N Latitude vs.Cloudiness Reg.png')

plt.show()
# Out:
# The r-squared is: 0.09733564460738992

# %%
print('For every unit of change in latitude the cloudiness increases ' + str(round(slope,2)) +' units.') 
print('The implication of the r-squared value is that the model offers poor predicatability of results.')
print('Visually this is observed in the wide scatter of datapoints , eg high')
print('  variance, with large distributions at the extreme ends of the y-axis.')
# Out:
# For every unit of change in latitude the cloudiness increases 0.54 units.
# The implication of the r-squared value is that the model offers poor predicatability of results.
# Visually this is observed in the wide scatter of datapoints , eg high
#   variance, with large distributions at the extreme ends of the y-axis.

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression
# Number of cities in cleaned southern hemisphere dataframe
n2 = len(south_df. index)
t= np.arange(n2)  # Color scale matched with number of data points
plt.scatter(south_df['Lat'], south_df['Cloudiness'], s=5, c=t)

# Title and Labels
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title(f'Southern Latitudes vs.Cloudiness (%) {time.strftime("%m/%d/%Y")}')

plt.grid(True)

# Print out the r-squared value along with the plot.
print(f"The r-squared is: {rvalue**2}")

# Regression Line
x_values = south_df['Lat']
y_values = south_df['Cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-55,60),fontsize=15,color="darkblue")

# Save the figure
plt.savefig('S Latitude vs.Cloudiness Reg.png')

plt.show()
# Out:
# The r-squared is: 0.07272053384949877

# %%
print('For every unit of change in latitude the cloudiness increases ' + str(round(slope,2)) +' units.') 
print('The implication of the r-squared value is that the model offers poor predicatability of results.')
print('Visually this is observed in the wide scatter of datapoints , eg high')
print('  variance, with large distributions at the extreme ends of the y-axis.')
# Out:
# For every unit of change in latitude the cloudiness increases 0.71 units.
# The implication of the r-squared value is that the model offers poor predicatability of results.
# Visually this is observed in the wide scatter of datapoints , eg high
#   variance, with large distributions at the extreme ends of the y-axis.

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Northern Hemisphere - Wind Speed vs. Latitude Linear Regression
# Number of cities in cleaned northern hemisphere dataframe
n1 = len(northtemp_df. index)
t= np.arange(n1)  # Color scale matched with number of data points
plt.scatter(northtemp_df['Lat'], northtemp_df['Wind Speed'], s=5, c=t)

# Title and Labels
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title(f'Northern Latitudes vs.Wind Speed (mph) {time.strftime("%m/%d/%Y")}')

plt.grid(True)

# Print out the r-squared value along with the plot.
print(f"The r-squared is: {rvalue**2}")

# Regression Line
x_values = northtemp_df['Lat']
y_values = northtemp_df['Wind Speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(5,20),fontsize=15,color="darkblue")

# Save the figure
plt.savefig('N Latitude vs.Wind Speed Reg.png')

plt.show()
# Out:
# The r-squared is: 0.06506277860229132

# %%
print('For every unit of change in latitude the cloudiness increases ' + str(round(slope,2)) +' units...nearly a flat line.') 
print('The implication of the r-squared value is that the model offers poor predicatability of results.')
print('Visually this is observed in the wide scatter of datapoints , eg high')
print('  variance, with large distributions at the extreme ends of the y-axis.')
# Out:
# For every unit of change in latitude the cloudiness increases 0.03 units...nearly a flat line.
# The implication of the r-squared value is that the model offers poor predicatability of results.
# Visually this is observed in the wide scatter of datapoints , eg high
#   variance, with large distributions at the extreme ends of the y-axis.

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
# Number of cities in cleaned southern hemisphere dataframe
n2 = len(south_df. index)
t= np.arange(n2)  # Color scale matched with number of data points
plt.scatter(south_df['Lat'], south_df['Wind Speed'], s=5, c=t)

# Title and Labels
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title(f'Southern Latitudes vs.Wind Speed (mph) {time.strftime("%m/%d/%Y")}')

plt.grid(True)

# Print out the r-squared value along with the plot.
print(f"The r-squared is: {rvalue**2}")

# Regression Line
x_values = south_df['Lat']
y_values = south_df['Wind Speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-55,13),fontsize=15,color="darkblue")

# Save the figure
plt.savefig('S Latitude vs.Wind Speed Reg.png')

plt.show()
# Out:
# The r-squared is: 0.011866856812591501

# %%
print('For every unit of change in latitude the cloudiness increases ' + str(round(slope,2)) +' units.') 
print('The implication of the r-squared value is that the model offers poor predicatability of results.')
print('Visually this is observed in the wide scatter of datapoints , eg high')
print('  variance, with large distributions at the extreme ends of the y-axis.')
# Out:
# For every unit of change in latitude the cloudiness increases -0.1 units.
# The implication of the r-squared value is that the model offers poor predicatability of results.
# Visually this is observed in the wide scatter of datapoints , eg high
#   variance, with large distributions at the extreme ends of the y-axis.
